# %%
import cv2
from keras.models import load_model
from keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import models
import keras
import os
from tensorflow.python.keras.preprocessing import image
from keras import backend as K
from keras.models import load_model
import numpy as np
from tensorflow.keras.applications.vgg16 import preprocess_input

model = models.load_model('../model/vgg16_mass_benign_or_malignant_fine_Adam_best2.h5')
print(model.summary())
# Out:
# Using TensorFlow backend.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# vgg16 (Model)                (None, 8, 8, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              33555456
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# ...
# Total params: 48,401,602
# Trainable params: 38,406,530
# Non-trainable params: 9,995,072
# ...

# %%
def load_testing():
    images = np.load(os.path.join('../Data_final_massver', 'X_test.npy'))
    labels = np.load(os.path.join('../Data_final_massver', 'test_mass_labels2_num.npy'))
    FN = np.load(os.path.join('../Data_final_massver', 'test_mass_FN.npy'))
    return images, labels, FN

# %%
test_images, test_labels, test_FN= load_testing()
n_test_img = test_images.shape[0]

test_labels_raw = test_labels.copy()
test_labels = to_categorical(test_labels)

#test_images = test_images.reshape((n_test_img, 256, 256, 1))

test_images = test_images.astype('uint16')/256
test_images = np.repeat(test_images, 3, axis=3)

# %%
idx = 1

plt.imshow(test_images[idx][:,:,0], cmap='gray')
plt.show()

print("Label: " + str(test_labels[idx]))
print("FN: " + str(test_FN[idx]))
# Out:
# Label: [1. 0.]
# FN: Mass-Training_P_00604_LEFT_CC.png

# %%
x = test_images[idx]
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
x.shape
# Out:
# (1, 256, 256, 3)

# %%
preds = model.predict(x)

# %%
preds
# Out:
# array([[0.8521937 , 0.14780633]], dtype=float32)

# %%
np.argmax(preds[0])
# Out:
# 0

# %%
model.get_layer('vgg16').get_layer('block3_conv1').output
# Out:
# <tf.Tensor 'block3_conv1/Identity:0' shape=(None, 64, 64, 256) dtype=float32>

# %%
model.get_layer('flatten').output
# Out:
# <tf.Tensor 'flatten/Identity:0' shape=(None, 32768) dtype=float32>

# %%
model.get_layer('vgg16').output

# %%
model_input = model.input

    # y_c : class_index에 해당하는 CNN 마지막 layer op(softmax, linear, ...)의 입력
y_c = model.outputs[0].op.inputs[0][0, np.argmax(preds[0])]

    # A_k: activation layer의 출력 feature map
A_k = model.get_layer('vgg16').get_layer('block3_conv1').output


    # model의 입력에 대해서,
    # activation conv layer의 출력(A_k)과
    # 최종 layer activation 입력(y_c)의 A_k에 대한 gradient 계산
get_output = K.function([model_input], [A_k, K.gradients(y_c, A_k)[0]])

[conv_output, grad_val] = get_output([img_tensor])

    # batch size가 포함되어 shape가 (1, width, height, k)이므로
    # (width, height, k)로 shape 변경
    # 여기서 width, height는 activation conv layer인 A_k feature map의 width와 height를 의미함
conv_output = conv_output[0]
grad_val = grad_val[0]

    # global average pooling 연산
    # gradient의 width, height에 대해 평균을 구해서(1/Z) weights(a^c_k) 계산
weights = np.mean(grad_val, axis=(0, 1))

    # activation layer의 출력 feature map(conv_output)과
    # class_index에 해당하는 gradient(a^c_k)를 k에 대응해서 linear combination 계산

    # feature map(conv_output)의 (width, height)로 초기화
grad_cam = np.zeros(dtype=np.float32, shape=conv_output.shape[0:2])
for k, w in enumerate(weights):
    grad_cam += w * conv_output[:, :, k]

    # 계산된 linear combination 에 ReLU 적용
grad_cam = np.maximum(grad_cam, 0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-e00669eff288> in <module>
#      11     # activation conv layer의 출력(A_k)과
#      12     # 최종 layer activation 입력(y_c)의 A_k에 대한 gradient 계산
# ---> 13 get_output = K.function([model_input], [A_k, K.gradients(y_c, A_k)[0]])
#      14
#      15 [conv_output, grad_val] = get_output([img_tensor])
#
# ~\anaconda3\envs\mammo\lib\site-packages\keras\backend\tensorflow_backend.py in function(inputs, outputs, updates, **kwargs)
#    3007     return tf_keras_backend.function(inputs, outputs,
#    3008                                      updates=updates,
# -> 3009                                      **kwargs)
#    3010
#    3011
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\backend.py in function(inputs, outputs, updates, name, **kwargs)
# ...

# %%
layer_output = model.get_layer('vgg16').get_layer('block3_conv1').output

# %%
mymodel_output = model.output[:, 0]
last_conv_layer = model.get_layer('vgg16').get_layer('block5_conv3')
for layer in model.get_layer('vgg16').layers:
    if layer.name.startswith('block5_conv3'):
        last_conv_layer = layer
last_conv_layer2 = model.get_layer('flatten')
print(last_conv_layer.output)
print(last_conv_layer2.output)
# Out:
# Tensor("block5_conv3/Identity:0", shape=(None, 16, 16, 512), dtype=float32)
# Tensor("flatten/Identity:0", shape=(None, 32768), dtype=float32)

# %%
grads = K.gradients(mymodel_output, last_conv_layer2.output)[0]
pooled_grads = K.mean(grads, axis=(0, 1))
iterate = K.function([model.input], [pooled_grads, last_conv_layer2.output[0]])
pooled_grads_value, conv_layer_output_value = iterate([x])
    
conv_layer_output_value.shape
# Out:
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-13-21998dc279f4> in <module>
#       2 pooled_grads = K.mean(grads, axis=(0, 1))
#       3 iterate = K.function([model.input], [pooled_grads, last_conv_layer2.output[0]])
# ----> 4 pooled_grads_value, conv_layer_output_value = iterate([x])
#       5
#       6 conv_layer_output_value.shape
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
# ...

# %%
for i in range(i):
    conv_layer_output_value[i] *= pooled_grads_value[i]
heatmap = np.mean(conv_layer_output_value, axis=-1)

# %%
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)

plt.matshow(heatmap)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-509063f1ac69> in <module>
#       2 heatmap /= np.max(heatmap)
#       3
# ----> 4 plt.matshow(heatmap)
#       5 plt.show()
#
# ~\anaconda3\envs\mammo\lib\site-packages\matplotlib\pyplot.py in matshow(A, fignum, **kwargs)
#    2186         # Extract actual aspect ratio of array and make appropriately sized
#    2187         # figure.
# -> 2188         fig = figure(fignum, figsize=figaspect(A))
#    2189         ax = fig.add_axes([0.15, 0.09, 0.775, 0.775])
#    2190     im = ax.matshow(A, **kwargs)
#
# ~\anaconda3\envs\mammo\lib\site-packages\matplotlib\figure.py in figaspect(arg)
#    2741     # Extract the aspect ratio of the array
#    2742     if isarray:
# -> 2743         nr, nc = arg.shape[:2]
#    2744         arr_ratio = nr / nc
#    2745     else:
#
# ...
