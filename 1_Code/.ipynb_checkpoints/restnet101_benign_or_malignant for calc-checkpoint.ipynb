# %%
import numpy as np
import os
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
def load_training():
    images = np.load(os.path.join('../Data_final_calcver', 'X_train.npy'))
    labels = np.load(os.path.join('../Data_final_calcver', 'train_calc_labels2_num.npy'))
    #FN = np.load(os.path.join('../Data_final_calcver', 'train_calc_FN.npy'))
    return images, labels#, FN


def load_testing():
    images = np.load(os.path.join('../Data_final_calcver', 'X_test.npy'))
    labels = np.load(os.path.join('../Data_final_calcver', 'test_calc_labels2_num.npy'))
    #FN = np.load(os.path.join('../Data_final_calcver', 'test_calc_FN.npy'))
    return images, labels#, FN

# %%
train_images, train_labels= load_training()
test_images, test_labels= load_testing()

n_train_img = train_images.shape[0]
n_test_img = test_images.shape[0]
print("Train size: %d \t Test size: %d" % (n_train_img, n_test_img))

img_w = train_images.shape[1]
img_h = train_images.shape[2]
print("Image size: %dx%d" % (img_w, img_h))
# Out:
# Train size: 1535 	 Test size: 337
# Image size: 256x256

# %%
idx = 10

plt.imshow(test_images[idx][:,:,0], cmap='gray')
plt.show()

print("Label: " + str(test_labels[idx]))
#print("FN: " + str(test_FN[idx]))
# Out:
# Label: 0

# %%
train_labels = to_categorical(train_labels)
test_labels_raw = test_labels.copy()
test_labels = to_categorical(test_labels)

# %%
train_images.shape
# Out:
# (1535, 256, 256, 1)

# %%
train_images = train_images.reshape((n_train_img, img_w, img_h, 1))
test_images = test_images.reshape((n_test_img, img_w, img_h, 1))

# %%
train_images = train_images.astype('uint16')/256
test_images = test_images.astype('uint16')/256

train_images = np.repeat(train_images, 3, axis=3)
test_images = np.repeat(test_images, 3, axis=3)

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2,
    rotation_range=180,
    shear_range=15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='reflect'
)

# %%
train_datagen.fit(train_images)

train_generator = train_datagen.flow(train_images, train_labels, batch_size=128, subset='training')
validation_generator = train_datagen.flow(train_images, train_labels, batch_size=128, subset='validation')

preprocess_input(test_images);

# %%
def create_resnet101(verbose=False, fc_size=256, output = 2, dropout=None):
    
    resnet101_base = ResNet101(weights='imagenet',
                       include_top=False,
                       input_shape=(256, 256, 3))
    resnet101 = models.Sequential()
    resnet101.add(resnet101_base)

    resnet101.add(layers.Flatten())
    if dropout is not None:
        resnet101.add(layers.Dropout(dropout))
    resnet101.add(layers.Dense(fc_size, activation='relu'))
    resnet101.add(layers.Dense(output, activation='softmax'))

    # Freeze the convolutional base
    resnet101_base.trainable = False
    
    if verbose:
        resnet101_base.summary()
        resnet101.summary()

    return resnet101

# %%
resnet = ResNet101(weights='imagenet',
                       include_top=False,
                       input_shape=(256, 256, 3))
for layer in resnet.layers:
    layer.trainable = False
resnet_maxpool = resnet.get_layer('conv5_block3_out').output
FeatureFlatten = Flatten()(resnet_maxpool)
dense1 = Dense(1024, name = 'dense1', activation = 'relu')(FeatureFlatten)
dense2 = Dense(128, name = 'dense2', activation = 'relu')(dense1)
predictions = Dense(2, name = 'predictions', activation = 'softmax')(dense2)

new_resnet = Model(inputs = resnet.input, outputs = predictions)
new_resnet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 262, 262, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 128, 128, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 128, 128, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 128, 128, 64) 0           conv1_bn[0][0]
# ...

# %%
resnet101_calc_benign_or_malignant_best_Adam = new_resnet

# %%
resnet101_calc_benign_or_malignant_best_RMSprop = new_resnet

# %% [markdown]
# ### Adam

# %%
earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/resnet101_calc_benign_or_malignant_best_Adam.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

resnet101_calc_benign_or_malignant_best_Adam.compile(optimizer=optimizers.Adam(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_resnet101_calc_benign_or_malignant_best_Adam = resnet101_calc_benign_or_malignant_best_Adam.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:From <ipython-input-16-a6e324cf13d2>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 2s - loss: 4.8146 - recall: 0.5449
# Epoch 00001: val_loss improved from inf to 0.66456, saving model to ../model/resnet101_calc_benign_or_malignant_best_Adam.h5
# 5/5 [==============================] - 20s 4s/step - loss: 4.2324 - recall: 0.5234 - val_loss: 0.6646 - val_recall: 0.6124
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.8057 - recall: 0.6680
# Epoch 00002: val_loss did not improve from 0.66456
# ...

# %%
models.save_model(resnet101_calc_benign_or_malignant_best_Adam, '../model/resnet101_calc_benign_or_malignant_end_Adam.h5')

# %%
tra_loss_fe = history_resnet101_calc_benign_or_malignant_best_Adam.history['loss']
tra_acc_fe = history_resnet101_calc_benign_or_malignant_best_Adam.history['recall']
val_loss_fe = history_resnet101_calc_benign_or_malignant_best_Adam.history['val_loss']
val_acc_fe = history_resnet101_calc_benign_or_malignant_best_Adam.history['val_recall']

# %%
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_resnet101_calc_benign_or_malignant = models.load_model('../model/resnet101_calc_benign_or_malignant_best_Adam.h5')
test_loss_fe, test_acc_fe = resnet101_calc_benign_or_malignant_best_Adam.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_resnet101_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)

# %%
print("resnet101 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# resnet101 benign or malignant
#
# Epoch [end]: 35
# Epoch [opt]: 5
# Valid recall [end]: 0.5570
# Valid recall [opt]: 0.6678
# Test recall [end]:  0.6469
# Test recall [opt]:  0.6499
# Valid loss [end]: 0.9670
# Valid loss [opt]: 0.6021
# Test loss [end]:  0.8866
# Test loss [opt]:  0.6283

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# ### SGD

# %%
resnet101_calc_benign_or_malignant_best_SGD = create_resnet101(dropout=0.5, fc_size=128, output = 2)

earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/resnet101_calc_benign_or_malignant_best_SGD.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

resnet101_calc_benign_or_malignant_best_SGD.compile(optimizer=optimizers.SGD(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_resnet101_calc_benign_or_malignant_best_SGD = resnet101_calc_benign_or_malignant_best_SGD.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 2s - loss: 1.2863 - recall: 0.5130
# Epoch 00001: val_loss improved from inf to 0.88812, saving model to ../model/resnet101_calc_benign_or_malignant_best_SGD.h5
# 5/5 [==============================] - 15s 3s/step - loss: 1.3254 - recall: 0.5119 - val_loss: 0.8881 - val_recall: 0.5342
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 1.2174 - recall: 0.5664
# Epoch 00002: val_loss did not improve from 0.88812
# 5/5 [==============================] - 12s 2s/step - loss: 1.2032 - recall: 0.5688 - val_loss: 0.9497 - val_recall: 0.4853
# Epoch 3/300
# 4/5 [=======================>......] - ETA: 1s - loss: 1.2207 - recall: 0.5645
# ...

# %%
models.save_model(resnet101_calc_benign_or_malignant_best_SGD, '../model/resnet101_calc_benign_or_malignant_end_SGD.h5')

# %%
tra_loss_fe = history_resnet101_calc_benign_or_malignant_best_SGD.history['loss']
tra_acc_fe = history_resnet101_calc_benign_or_malignant_best_SGD.history['recall']
val_loss_fe = history_resnet101_calc_benign_or_malignant_best_SGD.history['val_loss']
val_acc_fe = history_resnet101_calc_benign_or_malignant_best_SGD.history['val_recall']

epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_resnet101_calc_benign_or_malignant = models.load_model('../model/resnet101_calc_benign_or_malignant_best_SGD.h5')
test_loss_fe, test_acc_fe = resnet101_calc_benign_or_malignant_best_SGD.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_resnet101_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)

print("resnet101 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# resnet101 benign or malignant
#
# Epoch [end]: 120
# Epoch [opt]: 90
# Valid recall [end]: 0.5928
# Valid recall [opt]: 0.6384
# Test recall [end]:  0.6647
# Test recall [opt]:  0.6736
# Valid loss [end]: 0.7185
# Valid loss [opt]: 0.6335
# Test loss [end]:  0.5985
# Test loss [opt]:  0.6026

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 recall')
plt.ylabel('recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# ### RMSprop

# %%
earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/resnet101_calc_benign_or_malignant_best_RMSprop.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

resnet101_calc_benign_or_malignant_best_RMSprop.compile(optimizer=optimizers.RMSprop(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_resnet101_calc_benign_or_malignant_best_RMSprop = resnet101_calc_benign_or_malignant_best_RMSprop.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 2s - loss: 4.1119 - recall: 0.5566
# Epoch 00001: val_loss improved from inf to 1.86836, saving model to ../model/resnet101_calc_benign_or_malignant_best_RMSprop.h5
# 5/5 [==============================] - 17s 3s/step - loss: 4.2508 - recall: 0.5663 - val_loss: 1.8684 - val_recall: 0.4951
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 1.6888 - recall: 0.6217
# Epoch 00002: val_loss improved from 1.86836 to 1.29493, saving model to ../model/resnet101_calc_benign_or_malignant_best_RMSprop.h5
# 5/5 [==============================] - 14s 3s/step - loss: 1.5544 - recall: 0.6224 - val_loss: 1.2949 - val_recall: 0.4853
# Epoch 3/300
# ...

# %%
models.save_model(resnet101_calc_benign_or_malignant_best_RMSprop, '../model/resnet101_calc_benign_or_malignant_end_RMSprop.h5')

# %%
tra_loss_fe = history_resnet101_calc_benign_or_malignant_best_RMSprop.history['loss']
tra_acc_fe = history_resnet101_calc_benign_or_malignant_best_RMSprop.history['recall']
val_loss_fe = history_resnet101_calc_benign_or_malignant_best_RMSprop.history['val_loss']
val_acc_fe = history_resnet101_calc_benign_or_malignant_best_RMSprop.history['val_recall']

epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_resnet101_calc_benign_or_malignant = models.load_model('../model/resnet101_calc_benign_or_malignant_best_RMSprop.h5')
test_loss_fe, test_acc_fe = resnet101_calc_benign_or_malignant_best_RMSprop.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_resnet101_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)

print("resnet101 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# resnet101 benign or malignant
#
# Epoch [end]: 86
# Epoch [opt]: 56
# Valid recall [end]: 0.6189
# Valid recall [opt]: 0.6840
# Test recall [end]:  0.6558
# Test recall [opt]:  0.6795
# Valid loss [end]: 0.7029
# Valid loss [opt]: 0.5612
# Test loss [end]:  0.6494
# Test loss [opt]:  0.5757

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# ### Adadelta

# %%
resnet101_calc_benign_or_malignant_best_Adadelta = create_resnet101(dropout=0.5, fc_size=128, output = 2)

earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/resnet101_calc_benign_or_malignant_best_Adadelta.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

resnet101_calc_benign_or_malignant_best_Adadelta.compile(optimizer=optimizers.Adadelta(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_resnet101_calc_benign_or_malignant_best_Adadelta = resnet101_calc_benign_or_malignant_best_Adadelta.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 2s - loss: 1.3844 - recall: 0.5234
# Epoch 00001: val_loss improved from inf to 0.96363, saving model to ../model/resnet101_calc_benign_or_malignant_best_Adadelta.h5
# 5/5 [==============================] - 15s 3s/step - loss: 1.3403 - recall: 0.5323 - val_loss: 0.9636 - val_recall: 0.4658
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 1.3690 - recall: 0.5469
# Epoch 00002: val_loss did not improve from 0.96363
# 5/5 [==============================] - 11s 2s/step - loss: 1.4161 - recall: 0.5328 - val_loss: 0.9772 - val_recall: 0.4723
# Epoch 3/300
# 4/5 [=======================>......] - ETA: 1s - loss: 1.4027 - recall: 0.5304
# ...

# %%
models.save_model(resnet101_calc_benign_or_malignant_best_Adadelta, '../model/resnet101_calc_benign_or_malignant_end_Adadelta.h5')

# %%
tra_loss_fe = history_resnet101_calc_benign_or_malignant_best_Adadelta.history['loss']
tra_acc_fe = history_resnet101_calc_benign_or_malignant_best_Adadelta.history['recall']
val_loss_fe = history_resnet101_calc_benign_or_malignant_best_Adadelta.history['val_loss']
val_acc_fe = history_resnet101_calc_benign_or_malignant_best_Adadelta.history['val_recall']

epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_resnet101_calc_benign_or_malignant = models.load_model('../model/resnet101_calc_benign_or_malignant_best_Adadelta.h5')
test_loss_fe, test_acc_fe = resnet101_calc_benign_or_malignant_best_Adadelta.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_resnet101_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)

print("resnet101 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# resnet101 benign or malignant
#
# Epoch [end]: 76
# Epoch [opt]: 46
# Valid recall [end]: 0.6189
# Valid recall [opt]: 0.5863
# Test recall [end]:  0.5430
# Test recall [opt]:  0.5312
# Valid loss [end]: 0.7846
# Valid loss [opt]: 0.7601
# Test loss [end]:  0.9448
# Test loss [opt]:  0.9902

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# ### Adagrad

# %%
resnet101_calc_benign_or_malignant_best_Adagrad = create_resnet101(dropout=0.5, fc_size=128, output = 2)

earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/resnet101_calc_benign_or_malignant_best_Adagrad.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

resnet101_calc_benign_or_malignant_best_Adagrad.compile(optimizer=optimizers.Adagrad(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_resnet101_calc_benign_or_malignant_best_Adagrad = resnet101_calc_benign_or_malignant_best_Adagrad.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 2s - loss: 1.4426 - recall: 0.5742
# Epoch 00001: val_loss improved from inf to 0.90561, saving model to ../model/resnet101_calc_benign_or_malignant_best_Adagrad.h5
# 5/5 [==============================] - 15s 3s/step - loss: 1.3761 - recall: 0.5875 - val_loss: 0.9056 - val_recall: 0.6482
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 1.1523 - recall: 0.6130
# Epoch 00002: val_loss improved from 0.90561 to 0.80824, saving model to ../model/resnet101_calc_benign_or_malignant_best_Adagrad.h5
# 5/5 [==============================] - 11s 2s/step - loss: 1.1400 - recall: 0.6156 - val_loss: 0.8082 - val_recall: 0.6254
# Epoch 3/300
# ...

# %%
models.save_model(resnet101_calc_benign_or_malignant_best_Adagrad, '../model/resnet101_calc_benign_or_malignant_end_Adagrad.h5')

# %%
tra_loss_fe = history_resnet101_calc_benign_or_malignant_best_Adagrad.history['loss']
tra_acc_fe = history_resnet101_calc_benign_or_malignant_best_Adagrad.history['recall']
val_loss_fe = history_resnet101_calc_benign_or_malignant_best_Adagrad.history['val_loss']
val_acc_fe = history_resnet101_calc_benign_or_malignant_best_Adagrad.history['val_recall']

epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_resnet101_calc_benign_or_malignant = models.load_model('../model/resnet101_calc_benign_or_malignant_best_Adagrad.h5')
test_loss_fe, test_acc_fe = resnet101_calc_benign_or_malignant_best_Adagrad.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_resnet101_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)

print("resnet101 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# resnet101 benign or malignant
#
# Epoch [end]: 114
# Epoch [opt]: 84
# Valid recall [end]: 0.6482
# Valid recall [opt]: 0.6254
# Test recall [end]:  0.7181
# Test recall [opt]:  0.7003
# Valid loss [end]: 0.6441
# Valid loss [opt]: 0.6154
# Test loss [end]:  0.5717
# Test loss [opt]:  0.5763

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# ### Adamax

# %%
resnet101_calc_benign_or_malignant_best_Adamax = create_resnet101(dropout=0.5, fc_size=128, output = 2)

earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/resnet101_calc_benign_or_malignant_best_Adamax.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

resnet101_calc_benign_or_malignant_best_Adamax.compile(optimizer=optimizers.Adamax(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_resnet101_calc_benign_or_malignant_best_Adamax = resnet101_calc_benign_or_malignant_best_Adamax.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 1s - loss: 1.9418 - recall: 0.5761
# Epoch 00001: val_loss improved from inf to 1.16803, saving model to ../model/resnet101_calc_benign_or_malignant_best_Adamax.h5
# 5/5 [==============================] - 15s 3s/step - loss: 1.8896 - recall: 0.5867 - val_loss: 1.1680 - val_recall: 0.6189
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 1.2670 - recall: 0.6387
# Epoch 00002: val_loss improved from 1.16803 to 0.87455, saving model to ../model/resnet101_calc_benign_or_malignant_best_Adamax.h5
# 5/5 [==============================] - 13s 3s/step - loss: 1.1938 - recall: 0.6453 - val_loss: 0.8745 - val_recall: 0.5635
# Epoch 3/300
# ...

# %%
models.save_model(resnet101_calc_benign_or_malignant_best_Adamax, '../model/resnet101_calc_benign_or_malignant_end_Adamax.h5')

# %%
tra_loss_fe = history_resnet101_calc_benign_or_malignant_best_Adamax.history['loss']
tra_acc_fe = history_resnet101_calc_benign_or_malignant_best_Adamax.history['recall']
val_loss_fe = history_resnet101_calc_benign_or_malignant_best_Adamax.history['val_loss']
val_acc_fe = history_resnet101_calc_benign_or_malignant_best_Adamax.history['val_recall']

epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_resnet101_calc_benign_or_malignant = models.load_model('../model/resnet101_calc_benign_or_malignant_best_Adamax.h5')
test_loss_fe, test_acc_fe = resnet101_calc_benign_or_malignant_best_Adamax.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_resnet101_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)

print("resnet101 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# resnet101 benign or malignant
#
# Epoch [end]: 79
# Epoch [opt]: 49
# Valid recall [end]: 0.6221
# Valid recall [opt]: 0.6743
# Test recall [end]:  0.6825
# Test recall [opt]:  0.7003
# Valid loss [end]: 0.6096
# Valid loss [opt]: 0.5802
# Test loss [end]:  0.5698
# Test loss [opt]:  0.5653

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# ## Nadam

# %%
resnet101_calc_benign_or_malignant_best_Nadam = create_resnet101(dropout=0.5, fc_size=128, output = 2)

earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/resnet101_calc_benign_or_malignant_best_Nadam.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

resnet101_calc_benign_or_malignant_best_Nadam.compile(optimizer=optimizers.Nadam(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_resnet101_calc_benign_or_malignant_best_Nadam = resnet101_calc_benign_or_malignant_best_Nadam.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:From <ipython-input-16-4922ae0e74c9>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 2s - loss: 4.1550 - recall: 0.5801
# Epoch 00001: val_loss improved from inf to 0.78794, saving model to ../model/resnet101_calc_benign_or_malignant_best_Nadam.h5
# 5/5 [==============================] - 16s 3s/step - loss: 3.5068 - recall: 0.5953 - val_loss: 0.7879 - val_recall: 0.5765
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.8636 - recall: 0.6445
# ...

# %%
models.save_model(resnet101_calc_benign_or_malignant_best_Nadam, '../model/resnet101_calc_benign_or_malignant_end_Nadam.h5')

# %%
tra_loss_fe = history_resnet101_calc_benign_or_malignant_best_Nadam.history['loss']
tra_acc_fe = history_resnet101_calc_benign_or_malignant_best_Nadam.history['recall']
val_loss_fe = history_resnet101_calc_benign_or_malignant_best_Nadam.history['val_loss']
val_acc_fe = history_resnet101_calc_benign_or_malignant_best_Nadam.history['val_recall']

epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_resnet101_calc_benign_or_malignant = models.load_model('../model/resnet101_calc_benign_or_malignant_best_Nadam.h5')
test_loss_fe, test_acc_fe = resnet101_calc_benign_or_malignant_best_Nadam.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_resnet101_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)

print("resnet101 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# resnet101 benign or malignant
#
# Epoch [end]: 38
# Epoch [opt]: 8
# Valid recall [end]: 0.5440
# Valid recall [opt]: 0.6482
# Test recall [end]:  0.6380
# Test recall [opt]:  0.6736
# Valid loss [end]: 0.7050
# Valid loss [opt]: 0.6015
# Test loss [end]:  0.5907
# Test loss [opt]:  0.5667

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# #### fine tuning

# %%
resnet101_calc_benign_or_malignant_fine_RMSprop = models.load_model('../model/resnet101_calc_benign_or_malignant_best_RMSprop.h5')

for layer in resnet101_calc_benign_or_malignant_fine_RMSprop.layers:
    if layer.name.startswith('block5_conv3'):
        layer.trainable = True
    else:
        layer.trainable = False

# Recompile the model ()
resnet101_calc_benign_or_malignant_fine_RMSprop.compile(optimizer=optimizers.RMSprop(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

resnet101_calc_benign_or_malignant_fine_RMSprop.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 262, 262, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 128, 128, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 128, 128, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 128, 128, 64) 0           conv1_bn[0][0]
# ...

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint(
        '../model/resnet101_calc_benign_or_malignant_fine_RMSprop_best.h5',
        monitor='val_loss',
        mode='min',
        verbose=1, 
     
    save_best_only=True, 
        save_freq='epoch')

# %%
history_fit = resnet101_calc_benign_or_malignant_fine_RMSprop.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[early_stop, checkpoint],
        shuffle=True,
        verbose=1,
        initial_epoch=0)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# WARNING:tensorflow:The list of trainable weights is empty. Make sure that you are not setting model.trainable to False before compiling the model.
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5395 - recall: 0.7370
# Epoch 00001: val_loss improved from inf to 0.58412, saving model to ../model/resnet101_calc_benign_or_malignant_fine_RMSprop_best.h5
# 5/5 [==============================] - 13s 3s/step - loss: 0.5413 - recall: 0.7313 - val_loss: 0.5841 - val_recall: 0.6710
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.6185 - recall: 0.6674
# Epoch 00002: val_loss improved from 0.58412 to 0.56859, saving model to ../model/resnet101_calc_benign_or_malignant_fine_RMSprop_best.h5
# ...

# %%
models.save_model(resnet101_calc_benign_or_malignant_fine_RMSprop, '../model/resnet101_calc_benign_or_malignant_fine_RMSprop_end.h5')

# %%
# History of accuracy and loss
tra_loss_fe = history_fit.history['loss']
tra_acc_fe = history_fit.history['recall']
val_loss_fe = history_fit.history['val_loss']
val_acc_fe = history_fit.history['val_recall']

# Total number of epochs training
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

# Epoch when reached the validation loss minimum
opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

# Loss and accuracy on the validation set
end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

# Loss and accuracy on the test set
opt_resnet101_calc_benign_or_malignant_fine_RMSprop = models.load_model('../model/resnet101_calc_benign_or_malignant_fine_RMSprop_best.h5')
test_loss_fe, test_acc_fe = resnet101_calc_benign_or_malignant_fine_RMSprop.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_resnet101_calc_benign_or_malignant_fine_RMSprop.evaluate(test_images, test_labels, verbose=False)

print("resnet101 Fine Tuning\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# resnet101 Fine Tuning
#
# Epoch [end]: 63
# Epoch [opt]: 33
# Valid recall [end]: 0.6710
# Valid recall [opt]: 0.6906
# Test recall [end]:  0.6795
# Test recall [opt]:  0.6795
# Valid loss [end]: 0.5907
# Valid loss [opt]: 0.5547
# Test loss [end]:  0.5757
# Test loss [opt]:  0.5757

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %%
resnet101_calc_benign_or_malignant_fine_RMSprop2 = models.load_model('../model/resnet101_calc_benign_or_malignant_fine_RMSprop_best.h5')

for layer in resnet101_calc_benign_or_malignant_fine_RMSprop2.layers:
    if layer.name in ('block5_conv2', 'block5_conv3'):
        layer.trainable = True
    else:
        layer.trainable = False

# Recompile the model ()
resnet101_calc_benign_or_malignant_fine_RMSprop2.compile(optimizer=optimizers.RMSprop(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

resnet101_calc_benign_or_malignant_fine_RMSprop2.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 262, 262, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 128, 128, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 128, 128, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 128, 128, 64) 0           conv1_bn[0][0]
# ...

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint(
        '../model/resnet101_calc_benign_or_malignant_fine_RMSprop_best2.h5',
        monitor='val_loss',
        mode='min',
        verbose=1, 
     
    save_best_only=True, 
        save_freq='epoch')

# %%
history_fit = resnet101_calc_benign_or_malignant_fine_RMSprop2.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[early_stop, checkpoint],
        shuffle=True,
        verbose=1,
        initial_epoch=0)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# WARNING:tensorflow:The list of trainable weights is empty. Make sure that you are not setting model.trainable to False before compiling the model.
# 4/5 [=======================>......] - ETA: 1s - loss: 0.6078 - recall: 0.6738
# Epoch 00001: val_loss improved from inf to 0.58994, saving model to ../model/resnet101_calc_benign_or_malignant_fine_RMSprop_best2.h5
# 5/5 [==============================] - 13s 3s/step - loss: 0.6154 - recall: 0.6735 - val_loss: 0.5899 - val_recall: 0.6678
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5874 - recall: 0.6978
# Epoch 00002: val_loss did not improve from 0.58994
# 5/5 [==============================] - 11s 2s/step - loss: 0.5807 - recall: 0.6990 - val_loss: 0.6002 - val_recall: 0.6417
# ...

# %%
models.save_model(resnet101_calc_benign_or_malignant_fine_RMSprop2, '../model/resnet101_calc_benign_or_malignant_fine_RMSprop_end2.h5')

# %%
# History of accuracy and loss
tra_loss_fe = history_fit.history['loss']
tra_acc_fe = history_fit.history['recall']
val_loss_fe = history_fit.history['val_loss']
val_acc_fe = history_fit.history['val_recall']

# Total number of epochs training
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

# Epoch when reached the validation loss minimum
opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

# Loss and accuracy on the validation set
end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

# Loss and accuracy on the test set
opt_resnet101_calc_benign_or_malignant_fine_RMSprop2 = models.load_model('../model/resnet101_calc_benign_or_malignant_fine_RMSprop_best2.h5')
test_loss_fe, test_acc_fe = resnet101_calc_benign_or_malignant_fine_RMSprop2.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_resnet101_calc_benign_or_malignant_fine_RMSprop2.evaluate(test_images, test_labels, verbose=False)

print("resnet101 Fine Tuning\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# resnet101 Fine Tuning
#
# Epoch [end]: 51
# Epoch [opt]: 21
# Valid recall [end]: 0.6547
# Valid recall [opt]: 0.6710
# Test recall [end]:  0.6795
# Test recall [opt]:  0.6795
# Valid loss [end]: 0.5898
# Valid loss [opt]: 0.5634
# Test loss [end]:  0.5757
# Test loss [opt]:  0.5757

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %%
resnet101_calc_benign_or_malignant_fine_RMSprop3 = models.load_model('../model/resnet101_calc_benign_or_malignant_fine_RMSprop_best2.h5')

for layer in resnet101_calc_benign_or_malignant_fine_RMSprop3.layers:
    if layer.name in ('block5_conv1', 'block5_conv2', 'block5_conv3'):
        layer.trainable = True
    else:
        layer.trainable = False

# Recompile the model ()
resnet101_calc_benign_or_malignant_fine_RMSprop3.compile(optimizer=optimizers.RMSprop(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

resnet101_calc_benign_or_malignant_fine_RMSprop3.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 262, 262, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 128, 128, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 128, 128, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 128, 128, 64) 0           conv1_bn[0][0]
# ...

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint(
        '../model/resnet101_calc_benign_or_malignant_fine_RMSprop_best3.h5',
        monitor='val_loss',
        mode='min',
        verbose=1, 
     
    save_best_only=True, 
        save_freq='epoch')

# %%
history_fit = resnet101_calc_benign_or_malignant_fine_RMSprop3.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[early_stop, checkpoint],
        shuffle=True,
        verbose=1,
        initial_epoch=0)
# Out:
# WARNING:tensorflow:From <ipython-input-18-c3ec1b74d1c0>:9: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# WARNING:tensorflow:The list of trainable weights is empty. Make sure that you are not setting model.trainable to False before compiling the model.
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5844 - recall: 0.7065
# Epoch 00001: val_loss improved from inf to 0.62351, saving model to ../model/resnet101_calc_benign_or_malignant_fine_RMSprop_best3.h5
# 5/5 [==============================] - 15s 3s/step - loss: 0.6001 - recall: 0.6956 - val_loss: 0.6235 - val_recall: 0.6580
# Epoch 2/300
# ...

# %%
models.save_model(resnet101_calc_benign_or_malignant_fine_RMSprop3, '../model/resnet101_calc_benign_or_malignant_fine_RMSprop_end3.h5')

# %%
# History of accuracy and loss
tra_loss_fe = history_fit.history['loss']
tra_acc_fe = history_fit.history['recall']
val_loss_fe = history_fit.history['val_loss']
val_acc_fe = history_fit.history['val_recall']

# Total number of epochs training
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

# Epoch when reached the validation loss minimum
opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

# Loss and accuracy on the validation set
end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

# Loss and accuracy on the test set
opt_resnet101_calc_benign_or_malignant_fine_RMSprop3 = models.load_model('../model/resnet101_calc_benign_or_malignant_fine_RMSprop_best3.h5')
test_loss_fe, test_acc_fe = resnet101_calc_benign_or_malignant_fine_RMSprop3.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_resnet101_calc_benign_or_malignant_fine_RMSprop3.evaluate(test_images, test_labels, verbose=False)

print("resnet101 Fine Tuning\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet101 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();
