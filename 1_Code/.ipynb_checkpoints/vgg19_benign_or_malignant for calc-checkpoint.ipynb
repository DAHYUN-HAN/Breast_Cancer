# %%
import numpy as np
import os
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
def load_training():
    images = np.load(os.path.join('../Data_final_calcver', 'X_train.npy'))
    labels = np.load(os.path.join('../Data_final_calcver', 'train_calc_labels2_num.npy'))
    return images, labels


def load_testing():
    images = np.load(os.path.join('../Data_final_calcver', 'X_test.npy'))
    labels = np.load(os.path.join('../Data_final_calcver', 'test_calc_labels2_num.npy'))
    return images, labels

# %%
train_images, train_labels= load_training()
test_images, test_labels= load_testing()

n_train_img = train_images.shape[0]
n_test_img = test_images.shape[0]
print("Train size: %d \t Test size: %d" % (n_train_img, n_test_img))

img_w = train_images.shape[1]
img_h = train_images.shape[2]
print("Image size: %dx%d" % (img_w, img_h))
# Out:
# Train size: 1546 	 Test size: 326
# Image size: 256x256

# %%
train_labels = to_categorical(train_labels)
test_labels_raw = test_labels.copy()
test_labels = to_categorical(test_labels)

# %%
train_images.shape
# Out:
# (1546, 256, 256, 1)

# %%
train_images = train_images.reshape((n_train_img, img_w, img_h, 1))
test_images = test_images.reshape((n_test_img, img_w, img_h, 1))

# %%
train_images = train_images.astype('uint16')/256
test_images = test_images.astype('uint16')/256

train_images = np.repeat(train_images, 3, axis=3)
test_images = np.repeat(test_images, 3, axis=3)

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2,
    rotation_range=180,
    shear_range=15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='reflect'
)

# %%
train_datagen.fit(train_images)

train_generator = train_datagen.flow(train_images, train_labels, batch_size=128, subset='training')
validation_generator = train_datagen.flow(train_images, train_labels, batch_size=128, subset='validation')

preprocess_input(test_images);

# %%
idx = 111

plt.imshow(train_images[idx][:,:,0], cmap='gray')
plt.show()

print("Label: " + str(train_labels[idx]))
# Out:
# Label: [0. 1.]

# %%
def create_vgg19(verbose=False, fc_size=256, output = 4, dropout=None):

    vgg19_base = VGG19(weights='imagenet',
                       include_top=False,
                       input_shape=(256, 256, 3))
    vgg19 = models.Sequential()
    vgg19.add(vgg19_base)

    vgg19.add(layers.Flatten())
    if dropout is not None:
        vgg19.add(layers.Dropout(dropout))
    vgg19.add(layers.Dense(1024, activation='relu'))
    vgg19.add(layers.Dense(fc_size, activation='relu'))
    vgg19.add(layers.Dense(output, activation='softmax'))

    # Freeze the convolutional base
    vgg19_base.trainable = False
    
    if verbose:
        vgg19_base.summary()
        vgg19.summary()

    return vgg19

# %%
vgg19_calc_benign_or_malignant_best = create_vgg19(dropout=0.5, fc_size=128, output = 2)

# %%
vgg19_calc_benign_or_malignant_best.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Model)                (None, 8, 8, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              33555456
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 53,711,298
# Trainable params: 33,686,914
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/vgg19_calc_benign_or_malignant_best.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

vgg19_calc_benign_or_malignant_best.compile(optimizer=optimizers.Adam(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_vgg19_calc_benign_or_malignant_best = vgg19_calc_benign_or_malignant_best.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:From <ipython-input-16-1dc8a0f73388>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 6 steps, validate for 3 steps
# Epoch 1/300
# 5/6 [========================>.....] - ETA: 2s - loss: 1.3706 - recall: 0.6344
# Epoch 00001: val_loss improved from inf to 1.24282, saving model to ../model/vgg19_calc_benign_or_malignant_best.h5
# 6/6 [==============================] - 18s 3s/step - loss: 1.3076 - recall: 0.6393 - val_loss: 1.2428 - val_recall: 0.6687
# Epoch 2/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.9274 - recall: 0.7155
# Epoch 00002: val_loss improved from 1.24282 to 1.03324, saving model to ../model/vgg19_calc_benign_or_malignant_best.h5
# 6/6 [==============================] - 12s 2s/step - loss: 1.0189 - recall: 0.7004 - val_loss: 1.0332 - val_recall: 0.6327
# Epoch 3/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.7349 - recall: 0.7060
# Epoch 00003: val_loss improved from 1.03324 to 0.77757, saving model to ../model/vgg19_calc_benign_or_malignant_best.h5
# 6/6 [==============================] - 13s 2s/step - loss: 0.7089 - recall: 0.7133 - val_loss: 0.7776 - val_recall: 0.6179
# Epoch 4/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.7178 - recall: 0.7193
# Epoch 00004: val_loss improved from 0.77757 to 0.74363, saving model to ../model/vgg19_calc_benign_or_malignant_best.h5
# 6/6 [==============================] - 13s 2s/step - loss: 0.7028 - recall: 0.7166 - val_loss: 0.7436 - val_recall: 0.6576
# Epoch 5/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5687 - recall: 0.7170
# Epoch 00005: val_loss improved from 0.74363 to 0.65736, saving model to ../model/vgg19_calc_benign_or_malignant_best.h5
# 6/6 [==============================] - 13s 2s/step - loss: 0.5810 - recall: 0.7173 - val_loss: 0.6574 - val_recall: 0.6268
# Epoch 6/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.7444 - recall: 0.6578
# Epoch 00006: val_loss improved from 0.65736 to 0.61269, saving model to ../model/vgg19_calc_benign_or_malignant_best.h5
# 6/6 [==============================] - 14s 2s/step - loss: 0.7467 - recall: 0.6615 - val_loss: 0.6127 - val_recall: 0.6342
# Epoch 7/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5435 - recall: 0.7428
# Epoch 00007: val_loss did not improve from 0.61269
# 6/6 [==============================] - 12s 2s/step - loss: 0.5736 - recall: 0.7270 - val_loss: 0.7256 - val_recall: 0.6253
# Epoch 8/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5804 - recall: 0.7037
# Epoch 00008: val_loss did not improve from 0.61269
# 6/6 [==============================] - 13s 2s/step - loss: 0.5829 - recall: 0.7075 - val_loss: 0.6342 - val_recall: 0.6628
# Epoch 9/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.6162 - recall: 0.7016
# Epoch 00009: val_loss did not improve from 0.61269
# 6/6 [==============================] - 12s 2s/step - loss: 0.5974 - recall: 0.7083 - val_loss: 0.6992 - val_recall: 0.6368
# Epoch 10/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5333 - recall: 0.7272
# Epoch 00010: val_loss did not improve from 0.61269
# 6/6 [==============================] - 13s 2s/step - loss: 0.5365 - recall: 0.7245 - val_loss: 0.6237 - val_recall: 0.6791
# Epoch 11/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5280 - recall: 0.7428
# Epoch 00011: val_loss did not improve from 0.61269
# 6/6 [==============================] - 13s 2s/step - loss: 0.5490 - recall: 0.7284 - val_loss: 0.6386 - val_recall: 0.6524
# Epoch 12/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5274 - recall: 0.7516
# Epoch 00012: val_loss did not improve from 0.61269
# 6/6 [==============================] - 13s 2s/step - loss: 0.5492 - recall: 0.7396 - val_loss: 0.6794 - val_recall: 0.6702
# Epoch 13/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5935 - recall: 0.7094
# Epoch 00013: val_loss did not improve from 0.61269
# 6/6 [==============================] - 13s 2s/step - loss: 0.5931 - recall: 0.7122 - val_loss: 0.6720 - val_recall: 0.6661
# Epoch 14/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5348 - recall: 0.7328
# Epoch 00014: val_loss did not improve from 0.61269
# 6/6 [==============================] - 11s 2s/step - loss: 0.5184 - recall: 0.7381 - val_loss: 0.6677 - val_recall: 0.6368
# Epoch 15/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5036 - recall: 0.7537
# Epoch 00015: val_loss did not improve from 0.61269
# 6/6 [==============================] - 12s 2s/step - loss: 0.5081 - recall: 0.7505 - val_loss: 0.6653 - val_recall: 0.6158
# Epoch 16/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5291 - recall: 0.7326
# Epoch 00016: val_loss did not improve from 0.61269
# 6/6 [==============================] - 12s 2s/step - loss: 0.5216 - recall: 0.7420 - val_loss: 0.7057 - val_recall: 0.6268
# Epoch 17/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5125 - recall: 0.7420
# Epoch 00017: val_loss did not improve from 0.61269
# 6/6 [==============================] - 13s 2s/step - loss: 0.5126 - recall: 0.7472 - val_loss: 0.6258 - val_recall: 0.6435
# Epoch 18/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5420 - recall: 0.7241
# Epoch 00018: val_loss did not improve from 0.61269
# 6/6 [==============================] - 13s 2s/step - loss: 0.5447 - recall: 0.7232 - val_loss: 0.6387 - val_recall: 0.6624
# Epoch 19/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4967 - recall: 0.7530
# Epoch 00019: val_loss did not improve from 0.61269
# 6/6 [==============================] - 13s 2s/step - loss: 0.4946 - recall: 0.7590 - val_loss: 0.6695 - val_recall: 0.6472
# Epoch 20/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5137 - recall: 0.7359
# Epoch 00020: val_loss did not improve from 0.61269
# 6/6 [==============================] - 14s 2s/step - loss: 0.5140 - recall: 0.7344 - val_loss: 0.6295 - val_recall: 0.6728
# Epoch 21/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5287 - recall: 0.7437
# Epoch 00021: val_loss did not improve from 0.61269
# 6/6 [==============================] - 13s 2s/step - loss: 0.5271 - recall: 0.7435 - val_loss: 0.6192 - val_recall: 0.6539
# Epoch 22/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5319 - recall: 0.7297
# Epoch 00022: val_loss did not improve from 0.61269
# 6/6 [==============================] - 13s 2s/step - loss: 0.5269 - recall: 0.7357 - val_loss: 0.6195 - val_recall: 0.6478
# Epoch 23/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5131 - recall: 0.7405
# Epoch 00023: val_loss improved from 0.61269 to 0.59750, saving model to ../model/vgg19_calc_benign_or_malignant_best.h5
# 6/6 [==============================] - 13s 2s/step - loss: 0.5070 - recall: 0.7381 - val_loss: 0.5975 - val_recall: 0.6702
# Epoch 24/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5283 - recall: 0.7250
# Epoch 00024: val_loss did not improve from 0.59750
# 6/6 [==============================] - 13s 2s/step - loss: 0.5263 - recall: 0.7214 - val_loss: 0.6133 - val_recall: 0.6587
# Epoch 25/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4604 - recall: 0.7529
# Epoch 00025: val_loss did not improve from 0.59750
# 6/6 [==============================] - 13s 2s/step - loss: 0.4706 - recall: 0.7525 - val_loss: 0.5998 - val_recall: 0.6828
# Epoch 26/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5025 - recall: 0.7437
# Epoch 00026: val_loss improved from 0.59750 to 0.57855, saving model to ../model/vgg19_calc_benign_or_malignant_best.h5
# 6/6 [==============================] - 13s 2s/step - loss: 0.4920 - recall: 0.7487 - val_loss: 0.5785 - val_recall: 0.6832
# Epoch 27/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4760 - recall: 0.7537
# Epoch 00027: val_loss did not improve from 0.57855
# 6/6 [==============================] - 12s 2s/step - loss: 0.4648 - recall: 0.7609 - val_loss: 0.6134 - val_recall: 0.6390
# Epoch 28/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4838 - recall: 0.7531
# Epoch 00028: val_loss did not improve from 0.57855
# 6/6 [==============================] - 12s 2s/step - loss: 0.5006 - recall: 0.7383 - val_loss: 0.5863 - val_recall: 0.6906
# Epoch 29/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5386 - recall: 0.6967
# Epoch 00029: val_loss did not improve from 0.57855
# 6/6 [==============================] - 13s 2s/step - loss: 0.5256 - recall: 0.7095 - val_loss: 0.6326 - val_recall: 0.6539
# Epoch 30/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4895 - recall: 0.7232
# Epoch 00030: val_loss did not improve from 0.57855
# 6/6 [==============================] - 12s 2s/step - loss: 0.4973 - recall: 0.7225 - val_loss: 0.6325 - val_recall: 0.6509
# Epoch 31/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5001 - recall: 0.7406
# Epoch 00031: val_loss did not improve from 0.57855
# 6/6 [==============================] - 13s 2s/step - loss: 0.5085 - recall: 0.7344 - val_loss: 0.5903 - val_recall: 0.6676
# Epoch 32/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4837 - recall: 0.7359
# Epoch 00032: val_loss did not improve from 0.57855
# 6/6 [==============================] - 13s 2s/step - loss: 0.4950 - recall: 0.7344 - val_loss: 0.6140 - val_recall: 0.6565
# Epoch 33/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5201 - recall: 0.7297
# Epoch 00033: val_loss did not improve from 0.57855
# 6/6 [==============================] - 12s 2s/step - loss: 0.5163 - recall: 0.7296 - val_loss: 0.5989 - val_recall: 0.6724
# Epoch 34/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4884 - recall: 0.7240
# Epoch 00034: val_loss did not improve from 0.57855
# 6/6 [==============================] - 12s 2s/step - loss: 0.4968 - recall: 0.7192 - val_loss: 0.5984 - val_recall: 0.6602
# Epoch 35/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4761 - recall: 0.7631
# Epoch 00035: val_loss improved from 0.57855 to 0.57721, saving model to ../model/vgg19_calc_benign_or_malignant_best.h5
# 6/6 [==============================] - 14s 2s/step - loss: 0.4852 - recall: 0.7544 - val_loss: 0.5772 - val_recall: 0.6351
# Epoch 36/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4757 - recall: 0.7553
# Epoch 00036: val_loss did not improve from 0.57721
# 6/6 [==============================] - 13s 2s/step - loss: 0.4761 - recall: 0.7518 - val_loss: 0.5983 - val_recall: 0.6659
# Epoch 37/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4746 - recall: 0.7326
# Epoch 00037: val_loss did not improve from 0.57721
# 6/6 [==============================] - 13s 2s/step - loss: 0.4818 - recall: 0.7368 - val_loss: 0.5813 - val_recall: 0.6492
# Epoch 38/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4803 - recall: 0.7412
# Epoch 00038: val_loss did not improve from 0.57721
# 6/6 [==============================] - 12s 2s/step - loss: 0.4779 - recall: 0.7427 - val_loss: 0.5993 - val_recall: 0.6518
# Epoch 39/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4712 - recall: 0.7422
# Epoch 00039: val_loss did not improve from 0.57721
# 6/6 [==============================] - 12s 2s/step - loss: 0.4844 - recall: 0.7292 - val_loss: 0.5850 - val_recall: 0.6874
# Epoch 40/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4755 - recall: 0.7594
# Epoch 00040: val_loss did not improve from 0.57721
# 6/6 [==============================] - 13s 2s/step - loss: 0.4752 - recall: 0.7643 - val_loss: 0.6154 - val_recall: 0.6613
# Epoch 41/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4825 - recall: 0.7420
# Epoch 00041: val_loss improved from 0.57721 to 0.57449, saving model to ../model/vgg19_calc_benign_or_malignant_best.h5
# 6/6 [==============================] - 13s 2s/step - loss: 0.4797 - recall: 0.7407 - val_loss: 0.5745 - val_recall: 0.6706
# Epoch 42/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4761 - recall: 0.7530
# Epoch 00042: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4742 - recall: 0.7473 - val_loss: 0.6649 - val_recall: 0.6618
# Epoch 43/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4513 - recall: 0.7733
# Epoch 00043: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4589 - recall: 0.7681 - val_loss: 0.6280 - val_recall: 0.6498
# Epoch 44/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4786 - recall: 0.7420
# Epoch 00044: val_loss did not improve from 0.57449
# 6/6 [==============================] - 12s 2s/step - loss: 0.4758 - recall: 0.7447 - val_loss: 0.6280 - val_recall: 0.6591
# Epoch 45/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4867 - recall: 0.7406
# Epoch 00045: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4825 - recall: 0.7396 - val_loss: 0.6051 - val_recall: 0.6346
# Epoch 46/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4623 - recall: 0.7672
# Epoch 00046: val_loss did not improve from 0.57449
# 6/6 [==============================] - 12s 2s/step - loss: 0.4643 - recall: 0.7695 - val_loss: 0.6258 - val_recall: 0.6817
# Epoch 47/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4704 - recall: 0.7500
# Epoch 00047: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4783 - recall: 0.7422 - val_loss: 0.6713 - val_recall: 0.6420
# Epoch 48/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4810 - recall: 0.7422
# Epoch 00048: val_loss did not improve from 0.57449
# 6/6 [==============================] - 12s 2s/step - loss: 0.4801 - recall: 0.7487 - val_loss: 0.6287 - val_recall: 0.6717
# Epoch 49/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4439 - recall: 0.7670
# Epoch 00049: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4607 - recall: 0.7577 - val_loss: 0.6129 - val_recall: 0.6487
# Epoch 50/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4528 - recall: 0.7420
# Epoch 00050: val_loss did not improve from 0.57449
# 6/6 [==============================] - 12s 2s/step - loss: 0.4587 - recall: 0.7381 - val_loss: 0.6286 - val_recall: 0.6477
# Epoch 51/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4601 - recall: 0.7412
# Epoch 00051: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4646 - recall: 0.7401 - val_loss: 0.6369 - val_recall: 0.6711
# Epoch 52/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4492 - recall: 0.7631
# Epoch 00052: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4468 - recall: 0.7649 - val_loss: 0.6812 - val_recall: 0.6733
# Epoch 53/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4897 - recall: 0.7500
# Epoch 00053: val_loss did not improve from 0.57449
# 6/6 [==============================] - 12s 2s/step - loss: 0.4908 - recall: 0.7435 - val_loss: 0.6371 - val_recall: 0.6613
# Epoch 54/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4879 - recall: 0.7547
# Epoch 00054: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4845 - recall: 0.7565 - val_loss: 0.6506 - val_recall: 0.6576
# Epoch 55/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4728 - recall: 0.7453
# Epoch 00055: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4730 - recall: 0.7474 - val_loss: 0.6077 - val_recall: 0.6628
# Epoch 56/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4533 - recall: 0.7686
# Epoch 00056: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4553 - recall: 0.7707 - val_loss: 0.6278 - val_recall: 0.6268
# Epoch 57/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4552 - recall: 0.7483
# Epoch 00057: val_loss did not improve from 0.57449
# 6/6 [==============================] - 12s 2s/step - loss: 0.4654 - recall: 0.7407 - val_loss: 0.5861 - val_recall: 0.6414
# Epoch 58/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4799 - recall: 0.7389
# Epoch 00058: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4688 - recall: 0.7472 - val_loss: 0.6906 - val_recall: 0.6613
# Epoch 59/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4681 - recall: 0.7647
# Epoch 00059: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4699 - recall: 0.7596 - val_loss: 0.6980 - val_recall: 0.6335
# Epoch 60/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4367 - recall: 0.7795
# Epoch 00060: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4437 - recall: 0.7720 - val_loss: 0.6617 - val_recall: 0.6398
# Epoch 61/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4753 - recall: 0.7295
# Epoch 00061: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4886 - recall: 0.7264 - val_loss: 0.6487 - val_recall: 0.6351
# Epoch 62/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4619 - recall: 0.7594
# Epoch 00062: val_loss did not improve from 0.57449
# 6/6 [==============================] - 12s 2s/step - loss: 0.4525 - recall: 0.7669 - val_loss: 0.6553 - val_recall: 0.6702
# Epoch 63/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4907 - recall: 0.7375
# Epoch 00063: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4776 - recall: 0.7435 - val_loss: 0.6385 - val_recall: 0.6513
# Epoch 64/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4645 - recall: 0.7248
# Epoch 00064: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4699 - recall: 0.7251 - val_loss: 0.6059 - val_recall: 0.6639
# Epoch 65/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4491 - recall: 0.7772
# Epoch 00065: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4522 - recall: 0.7662 - val_loss: 0.6459 - val_recall: 0.6335
# Epoch 66/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4443 - recall: 0.7740
# Epoch 00066: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4643 - recall: 0.7583 - val_loss: 0.6277 - val_recall: 0.6958
# Epoch 67/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4678 - recall: 0.7311
# Epoch 00067: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4604 - recall: 0.7369 - val_loss: 0.5973 - val_recall: 0.6591
# Epoch 68/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4469 - recall: 0.7647
# Epoch 00068: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4449 - recall: 0.7662 - val_loss: 0.6365 - val_recall: 0.6713
# Epoch 69/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4711 - recall: 0.7531
# Epoch 00069: val_loss did not improve from 0.57449
# 6/6 [==============================] - 13s 2s/step - loss: 0.4770 - recall: 0.7500 - val_loss: 0.6405 - val_recall: 0.6613
# Epoch 70/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4565 - recall: 0.7781
# Epoch 00070: val_loss did not improve from 0.57449
# 6/6 [==============================] - 12s 2s/step - loss: 0.4411 - recall: 0.7877 - val_loss: 0.6259 - val_recall: 0.6576
# Epoch 71/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4383 - recall: 0.7796
# Epoch 00071: val_loss did not improve from 0.57449
# 6/6 [==============================] - 12s 2s/step - loss: 0.4425 - recall: 0.7785 - val_loss: 0.6934 - val_recall: 0.6613
# Epoch 00071: early stopping

# %%
models.save_model(vgg19_calc_benign_or_malignant_best, '../model/vgg19_calc_benign_or_malignant_end.h5')

# %%
tra_loss_fe = history_vgg19_calc_benign_or_malignant_best.history['loss']
tra_acc_fe = history_vgg19_calc_benign_or_malignant_best.history['recall']
val_loss_fe = history_vgg19_calc_benign_or_malignant_best.history['val_loss']
val_acc_fe = history_vgg19_calc_benign_or_malignant_best.history['val_recall']

# %%
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_vgg19_calc_benign_or_malignant = models.load_model('../model/vgg19_calc_benign_or_malignant_best.h5')
test_loss_fe, test_acc_fe = vgg19_calc_benign_or_malignant_best.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_vgg19_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-dddb77d8bac9> in <module>
#       9 opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]
#      10
# ---> 11 opt_vgg19_calc_benign_or_malignant = models.load_model('../model/vgg19_calc_benign_or_malignant_best.h5')
#      12 test_loss_fe, test_acc_fe = vgg19_calc_benign_or_malignant_best.evaluate(test_images, test_labels, verbose=False)
#      13 opt_test_loss_fe, opt_test_acc_fe = opt_vgg19_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\saving\save.py in load_model(filepath, custom_objects, compile)
#     144   if (h5py is not None and (
#     145       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\saving\hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     182       # Compile model.
#     183       model.compile(**saving_utils.compile_args_from_training_config(
# --> 184           training_config, custom_objects))
#     185
#     186       # Set optimizer weights.
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\engine\training.py in compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, weighted_metrics, target_tensors, distribute, **kwargs)
#     427     with K.get_graph().as_default():
#     428       # Save all metric attributes per output of the model.
# --> 429       self._cache_output_metric_attributes(metrics, weighted_metrics)
#     430
#     431       # Set metric attributes on model.
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\engine\training.py in _cache_output_metric_attributes(self, metrics, weighted_metrics)
#    1840         output_shapes.append(output.shape.as_list())
#    1841     self._per_output_metrics = training_utils.collect_per_output_metric_info(
# -> 1842         metrics, self.output_names, output_shapes, self.loss_functions)
#    1843     self._per_output_weighted_metrics = (
#    1844         training_utils.collect_per_output_metric_info(
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py in collect_per_output_metric_info(metrics, output_names, output_shapes, loss_fns, is_weighted)
#     880       metric_name = get_metric_name(metric, is_weighted)
#     881       metric_fn = get_metric_function(
# --> 882           metric, output_shape=output_shapes[i], loss_fn=loss_fns[i])
#     883
#     884       # If the metric function is not stateful, we create a stateful version.
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py in get_metric_function(metric, output_shape, loss_fn)
#    1105   """
#    1106   if metric not in ['accuracy', 'acc', 'crossentropy', 'ce']:
# -> 1107     return metrics_module.get(metric)
#    1108
#    1109   is_sparse_categorical_crossentropy = (
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\metrics.py in get(identifier)
#    3062     return deserialize(identifier)
#    3063   elif isinstance(identifier, six.string_types):
# -> 3064     return deserialize(str(identifier))
#    3065   elif callable(identifier):
#    3066     return identifier
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\metrics.py in deserialize(config, custom_objects)
#    3054       module_objects=globals(),
#    3055       custom_objects=custom_objects,
# -> 3056       printable_module_name='metric function')
#    3057
#    3058
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\utils\generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     320       obj = module_objects.get(object_name)
#     321       if obj is None:
# --> 322         raise ValueError('Unknown ' + printable_module_name + ':' + object_name)
#     323     # Classes passed by name are instantiated with no args, functions are
#     324     # returned as-is.
#
# ValueError: Unknown metric function:recall

# %%
print("VGG19 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid accuracy [end]: %.4f" % end_val_acc_fe)
print("Valid accuracy [opt]: %.4f" % opt_val_acc_fe)
print("Test accuracy [end]:  %.4f" % test_acc_fe)
print("Test accuracy [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)

# %%
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('VGG19 FT accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('VGG19 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# #### fine tuning

# %%
vgg19_calc_benign_or_malignant_1 = models.load_model('../model/vgg19_calc_benign_or_malignant_best.h5')

for layer in vgg19_calc_benign_or_malignant_1.get_layer('vgg19').layers:
    if layer.name.startswith('block5_conv4'):
        layer.trainable = True
    else:
        layer.trainable = False

# Recompile the model ()
vgg19_calc_benign_or_malignant_1.compile(optimizer=optimizers.RMSprop(lr=1e-4), loss='categorical_crossentropy', metrics=[tf.keras.metrics.Recall(name='recall')])

vgg19_calc_benign_or_malignant_1.summary()
vgg19_calc_benign_or_malignant_1.get_layer('vgg19').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Model)                (None, 8, 8, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              33555456
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 53,711,298
# Trainable params: 36,046,722
# Non-trainable params: 17,664,576
# _________________________________________________________________
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 2,359,808
# Non-trainable params: 17,664,576
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint(
        '../model/vgg19_calc_benign_or_malignant_1_best.h5',
        monitor='val_loss',
        mode='min',
        verbose=1, 
     
    save_best_only=True, 
        save_freq='epoch')

# %%
history_fit = vgg19_calc_benign_or_malignant_1.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[early_stop, checkpoint],
        shuffle=True,
        verbose=1,
        initial_epoch=0)
# Out:
# WARNING:tensorflow:From <ipython-input-12-329dade40d09>:9: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 6 steps, validate for 3 steps
# Epoch 1/300
# 5/6 [========================>.....] - ETA: 2s - loss: 0.7201 - recall: 0.7063
# Epoch 00001: val_loss improved from inf to 0.58713, saving model to ../model/vgg19_calc_benign_or_malignant_1_best.h5
# 6/6 [==============================] - 17s 3s/step - loss: 0.6904 - recall: 0.7174 - val_loss: 0.5871 - val_recall: 0.6699
# Epoch 2/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5027 - recall: 0.7270
# Epoch 00002: val_loss improved from 0.58713 to 0.55085, saving model to ../model/vgg19_calc_benign_or_malignant_1_best.h5
# 6/6 [==============================] - 14s 2s/step - loss: 0.5041 - recall: 0.7214 - val_loss: 0.5508 - val_recall: 0.6505
# Epoch 3/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4953 - recall: 0.7375
# Epoch 00003: val_loss did not improve from 0.55085
# 6/6 [==============================] - 11s 2s/step - loss: 0.5012 - recall: 0.7366 - val_loss: 0.6266 - val_recall: 0.6408
# Epoch 4/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5144 - recall: 0.7286
# Epoch 00004: val_loss did not improve from 0.55085
# 6/6 [==============================] - 12s 2s/step - loss: 0.5172 - recall: 0.7283 - val_loss: 0.5843 - val_recall: 0.6602
# Epoch 5/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5181 - recall: 0.7538
# Epoch 00005: val_loss did not improve from 0.55085
# 6/6 [==============================] - 11s 2s/step - loss: 0.5068 - recall: 0.7559 - val_loss: 0.5986 - val_recall: 0.6570
# Epoch 6/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4725 - recall: 0.7856
# Epoch 00006: val_loss improved from 0.55085 to 0.54796, saving model to ../model/vgg19_calc_benign_or_malignant_1_best.h5
# 6/6 [==============================] - 12s 2s/step - loss: 0.4788 - recall: 0.7752 - val_loss: 0.5480 - val_recall: 0.6990
# Epoch 7/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5056 - recall: 0.7136
# Epoch 00007: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4906 - recall: 0.7228 - val_loss: 0.5751 - val_recall: 0.6667
# Epoch 8/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4954 - recall: 0.7375
# Epoch 00008: val_loss did not improve from 0.54796
# 6/6 [==============================] - 13s 2s/step - loss: 0.4821 - recall: 0.7578 - val_loss: 0.6316 - val_recall: 0.6537
# Epoch 9/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.5056 - recall: 0.7538
# Epoch 00009: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4934 - recall: 0.7531 - val_loss: 0.5973 - val_recall: 0.6893
# Epoch 10/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4739 - recall: 0.7437
# Epoch 00010: val_loss did not improve from 0.54796
# 6/6 [==============================] - 13s 2s/step - loss: 0.4786 - recall: 0.7366 - val_loss: 0.5834 - val_recall: 0.6375
# Epoch 11/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4544 - recall: 0.7437
# Epoch 00011: val_loss did not improve from 0.54796
# 6/6 [==============================] - 11s 2s/step - loss: 0.4657 - recall: 0.7393 - val_loss: 0.5799 - val_recall: 0.6796
# Epoch 12/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4564 - recall: 0.7547
# Epoch 00012: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4479 - recall: 0.7578 - val_loss: 0.6838 - val_recall: 0.6343
# Epoch 13/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4618 - recall: 0.7547
# Epoch 00013: val_loss did not improve from 0.54796
# 6/6 [==============================] - 13s 2s/step - loss: 0.4706 - recall: 0.7476 - val_loss: 0.6197 - val_recall: 0.6311
# Epoch 14/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4520 - recall: 0.7609
# Epoch 00014: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4733 - recall: 0.7487 - val_loss: 0.5858 - val_recall: 0.6634
# Epoch 15/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4483 - recall: 0.7922
# Epoch 00015: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4594 - recall: 0.7821 - val_loss: 0.5934 - val_recall: 0.6505
# Epoch 16/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4781 - recall: 0.7454
# Epoch 00016: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4639 - recall: 0.7559 - val_loss: 0.6521 - val_recall: 0.6505
# Epoch 17/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4788 - recall: 0.7705
# Epoch 00017: val_loss did not improve from 0.54796
# 6/6 [==============================] - 11s 2s/step - loss: 0.4785 - recall: 0.7724 - val_loss: 0.6555 - val_recall: 0.6505
# Epoch 18/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4537 - recall: 0.7621
# Epoch 00018: val_loss did not improve from 0.54796
# 6/6 [==============================] - 11s 2s/step - loss: 0.4533 - recall: 0.7683 - val_loss: 0.6187 - val_recall: 0.6861
# Epoch 19/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4516 - recall: 0.7739
# Epoch 00019: val_loss did not improve from 0.54796
# 6/6 [==============================] - 11s 2s/step - loss: 0.4765 - recall: 0.7614 - val_loss: 0.5836 - val_recall: 0.6343
# Epoch 20/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4523 - recall: 0.7605
# Epoch 00020: val_loss did not improve from 0.54796
# 6/6 [==============================] - 11s 2s/step - loss: 0.4392 - recall: 0.7779 - val_loss: 0.5588 - val_recall: 0.6926
# Epoch 21/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4513 - recall: 0.7672
# Epoch 00021: val_loss did not improve from 0.54796
# 6/6 [==============================] - 11s 2s/step - loss: 0.4495 - recall: 0.7655 - val_loss: 0.6453 - val_recall: 0.6796
# Epoch 22/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4496 - recall: 0.7812
# Epoch 00022: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4643 - recall: 0.7734 - val_loss: 0.5686 - val_recall: 0.6440
# Epoch 23/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4446 - recall: 0.7471
# Epoch 00023: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4650 - recall: 0.7324 - val_loss: 0.5732 - val_recall: 0.6667
# Epoch 24/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4101 - recall: 0.7797
# Epoch 00024: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4233 - recall: 0.7669 - val_loss: 0.6195 - val_recall: 0.6634
# Epoch 25/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4423 - recall: 0.7588
# Epoch 00025: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4285 - recall: 0.7779 - val_loss: 0.6608 - val_recall: 0.6667
# Epoch 26/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4761 - recall: 0.7370
# Epoch 00026: val_loss did not improve from 0.54796
# 6/6 [==============================] - 11s 2s/step - loss: 0.4664 - recall: 0.7366 - val_loss: 0.6289 - val_recall: 0.6440
# Epoch 27/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4524 - recall: 0.7705
# Epoch 00027: val_loss did not improve from 0.54796
# 6/6 [==============================] - 11s 2s/step - loss: 0.4425 - recall: 0.7821 - val_loss: 0.6821 - val_recall: 0.6828
# Epoch 28/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4563 - recall: 0.7571
# Epoch 00028: val_loss did not improve from 0.54796
# 6/6 [==============================] - 13s 2s/step - loss: 0.4620 - recall: 0.7586 - val_loss: 0.6523 - val_recall: 0.6602
# Epoch 29/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.3975 - recall: 0.7844
# Epoch 00029: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4136 - recall: 0.7734 - val_loss: 0.6421 - val_recall: 0.6667
# Epoch 30/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4757 - recall: 0.7437
# Epoch 00030: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4742 - recall: 0.7393 - val_loss: 0.6428 - val_recall: 0.6699
# Epoch 31/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4665 - recall: 0.7722
# Epoch 00031: val_loss did not improve from 0.54796
# 6/6 [==============================] - 11s 2s/step - loss: 0.4515 - recall: 0.7848 - val_loss: 0.6043 - val_recall: 0.6505
# Epoch 32/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4726 - recall: 0.7554
# Epoch 00032: val_loss did not improve from 0.54796
# 6/6 [==============================] - 13s 2s/step - loss: 0.4504 - recall: 0.7724 - val_loss: 0.7022 - val_recall: 0.6667
# Epoch 33/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4030 - recall: 0.7984
# Epoch 00033: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4269 - recall: 0.7826 - val_loss: 0.6636 - val_recall: 0.6440
# Epoch 34/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4407 - recall: 0.7739
# Epoch 00034: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4477 - recall: 0.7724 - val_loss: 0.6133 - val_recall: 0.6440
# Epoch 35/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4544 - recall: 0.7454
# Epoch 00035: val_loss did not improve from 0.54796
# 6/6 [==============================] - 12s 2s/step - loss: 0.4436 - recall: 0.7559 - val_loss: 0.5679 - val_recall: 0.6796
# Epoch 36/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4639 - recall: 0.7454
# Epoch 00036: val_loss improved from 0.54796 to 0.54788, saving model to ../model/vgg19_calc_benign_or_malignant_1_best.h5
# 6/6 [==============================] - 12s 2s/step - loss: 0.4614 - recall: 0.7490 - val_loss: 0.5479 - val_recall: 0.6375
# Epoch 37/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4289 - recall: 0.7828
# Epoch 00037: val_loss did not improve from 0.54788
# 6/6 [==============================] - 13s 2s/step - loss: 0.4140 - recall: 0.7969 - val_loss: 0.6517 - val_recall: 0.6764
# Epoch 38/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4095 - recall: 0.7859
# Epoch 00038: val_loss did not improve from 0.54788
# 6/6 [==============================] - 12s 2s/step - loss: 0.4145 - recall: 0.7721 - val_loss: 0.6676 - val_recall: 0.6764
# Epoch 39/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4292 - recall: 0.7856
# Epoch 00039: val_loss improved from 0.54788 to 0.54007, saving model to ../model/vgg19_calc_benign_or_malignant_1_best.h5
# 6/6 [==============================] - 13s 2s/step - loss: 0.4205 - recall: 0.7931 - val_loss: 0.5401 - val_recall: 0.6828
# Epoch 40/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4138 - recall: 0.7812
# Epoch 00040: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4109 - recall: 0.7834 - val_loss: 0.6793 - val_recall: 0.6699
# Epoch 41/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4371 - recall: 0.7750
# Epoch 00041: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4208 - recall: 0.7786 - val_loss: 0.6013 - val_recall: 0.6602
# Epoch 42/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4497 - recall: 0.7672
# Epoch 00042: val_loss did not improve from 0.54007
# 6/6 [==============================] - 13s 2s/step - loss: 0.4517 - recall: 0.7578 - val_loss: 0.7489 - val_recall: 0.6570
# Epoch 43/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4070 - recall: 0.7844
# Epoch 00043: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4182 - recall: 0.7747 - val_loss: 0.6119 - val_recall: 0.6634
# Epoch 44/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4648 - recall: 0.7516
# Epoch 00044: val_loss did not improve from 0.54007
# 6/6 [==============================] - 13s 2s/step - loss: 0.4480 - recall: 0.7630 - val_loss: 0.6539 - val_recall: 0.6634
# Epoch 45/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4591 - recall: 0.7638
# Epoch 00045: val_loss did not improve from 0.54007
# 6/6 [==============================] - 11s 2s/step - loss: 0.4641 - recall: 0.7559 - val_loss: 0.5882 - val_recall: 0.6893
# Epoch 46/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4272 - recall: 0.7672
# Epoch 00046: val_loss did not improve from 0.54007
# 6/6 [==============================] - 11s 2s/step - loss: 0.4275 - recall: 0.7710 - val_loss: 0.5986 - val_recall: 0.6505
# Epoch 47/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4078 - recall: 0.7922
# Epoch 00047: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4070 - recall: 0.7956 - val_loss: 0.8555 - val_recall: 0.6440
# Epoch 48/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4176 - recall: 0.7923
# Epoch 00048: val_loss did not improve from 0.54007
# 6/6 [==============================] - 11s 2s/step - loss: 0.4321 - recall: 0.7766 - val_loss: 0.5487 - val_recall: 0.6828
# Epoch 49/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4218 - recall: 0.7750
# Epoch 00049: val_loss did not improve from 0.54007
# 6/6 [==============================] - 13s 2s/step - loss: 0.4323 - recall: 0.7630 - val_loss: 0.6233 - val_recall: 0.6699
# Epoch 50/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4185 - recall: 0.7672
# Epoch 00050: val_loss did not improve from 0.54007
# 6/6 [==============================] - 13s 2s/step - loss: 0.4259 - recall: 0.7708 - val_loss: 0.7699 - val_recall: 0.6375
# Epoch 51/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4174 - recall: 0.7856
# Epoch 00051: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4228 - recall: 0.7821 - val_loss: 0.6518 - val_recall: 0.6667
# Epoch 52/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4351 - recall: 0.7504
# Epoch 00052: val_loss did not improve from 0.54007
# 6/6 [==============================] - 13s 2s/step - loss: 0.4368 - recall: 0.7531 - val_loss: 0.6880 - val_recall: 0.6343
# Epoch 53/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4154 - recall: 0.7906
# Epoch 00053: val_loss did not improve from 0.54007
# 6/6 [==============================] - 11s 2s/step - loss: 0.4178 - recall: 0.7848 - val_loss: 0.6377 - val_recall: 0.6472
# Epoch 54/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4081 - recall: 0.8062
# Epoch 00054: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4058 - recall: 0.8086 - val_loss: 0.7121 - val_recall: 0.6731
# Epoch 55/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.3966 - recall: 0.7906
# Epoch 00055: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4081 - recall: 0.7917 - val_loss: 0.6474 - val_recall: 0.6634
# Epoch 56/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.3940 - recall: 0.7973
# Epoch 00056: val_loss did not improve from 0.54007
# 6/6 [==============================] - 11s 2s/step - loss: 0.4022 - recall: 0.7986 - val_loss: 0.5776 - val_recall: 0.6570
# Epoch 57/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4255 - recall: 0.7875
# Epoch 00057: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4198 - recall: 0.7865 - val_loss: 0.6502 - val_recall: 0.6602
# Epoch 58/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4415 - recall: 0.7588
# Epoch 00058: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4287 - recall: 0.7738 - val_loss: 0.6933 - val_recall: 0.6667
# Epoch 59/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4011 - recall: 0.7772
# Epoch 00059: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.3901 - recall: 0.7821 - val_loss: 0.6027 - val_recall: 0.6278
# Epoch 60/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4523 - recall: 0.7625
# Epoch 00060: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4352 - recall: 0.7721 - val_loss: 0.6481 - val_recall: 0.6634
# Epoch 61/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4343 - recall: 0.7588
# Epoch 00061: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4340 - recall: 0.7531 - val_loss: 0.6930 - val_recall: 0.6472
# Epoch 62/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4111 - recall: 0.7781
# Epoch 00062: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4088 - recall: 0.7760 - val_loss: 0.6514 - val_recall: 0.6537
# Epoch 63/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4538 - recall: 0.7605
# Epoch 00063: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4478 - recall: 0.7628 - val_loss: 0.6515 - val_recall: 0.6570
# Epoch 64/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4470 - recall: 0.7755
# Epoch 00064: val_loss did not improve from 0.54007
# 6/6 [==============================] - 11s 2s/step - loss: 0.4333 - recall: 0.7807 - val_loss: 0.7437 - val_recall: 0.6764
# Epoch 65/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.3822 - recall: 0.7923
# Epoch 00065: val_loss did not improve from 0.54007
# 6/6 [==============================] - 11s 2s/step - loss: 0.4002 - recall: 0.7903 - val_loss: 0.6173 - val_recall: 0.6731
# Epoch 66/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4426 - recall: 0.7516
# Epoch 00066: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4266 - recall: 0.7695 - val_loss: 0.7010 - val_recall: 0.6440
# Epoch 67/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4141 - recall: 0.7859
# Epoch 00067: val_loss did not improve from 0.54007
# 6/6 [==============================] - 13s 2s/step - loss: 0.4052 - recall: 0.7930 - val_loss: 0.7600 - val_recall: 0.6472
# Epoch 68/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.4204 - recall: 0.7828
# Epoch 00068: val_loss did not improve from 0.54007
# 6/6 [==============================] - 12s 2s/step - loss: 0.4232 - recall: 0.7821 - val_loss: 0.7783 - val_recall: 0.6570
# Epoch 69/300
# 5/6 [========================>.....] - ETA: 1s - loss: 0.3916 - recall: 0.7956
# Epoch 00069: val_loss did not improve from 0.54007
# 6/6 [==============================] - 11s 2s/step - loss: 0.3860 - recall: 0.8028 - val_loss: 0.7124 - val_recall: 0.6634
# Epoch 00069: early stopping

# %%
models.save_model(vgg19_calc_benign_or_malignant_1, '../model/vgg19_calc_benign_or_malignant_1_best.h5')

# %%
# History of accuracy and loss
tra_loss_fe = history_fit.history['loss']
tra_acc_fe = history_fit.history['recall']
val_loss_fe = history_fit.history['val_loss']
val_acc_fe = history_fit.history['val_recall']

# Total number of epochs training
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

# Epoch when reached the validation loss minimum
opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

# Loss and accuracy on the validation set
end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

# Loss and accuracy on the test set
opt_vgg19_calc_benign_or_malignant_1 = models.load_model('../model/vgg19_calc_benign_or_malignant_1_best.h5')
test_loss_fe, test_acc_fe = vgg19_calc_benign_or_malignant_1.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_vgg19_calc_benign_or_malignant_1.evaluate(test_images, test_labels, verbose=False)

print("VGG19 Fine Tuning\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid accuracy [end]: %.4f" % end_val_acc_fe)
print("Valid accuracy [opt]: %.4f" % opt_val_acc_fe)
print("Test accuracy [end]:  %.4f" % test_acc_fe)
print("Test accuracy [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# VGG19 Fine Tuning
#
# Epoch [end]: 69
# Epoch [opt]: 39
# Valid accuracy [end]: 0.6634
# Valid accuracy [opt]: 0.6828
# Test accuracy [end]:  0.6840
# Test accuracy [opt]:  0.6840
# Valid loss [end]: 0.7124
# Valid loss [opt]: 0.5401
# Test loss [end]:  0.7329
# Test loss [opt]:  0.7329

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('VGG19 FT accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('VGG19 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();
