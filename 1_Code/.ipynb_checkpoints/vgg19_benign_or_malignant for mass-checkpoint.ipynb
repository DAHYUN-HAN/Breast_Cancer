# %%
import numpy as np
import os
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
def load_training():
    images = np.load(os.path.join('../Data_final_massver', 'X_train.npy'))
    labels = np.load(os.path.join('../Data_final_massver', 'train_mass_labels2_num.npy'))
    return images, labels


def load_testing():
    images = np.load(os.path.join('../Data_final_massver', 'X_test.npy'))
    labels = np.load(os.path.join('../Data_final_massver', 'test_mass_labels2_num.npy'))
    return images, labels

# %%
train_images, train_labels= load_training()
test_images, test_labels= load_testing()

n_train_img = train_images.shape[0]
n_test_img = test_images.shape[0]
print("Train size: %d \t Test size: %d" % (n_train_img, n_test_img))

img_w = train_images.shape[1]
img_h = train_images.shape[2]
print("Image size: %dx%d" % (img_w, img_h))
# Out:
# Train size: 1318 	 Test size: 378
# Image size: 256x256

# %%
train_labels = to_categorical(train_labels)
test_labels_raw = test_labels.copy()
test_labels = to_categorical(test_labels)

# %%
train_images.shape
# Out:
# (1318, 256, 256, 1)

# %%
train_images = train_images.reshape((n_train_img, img_w, img_h, 1))
test_images = test_images.reshape((n_test_img, img_w, img_h, 1))

# %%
train_images = train_images.astype('uint16')/256
test_images = test_images.astype('uint16')/256

train_images = np.repeat(train_images, 3, axis=3)
test_images = np.repeat(test_images, 3, axis=3)

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2,
    rotation_range=180,
    shear_range=15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='reflect'
)

# %%
train_datagen.fit(train_images)

train_generator = train_datagen.flow(train_images, train_labels, batch_size=128, subset='training')
validation_generator = train_datagen.flow(train_images, train_labels, batch_size=128, subset='validation')

preprocess_input(test_images);

# %%
idx = 526

plt.imshow(train_images[idx][:,:,0], cmap='gray')
plt.show()

print("Label: " + str(train_labels[idx]))
# Out:
# Label: [0. 1.]

# %%
def create_vgg19(verbose=False, fc_size=256, output = 4, dropout=None):

    vgg19_base = VGG19(weights='imagenet',
                       include_top=False,
                       input_shape=(256, 256, 3))
    vgg19 = models.Sequential()
    vgg19.add(vgg19_base)

    vgg19.add(layers.Flatten())
    if dropout is not None:
        vgg19.add(layers.Dropout(dropout))
    vgg19.add(layers.Dense(1024, activation='relu'))
    vgg19.add(layers.Dense(fc_size, activation='relu'))
    vgg19.add(layers.Dense(output, activation='softmax'))

    # Freeze the convolutional base
    vgg19_base.trainable = False
    
    if verbose:
        vgg19_base.summary()
        vgg19.summary()

    return vgg19

# %%
vgg19_mass_benign_or_malignant_best = create_vgg19(dropout=0.5, fc_size=128, output = 2)

# %%
vgg19_mass_benign_or_malignant_best.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Model)                (None, 8, 8, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              33555456
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 53,711,298
# Trainable params: 33,686,914
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/vgg19_mass_benign_or_malignant_best.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

vgg19_mass_benign_or_malignant_best.compile(optimizer=optimizers.Adam(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_vgg19_mass_benign_or_malignant_best = vgg19_mass_benign_or_malignant_best.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:From <ipython-input-15-99428f1048be>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 2s - loss: 1.4164 - recall: 0.5012
# Epoch 00001: val_loss improved from inf to 0.66947, saving model to ../model/vgg19_mass_benign_or_malignant_best.h5
# 5/5 [==============================] - 15s 3s/step - loss: 1.4110 - recall: 0.4954 - val_loss: 0.6695 - val_recall: 0.4943
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 1.0490 - recall: 0.4916
# Epoch 00002: val_loss did not improve from 0.66947
# 5/5 [==============================] - 9s 2s/step - loss: 0.9847 - recall: 0.5157 - val_loss: 0.7011 - val_recall: 0.5019
# Epoch 3/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7984 - recall: 0.5254
# Epoch 00003: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7939 - recall: 0.5266 - val_loss: 0.7219 - val_recall: 0.5057
# Epoch 4/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.8019 - recall: 0.5020
# Epoch 00004: val_loss did not improve from 0.66947
# 5/5 [==============================] - 11s 2s/step - loss: 0.8048 - recall: 0.5078 - val_loss: 0.7299 - val_recall: 0.5095
# Epoch 5/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7766 - recall: 0.4988
# Epoch 00005: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7840 - recall: 0.4917 - val_loss: 0.6727 - val_recall: 0.4981
# Epoch 6/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.8009 - recall: 0.4961
# Epoch 00006: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7969 - recall: 0.4922 - val_loss: 0.7587 - val_recall: 0.5057
# Epoch 7/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7842 - recall: 0.4795
# Epoch 00007: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7991 - recall: 0.4567 - val_loss: 0.7265 - val_recall: 0.5095
# Epoch 8/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7315 - recall: 0.4940
# Epoch 00008: val_loss did not improve from 0.66947
# 5/5 [==============================] - 9s 2s/step - loss: 0.7376 - recall: 0.4936 - val_loss: 0.8935 - val_recall: 0.5057
# Epoch 9/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7824 - recall: 0.4883
# Epoch 00009: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7808 - recall: 0.4891 - val_loss: 0.7331 - val_recall: 0.5057
# Epoch 10/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7508 - recall: 0.4883
# Epoch 00010: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7582 - recall: 0.4899 - val_loss: 0.9150 - val_recall: 0.5057
# Epoch 11/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7015 - recall: 0.5469
# Epoch 00011: val_loss did not improve from 0.66947
# 5/5 [==============================] - 11s 2s/step - loss: 0.7177 - recall: 0.5188 - val_loss: 0.7652 - val_recall: 0.5057
# Epoch 12/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7387 - recall: 0.4688
# Epoch 00012: val_loss did not improve from 0.66947
# 5/5 [==============================] - 11s 2s/step - loss: 0.7305 - recall: 0.4859 - val_loss: 0.8548 - val_recall: 0.5057
# Epoch 13/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7303 - recall: 0.5020
# Epoch 00013: val_loss did not improve from 0.66947
# 5/5 [==============================] - 11s 2s/step - loss: 0.7297 - recall: 0.5016 - val_loss: 0.7262 - val_recall: 0.5057
# Epoch 14/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7152 - recall: 0.5039
# Epoch 00014: val_loss did not improve from 0.66947
# 5/5 [==============================] - 11s 2s/step - loss: 0.7143 - recall: 0.5125 - val_loss: 0.7620 - val_recall: 0.5019
# Epoch 15/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7344 - recall: 0.5012
# Epoch 00015: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7338 - recall: 0.4936 - val_loss: 0.6818 - val_recall: 0.4943
# Epoch 16/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7070 - recall: 0.5371
# Epoch 00016: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7092 - recall: 0.5297 - val_loss: 0.7294 - val_recall: 0.5057
# Epoch 17/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7216 - recall: 0.4941
# Epoch 00017: val_loss did not improve from 0.66947
# 5/5 [==============================] - 11s 2s/step - loss: 0.7163 - recall: 0.5047 - val_loss: 0.7036 - val_recall: 0.5057
# Epoch 18/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7184 - recall: 0.5036
# Epoch 00018: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7237 - recall: 0.4936 - val_loss: 0.6960 - val_recall: 0.5057
# Epoch 19/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7210 - recall: 0.5205
# Epoch 00019: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7363 - recall: 0.4954 - val_loss: 0.7556 - val_recall: 0.5057
# Epoch 20/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7145 - recall: 0.5181
# Epoch 00020: val_loss did not improve from 0.66947
# 5/5 [==============================] - 9s 2s/step - loss: 0.7155 - recall: 0.5193 - val_loss: 0.6849 - val_recall: 0.4943
# Epoch 21/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7173 - recall: 0.5036
# Epoch 00021: val_loss did not improve from 0.66947
# 5/5 [==============================] - 9s 2s/step - loss: 0.7201 - recall: 0.4972 - val_loss: 0.7003 - val_recall: 0.5057
# Epoch 22/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7015 - recall: 0.5398
# Epoch 00022: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7040 - recall: 0.5414 - val_loss: 0.7585 - val_recall: 0.5057
# Epoch 23/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7459 - recall: 0.4727
# Epoch 00023: val_loss did not improve from 0.66947
# 5/5 [==============================] - 11s 2s/step - loss: 0.7366 - recall: 0.4906 - val_loss: 0.7100 - val_recall: 0.5057
# Epoch 24/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7286 - recall: 0.4473
# Epoch 00024: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7238 - recall: 0.4530 - val_loss: 0.7022 - val_recall: 0.5057
# Epoch 25/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7111 - recall: 0.5078
# Epoch 00025: val_loss did not improve from 0.66947
# 5/5 [==============================] - 11s 2s/step - loss: 0.7175 - recall: 0.4953 - val_loss: 0.7296 - val_recall: 0.5057
# Epoch 26/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7021 - recall: 0.5020
# Epoch 00026: val_loss did not improve from 0.66947
# 5/5 [==============================] - 9s 2s/step - loss: 0.7043 - recall: 0.4954 - val_loss: 0.6839 - val_recall: 0.4981
# Epoch 27/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7109 - recall: 0.4578
# Epoch 00027: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7077 - recall: 0.4641 - val_loss: 0.7137 - val_recall: 0.5057
# Epoch 28/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.6874 - recall: 0.5446
# Epoch 00028: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.6909 - recall: 0.5378 - val_loss: 0.6919 - val_recall: 0.4943
# Epoch 29/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7001 - recall: 0.5349
# Epoch 00029: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7027 - recall: 0.5267 - val_loss: 0.7209 - val_recall: 0.5057
# Epoch 30/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7176 - recall: 0.4892
# Epoch 00030: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7188 - recall: 0.4899 - val_loss: 0.7184 - val_recall: 0.5057
# Epoch 31/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7179 - recall: 0.4988
# Epoch 00031: val_loss did not improve from 0.66947
# 5/5 [==============================] - 10s 2s/step - loss: 0.7196 - recall: 0.4899 - val_loss: 0.6743 - val_recall: 0.4981
# Epoch 00031: early stopping

# %%
models.save_model(vgg19_mass_benign_or_malignant_best, '../model/vgg19_mass_benign_or_malignant_end.h5')

# %%
tra_loss_fe = history_vgg19_mass_benign_or_malignant_best.history['loss']
tra_acc_fe = history_vgg19_mass_benign_or_malignant_best.history['recall']
val_loss_fe = history_vgg19_mass_benign_or_malignant_best.history['val_loss']
val_acc_fe = history_vgg19_mass_benign_or_malignant_best.history['val_recall']

# %%
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_vgg19_mass_benign_or_malignant = models.load_model('../model/vgg19_mass_benign_or_malignant_best.h5')
test_loss_fe, test_acc_fe = vgg19_mass_benign_or_malignant_best.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_vgg19_mass_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)

# %%
print("VGG19 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid accuracy [end]: %.4f" % end_val_acc_fe)
print("Valid accuracy [opt]: %.4f" % opt_val_acc_fe)
print("Test accuracy [end]:  %.4f" % test_acc_fe)
print("Test accuracy [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# VGG19 benign or malignant
#
# Epoch [end]: 31
# Epoch [opt]: 1
# Valid accuracy [end]: 0.4981
# Valid accuracy [opt]: 0.4943
# Test accuracy [end]:  0.3889
# Test accuracy [opt]:  0.6111
# Valid loss [end]: 0.6743
# Valid loss [opt]: 0.6695
# Test loss [end]:  0.7076
# Test loss [opt]:  0.6737

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('VGG19 FT accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('VGG19 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# #### fine tuning

# %%
vgg19_mass_benign_or_malignant_1 = models.load_model('../model/vgg19_mass_benign_or_malignant_best.h5')

for layer in vgg19_mass_benign_or_malignant_1.get_layer('vgg19').layers:
    if layer.name.startswith('block5_conv4'):
        layer.trainable = True
    else:
        layer.trainable = False

# Recompile the model ()
vgg19_mass_benign_or_malignant_1.compile(optimizer=optimizers.Adam(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])
vgg19_mass_benign_or_malignant_1.summary()
vgg19_mass_benign_or_malignant_1.get_layer('vgg19').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Model)                (None, 8, 8, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              33555456
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 53,711,298
# Trainable params: 36,046,722
# Non-trainable params: 17,664,576
# _________________________________________________________________
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 2,359,808
# Non-trainable params: 17,664,576
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint(
        '../model/vgg19_mass_benign_or_malignant_1_best.h5',
        monitor='val_loss',
        mode='min',
        verbose=1, 
     
    save_best_only=True, 
        save_freq='epoch')

# %%
history_fit = vgg19_mass_benign_or_malignant_1.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[early_stop, checkpoint],
        shuffle=True,
        verbose=1,
        initial_epoch=0)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5898 - recall: 0.6843
# Epoch 00001: val_loss improved from inf to 0.61870, saving model to ../model/vgg19_mass_benign_or_malignant_1_best.h5
# 5/5 [==============================] - 10s 2s/step - loss: 0.6107 - recall: 0.6593 - val_loss: 0.6187 - val_recall: 0.6274
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5781 - recall: 0.6934
# Epoch 00002: val_loss did not improve from 0.61870
# 5/5 [==============================] - 10s 2s/step - loss: 0.5519 - recall: 0.7017 - val_loss: 0.6577 - val_recall: 0.6464
# Epoch 3/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5678 - recall: 0.7229
# Epoch 00003: val_loss improved from 0.61870 to 0.54911, saving model to ../model/vgg19_mass_benign_or_malignant_1_best.h5
# 5/5 [==============================] - 10s 2s/step - loss: 0.5849 - recall: 0.6998 - val_loss: 0.5491 - val_recall: 0.6654
# Epoch 4/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5771 - recall: 0.6723
# Epoch 00004: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.5774 - recall: 0.6796 - val_loss: 0.7286 - val_recall: 0.6008
# Epoch 5/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.6351 - recall: 0.6816
# Epoch 00005: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.6394 - recall: 0.6703 - val_loss: 0.6089 - val_recall: 0.6616
# Epoch 6/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.6180 - recall: 0.6484
# Epoch 00006: val_loss did not improve from 0.54911
# 5/5 [==============================] - 11s 2s/step - loss: 0.6142 - recall: 0.6562 - val_loss: 0.6346 - val_recall: 0.6654
# Epoch 7/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5734 - recall: 0.6953
# Epoch 00007: val_loss did not improve from 0.54911
# 5/5 [==============================] - 11s 2s/step - loss: 0.5574 - recall: 0.7047 - val_loss: 0.6195 - val_recall: 0.6578
# Epoch 8/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5910 - recall: 0.6973
# Epoch 00008: val_loss did not improve from 0.54911
# 5/5 [==============================] - 11s 2s/step - loss: 0.5799 - recall: 0.7047 - val_loss: 0.5660 - val_recall: 0.6882
# Epoch 9/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5166 - recall: 0.7398
# Epoch 00009: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.5443 - recall: 0.7164 - val_loss: 0.6325 - val_recall: 0.6312
# Epoch 10/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5939 - recall: 0.7031
# Epoch 00010: val_loss did not improve from 0.54911
# 5/5 [==============================] - 11s 2s/step - loss: 0.6029 - recall: 0.6969 - val_loss: 0.6282 - val_recall: 0.6236
# Epoch 11/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.6569 - recall: 0.6797
# Epoch 00011: val_loss did not improve from 0.54911
# 5/5 [==============================] - 11s 2s/step - loss: 0.6454 - recall: 0.6844 - val_loss: 0.6521 - val_recall: 0.6426
# Epoch 12/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5882 - recall: 0.6836
# Epoch 00012: val_loss did not improve from 0.54911
# 5/5 [==============================] - 11s 2s/step - loss: 0.5952 - recall: 0.6656 - val_loss: 0.6143 - val_recall: 0.6996
# Epoch 13/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5953 - recall: 0.6934
# Epoch 00013: val_loss did not improve from 0.54911
# 5/5 [==============================] - 11s 2s/step - loss: 0.5882 - recall: 0.6906 - val_loss: 0.6029 - val_recall: 0.6502
# Epoch 14/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5387 - recall: 0.7181
# Epoch 00014: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.5496 - recall: 0.7145 - val_loss: 0.5780 - val_recall: 0.6882
# Epoch 15/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.6125 - recall: 0.6504
# Epoch 00015: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.6010 - recall: 0.6609 - val_loss: 0.6021 - val_recall: 0.6692
# Epoch 16/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5871 - recall: 0.6940
# Epoch 00016: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.5700 - recall: 0.7017 - val_loss: 0.6022 - val_recall: 0.6502
# Epoch 17/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5603 - recall: 0.7188
# Epoch 00017: val_loss did not improve from 0.54911
# 5/5 [==============================] - 11s 2s/step - loss: 0.5500 - recall: 0.7172 - val_loss: 0.6991 - val_recall: 0.6160
# Epoch 18/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5995 - recall: 0.6771
# Epoch 00018: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.6117 - recall: 0.6703 - val_loss: 0.6296 - val_recall: 0.6388
# Epoch 19/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5534 - recall: 0.7246
# Epoch 00019: val_loss did not improve from 0.54911
# 5/5 [==============================] - 9s 2s/step - loss: 0.5608 - recall: 0.7256 - val_loss: 0.6725 - val_recall: 0.6388
# Epoch 20/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5607 - recall: 0.7090
# Epoch 00020: val_loss did not improve from 0.54911
# 5/5 [==============================] - 11s 2s/step - loss: 0.5802 - recall: 0.7031 - val_loss: 0.6179 - val_recall: 0.6730
# Epoch 21/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5832 - recall: 0.6758
# Epoch 00021: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.5552 - recall: 0.6832 - val_loss: 0.6111 - val_recall: 0.6806
# Epoch 22/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5371 - recall: 0.6895
# Epoch 00022: val_loss did not improve from 0.54911
# 5/5 [==============================] - 11s 2s/step - loss: 0.5568 - recall: 0.6797 - val_loss: 0.7511 - val_recall: 0.6578
# Epoch 23/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5221 - recall: 0.7325
# Epoch 00023: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.5679 - recall: 0.7035 - val_loss: 0.6163 - val_recall: 0.6578
# Epoch 24/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5385 - recall: 0.6964
# Epoch 00024: val_loss did not improve from 0.54911
# 5/5 [==============================] - 9s 2s/step - loss: 0.5459 - recall: 0.7017 - val_loss: 0.5796 - val_recall: 0.6426
# Epoch 25/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5740 - recall: 0.6914
# Epoch 00025: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.5588 - recall: 0.7016 - val_loss: 0.5881 - val_recall: 0.6692
# Epoch 26/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5699 - recall: 0.6914
# Epoch 00026: val_loss did not improve from 0.54911
# 5/5 [==============================] - 11s 2s/step - loss: 0.5558 - recall: 0.7031 - val_loss: 0.6405 - val_recall: 0.6464
# Epoch 27/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5231 - recall: 0.7285
# Epoch 00027: val_loss did not improve from 0.54911
# 5/5 [==============================] - 11s 2s/step - loss: 0.5315 - recall: 0.7266 - val_loss: 0.6980 - val_recall: 0.6084
# Epoch 28/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5101 - recall: 0.7470
# Epoch 00028: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.5233 - recall: 0.7440 - val_loss: 0.6425 - val_recall: 0.6350
# Epoch 29/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5434 - recall: 0.7133
# Epoch 00029: val_loss did not improve from 0.54911
# 5/5 [==============================] - 9s 2s/step - loss: 0.5640 - recall: 0.7127 - val_loss: 0.7278 - val_recall: 0.6426
# Epoch 30/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5525 - recall: 0.7036
# Epoch 00030: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.5625 - recall: 0.7035 - val_loss: 0.6111 - val_recall: 0.6426
# Epoch 31/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5192 - recall: 0.7168
# Epoch 00031: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.5463 - recall: 0.7047 - val_loss: 0.5868 - val_recall: 0.6730
# Epoch 32/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.4866 - recall: 0.7446
# Epoch 00032: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.5104 - recall: 0.7330 - val_loss: 0.5949 - val_recall: 0.6730
# Epoch 33/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.5159 - recall: 0.7108
# Epoch 00033: val_loss did not improve from 0.54911
# 5/5 [==============================] - 10s 2s/step - loss: 0.5129 - recall: 0.7164 - val_loss: 0.5750 - val_recall: 0.6464
# Epoch 00033: early stopping

# %%
models.save_model(vgg19_mass_benign_or_malignant_1, '../model/vgg19_mass_benign_or_malignant_1_end.h5')

# %%
# History of accuracy and loss
tra_loss_fe = history_fit.history['loss']
tra_acc_fe = history_fit.history['recall']
val_loss_fe = history_fit.history['val_loss']
val_acc_fe = history_fit.history['val_recall']

# Total number of epochs training
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

# Epoch when reached the validation loss minimum
opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

# Loss and accuracy on the validation set
end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

# Loss and accuracy on the test set
opt_vgg19_mass_benign_or_malignant_1 = models.load_model('../model/vgg19_mass_benign_or_malignant_1_best.h5')
test_loss_fe, test_acc_fe = vgg19_mass_benign_or_malignant_1.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_vgg19_mass_benign_or_malignant_1.evaluate(test_images, test_labels, verbose=False)

print("VGG19 Fine Tuning\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid accuracy [end]: %.4f" % end_val_acc_fe)
print("Valid accuracy [opt]: %.4f" % opt_val_acc_fe)
print("Test accuracy [end]:  %.4f" % test_acc_fe)
print("Test accuracy [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# VGG19 Fine Tuning
#
# Epoch [end]: 38
# Epoch [opt]: 8
# Valid accuracy [end]: 0.6312
# Valid accuracy [opt]: 0.6388
# Test accuracy [end]:  0.5556
# Test accuracy [opt]:  0.5423
# Valid loss [end]: 0.6704
# Valid loss [opt]: 0.5725
# Test loss [end]:  0.8120
# Test loss [opt]:  0.8223

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('VGG19 FT accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('VGG19 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();
