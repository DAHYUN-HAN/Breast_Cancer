# %%
import numpy as np
import os
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
def load_training():
    images = np.load(os.path.join('../Data_final_calcver', 'X_train.npy'))
    labels = np.load(os.path.join('../Data_final_calcver', 'train_calc_labels2_num.npy'))
    #FN = np.load(os.path.join('../Data_final_calcver', 'train_calc_FN.npy'))
    return images, labels#, FN


def load_testing():
    images = np.load(os.path.join('../Data_final_calcver', 'X_test.npy'))
    labels = np.load(os.path.join('../Data_final_calcver', 'test_calc_labels2_num.npy'))
    #FN = np.load(os.path.join('../Data_final_calcver', 'test_calc_FN.npy'))
    return images, labels#, FN

# %%
train_images, train_labels= load_training()
test_images, test_labels= load_testing()

n_train_img = train_images.shape[0]
n_test_img = test_images.shape[0]
print("Train size: %d \t Test size: %d" % (n_train_img, n_test_img))

img_w = train_images.shape[1]
img_h = train_images.shape[2]
print("Image size: %dx%d" % (img_w, img_h))
# Out:
# Train size: 1535 	 Test size: 337
# Image size: 256x256

# %%
idx = 10

plt.imshow(test_images[idx][:,:,0], cmap='gray')
plt.show()

print("Label: " + str(test_labels[idx]))
#print("FN: " + str(test_FN[idx]))
# Out:
# Label: 0

# %%
train_labels = to_categorical(train_labels)
test_labels_raw = test_labels.copy()
test_labels = to_categorical(test_labels)

# %%
train_images.shape
# Out:
# (1535, 256, 256, 1)

# %%
train_images = train_images.reshape((n_train_img, img_w, img_h, 1))
test_images = test_images.reshape((n_test_img, img_w, img_h, 1))

# %%
train_images = train_images.astype('uint16')/256
test_images = test_images.astype('uint16')/256

train_images = np.repeat(train_images, 3, axis=3)
test_images = np.repeat(test_images, 3, axis=3)

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2,
    rotation_range=180,
    shear_range=15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='reflect'
)

# %%
train_datagen.fit(train_images)

train_generator = train_datagen.flow(train_images, train_labels, batch_size=128, subset='training')
validation_generator = train_datagen.flow(train_images, train_labels, batch_size=128, subset='validation')

preprocess_input(test_images);

# %%
def create_inceptionv3(verbose=False, fc_size=256, output = 2, dropout=None):
    
    inceptionv3_base = InceptionV3(weights='imagenet',
                       include_top=False,
                       input_shape=(256, 256, 3))
    inceptionv3 = models.Sequential()
    inceptionv3.add(inceptionv3_base)

    inceptionv3.add(layers.Flatten())
    if dropout is not None:
        inceptionv3.add(layers.Dropout(dropout))
    inceptionv3.add(layers.Dense(2048, activation='relu'))
    inceptionv3.add(layers.Dense(1048, activation='relu'))
    inceptionv3.add(layers.Dense(fc_size, activation='relu'))
    inceptionv3.add(layers.Dense(output, activation='softmax'))

    # Freeze the convolutional base
    inceptionv3_base.trainable = False
    
    if verbose:
        inceptionv3_base.summary()
        inceptionv3.summary()

    return inceptionv3

# %%
inceptionv3 = InceptionV3(weights='imagenet',
                       include_top=False,
                       input_shape=(256, 256, 3))
for layer in inceptionv3.layers:
    layer.trainable = False
inceptionv3_maxpool = inceptionv3.get_layer('mixed10').output
FeatureFlatten = Flatten()(inceptionv3_maxpool)
dense1 = Dense(1024, name = 'dense1', activation = 'relu')(FeatureFlatten)
dense2 = Dense(128, name = 'dense2', activation = 'relu')(dense1)
predictions = Dense(2, name = 'predictions', activation = 'softmax')(dense2)

new_inceptionv3 = Model(inputs = inceptionv3.input, outputs = predictions)
new_inceptionv3.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 127, 127, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 127, 127, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 127, 127, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 125, 125, 32) 9216        activation[0][0]
# ...

# %%
inceptionv3_calc_benign_or_malignant_best_Adam = new_inceptionv3

# %%
inceptionv3_calc_benign_or_malignant_best_RMSprop = new_inceptionv3

# %% [markdown]
# ### Adam

# %%
earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/inceptionv3_calc_benign_or_malignant_best_Adam.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

inceptionv3_calc_benign_or_malignant_best_Adam.compile(optimizer=optimizers.Adam(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_inceptionv3_calc_benign_or_malignant_best_Adam = inceptionv3_calc_benign_or_malignant_best_Adam.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:From <ipython-input-16-a2fcdd82e25e>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 1s - loss: 3.3509 - recall: 0.4883
# Epoch 00001: val_loss improved from inf to 15.27601, saving model to ../model/inceptionv3_calc_benign_or_malignant_best_Adam.h5
# 5/5 [==============================] - 16s 3s/step - loss: 2.8769 - recall: 0.5203 - val_loss: 15.2760 - val_recall: 0.6417
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.8656 - recall: 0.5587
# ...

# %%
models.save_model(inceptionv3_calc_benign_or_malignant_best_Adam, '../model/inceptionv3_calc_benign_or_malignant_end_Adam.h5')

# %%
tra_loss_fe = history_inceptionv3_calc_benign_or_malignant_best_Adam.history['loss']
tra_acc_fe = history_inceptionv3_calc_benign_or_malignant_best_Adam.history['recall']
val_loss_fe = history_inceptionv3_calc_benign_or_malignant_best_Adam.history['val_loss']
val_acc_fe = history_inceptionv3_calc_benign_or_malignant_best_Adam.history['val_recall']

# %%
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_inceptionv3_calc_benign_or_malignant = models.load_model('../model/inceptionv3_calc_benign_or_malignant_best_Adam.h5')
test_loss_fe, test_acc_fe = inceptionv3_calc_benign_or_malignant_best_Adam.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_inceptionv3_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)

# %%
print("inceptionv3 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# inceptionv3 benign or malignant
#
# Epoch [end]: 33
# Epoch [opt]: 3
# Valid recall [end]: 0.6417
# Valid recall [opt]: 0.5375
# Test recall [end]:  0.6409
# Test recall [opt]:  0.5252
# Valid loss [end]: 12.9733
# Valid loss [opt]: 2.1907
# Test loss [end]:  10.4914
# Test loss [opt]:  1.9827

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# ### SGD

# %%
inceptionv3_calc_benign_or_malignant_best_SGD = create_inceptionv3(dropout=0.5, fc_size=128, output = 2)

earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/inceptionv3_calc_benign_or_malignant_best_SGD.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

inceptionv3_calc_benign_or_malignant_best_SGD.compile(optimizer=optimizers.SGD(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_inceptionv3_calc_benign_or_malignant_best_SGD = inceptionv3_calc_benign_or_malignant_best_SGD.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 1s - loss: 1.0281 - recall: 0.3984
# Epoch 00001: val_loss improved from inf to 5.14853, saving model to ../model/inceptionv3_calc_benign_or_malignant_best_SGD.h5
# 5/5 [==============================] - 14s 3s/step - loss: 1.0133 - recall: 0.4000 - val_loss: 5.1485 - val_recall: 0.3811
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.8805 - recall: 0.4512
# Epoch 00002: val_loss improved from 5.14853 to 4.02199, saving model to ../model/inceptionv3_calc_benign_or_malignant_best_SGD.h5
# 5/5 [==============================] - 11s 2s/step - loss: 0.8818 - recall: 0.4500 - val_loss: 4.0220 - val_recall: 0.4104
# Epoch 3/300
# ...

# %%
models.save_model(inceptionv3_calc_benign_or_malignant_best_SGD, '../model/inceptionv3_calc_benign_or_malignant_end_SGD.h5')

# %%
tra_loss_fe = history_inceptionv3_calc_benign_or_malignant_best_SGD.history['loss']
tra_acc_fe = history_inceptionv3_calc_benign_or_malignant_best_SGD.history['recall']
val_loss_fe = history_inceptionv3_calc_benign_or_malignant_best_SGD.history['val_loss']
val_acc_fe = history_inceptionv3_calc_benign_or_malignant_best_SGD.history['val_recall']

epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_inceptionv3_calc_benign_or_malignant = models.load_model('../model/inceptionv3_calc_benign_or_malignant_best_SGD.h5')
test_loss_fe, test_acc_fe = inceptionv3_calc_benign_or_malignant_best_SGD.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_inceptionv3_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)

print("inceptionv3 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# inceptionv3 benign or malignant
#
# Epoch [end]: 37
# Epoch [opt]: 7
# Valid recall [end]: 0.6124
# Valid recall [opt]: 0.5277
# Test recall [end]:  0.5697
# Test recall [opt]:  0.5401
# Valid loss [end]: 2.7212
# Valid loss [opt]: 2.4799
# Test loss [end]:  2.4009
# Test loss [opt]:  2.0367

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 recall')
plt.ylabel('recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# ### RMSprop

# %%
earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/inceptionv3_calc_benign_or_malignant_best_RMSprop.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

inceptionv3_calc_benign_or_malignant_best_RMSprop.compile(optimizer=optimizers.RMSprop(learning_rate=0.001),
                                            loss='sparse_categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_inceptionv3_calc_benign_or_malignant_best_RMSprop = inceptionv3_calc_benign_or_malignant_best_RMSprop.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 1/5 [=====>........................] - ETA: 14sWARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-35-e2cb3a4c177a> in <module>
#       8         shuffle=True,
#       9         verbose=1,
# ---> 10         initial_epoch=0
#      11 )
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\util\deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
# ...

# %%
models.save_model(inceptionv3_calc_benign_or_malignant_best_RMSprop, '../model/inceptionv3_calc_benign_or_malignant_end_RMSprop.h5')

# %%
tra_loss_fe = history_inceptionv3_calc_benign_or_malignant_best_RMSprop.history['loss']
tra_acc_fe = history_inceptionv3_calc_benign_or_malignant_best_RMSprop.history['recall']
val_loss_fe = history_inceptionv3_calc_benign_or_malignant_best_RMSprop.history['val_loss']
val_acc_fe = history_inceptionv3_calc_benign_or_malignant_best_RMSprop.history['val_recall']

epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_inceptionv3_calc_benign_or_malignant = models.load_model('../model/inceptionv3_calc_benign_or_malignant_best_RMSprop.h5')
test_loss_fe, test_acc_fe = inceptionv3_calc_benign_or_malignant_best_RMSprop.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_inceptionv3_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)

print("inceptionv3 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# ### Adadelta

# %%
inceptionv3_calc_benign_or_malignant_best_Adadelta = create_inceptionv3(dropout=0.5, fc_size=128, output = 2)

earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/inceptionv3_calc_benign_or_malignant_best_Adadelta.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

inceptionv3_calc_benign_or_malignant_best_Adadelta.compile(optimizer=optimizers.Adadelta(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_inceptionv3_calc_benign_or_malignant_best_Adadelta = inceptionv3_calc_benign_or_malignant_best_Adadelta.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:From <ipython-input-14-a11772cfbc57>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7513 - recall: 0.6113
# Epoch 00001: val_loss improved from inf to 6.04510, saving model to ../model/inceptionv3_calc_benign_or_malignant_best_Adadelta.h5
# 5/5 [==============================] - 17s 3s/step - loss: 0.7502 - recall: 0.6141 - val_loss: 6.0451 - val_recall: 0.6417
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7755 - recall: 0.6133
# Epoch 00002: val_loss did not improve from 6.04510
# ...

# %%
models.save_model(inceptionv3_calc_benign_or_malignant_best_Adadelta, '../model/inceptionv3_calc_benign_or_malignant_end_Adadelta.h5')

# %%
tra_loss_fe = history_inceptionv3_calc_benign_or_malignant_best_Adadelta.history['loss']
tra_acc_fe = history_inceptionv3_calc_benign_or_malignant_best_Adadelta.history['recall']
val_loss_fe = history_inceptionv3_calc_benign_or_malignant_best_Adadelta.history['val_loss']
val_acc_fe = history_inceptionv3_calc_benign_or_malignant_best_Adadelta.history['val_recall']

epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_inceptionv3_calc_benign_or_malignant = models.load_model('../model/inceptionv3_calc_benign_or_malignant_best_Adadelta.h5')
test_loss_fe, test_acc_fe = inceptionv3_calc_benign_or_malignant_best_Adadelta.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_inceptionv3_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)

print("inceptionv3 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# inceptionv3 benign or malignant
#
# Epoch [end]: 69
# Epoch [opt]: 39
# Valid recall [end]: 0.6026
# Valid recall [opt]: 0.6515
# Test recall [end]:  0.5816
# Test recall [opt]:  0.5905
# Valid loss [end]: 6.1397
# Valid loss [opt]: 4.4460
# Test loss [end]:  4.1641
# Test loss [opt]:  4.2874

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# ### Adagrad

# %%
inceptionv3_calc_benign_or_malignant_best_Adagrad = create_inceptionv3(dropout=0.5, fc_size=128, output = 2)

earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/inceptionv3_calc_benign_or_malignant_best_Adagrad.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

inceptionv3_calc_benign_or_malignant_best_Adagrad.compile(optimizer=optimizers.Adagrad(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_inceptionv3_calc_benign_or_malignant_best_Adagrad = inceptionv3_calc_benign_or_malignant_best_Adagrad.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:From <ipython-input-17-c22e7a4385f3>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 2s - loss: 0.7486 - recall: 0.5391
# Epoch 00001: val_loss improved from inf to 3.93332, saving model to ../model/inceptionv3_calc_benign_or_malignant_best_Adagrad.h5
# 5/5 [==============================] - 16s 3s/step - loss: 0.7646 - recall: 0.5344 - val_loss: 3.9333 - val_recall: 0.5505
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7559 - recall: 0.5527
# Epoch 00002: val_loss did not improve from 3.93332
# ...

# %%
models.save_model(inceptionv3_calc_benign_or_malignant_best_Adagrad, '../model/inceptionv3_calc_benign_or_malignant_end_Adagrad.h5')

# %%
tra_loss_fe = history_inceptionv3_calc_benign_or_malignant_best_Adagrad.history['loss']
tra_acc_fe = history_inceptionv3_calc_benign_or_malignant_best_Adagrad.history['recall']
val_loss_fe = history_inceptionv3_calc_benign_or_malignant_best_Adagrad.history['val_loss']
val_acc_fe = history_inceptionv3_calc_benign_or_malignant_best_Adagrad.history['val_recall']

epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_inceptionv3_calc_benign_or_malignant = models.load_model('../model/inceptionv3_calc_benign_or_malignant_best_Adagrad.h5')
test_loss_fe, test_acc_fe = inceptionv3_calc_benign_or_malignant_best_Adagrad.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_inceptionv3_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)

print("inceptionv3 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# inceptionv3 benign or malignant
#
# Epoch [end]: 36
# Epoch [opt]: 6
# Valid recall [end]: 0.5831
# Valid recall [opt]: 0.5896
# Test recall [end]:  0.5846
# Test recall [opt]:  0.5846
# Valid loss [end]: 3.8151
# Valid loss [opt]: 3.5652
# Test loss [end]:  3.9709
# Test loss [opt]:  4.2084

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# ### Adamax

# %%
inceptionv3_calc_benign_or_malignant_best_Adamax = create_inceptionv3(dropout=0.5, fc_size=128, output = 2)

earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/inceptionv3_calc_benign_or_malignant_best_Adamax.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

inceptionv3_calc_benign_or_malignant_best_Adamax.compile(optimizer=optimizers.Adamax(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_inceptionv3_calc_benign_or_malignant_best_Adamax = inceptionv3_calc_benign_or_malignant_best_Adamax.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 1s - loss: 1.6206 - recall: 0.5664
# Epoch 00001: val_loss improved from inf to 14.25491, saving model to ../model/inceptionv3_calc_benign_or_malignant_best_Adamax.h5
# 5/5 [==============================] - 15s 3s/step - loss: 1.4299 - recall: 0.5797 - val_loss: 14.2549 - val_recall: 0.6417
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7420 - recall: 0.6094
# Epoch 00002: val_loss improved from 14.25491 to 3.82845, saving model to ../model/inceptionv3_calc_benign_or_malignant_best_Adamax.h5
# 5/5 [==============================] - 13s 3s/step - loss: 0.7301 - recall: 0.5953 - val_loss: 3.8284 - val_recall: 0.6384
# Epoch 3/300
# ...

# %%
models.save_model(inceptionv3_calc_benign_or_malignant_best_Adamax, '../model/inceptionv3_calc_benign_or_malignant_end_Adamax.h5')

# %%
tra_loss_fe = history_inceptionv3_calc_benign_or_malignant_best_Adamax.history['loss']
tra_acc_fe = history_inceptionv3_calc_benign_or_malignant_best_Adamax.history['recall']
val_loss_fe = history_inceptionv3_calc_benign_or_malignant_best_Adamax.history['val_loss']
val_acc_fe = history_inceptionv3_calc_benign_or_malignant_best_Adamax.history['val_recall']

epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]





print("inceptionv3 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
# Out:
# inceptionv3 benign or malignant
#
# Epoch [end]: 50
# Epoch [opt]: 20
# Valid recall [end]: 0.6417
# Valid recall [opt]: 0.5668
# Valid loss [end]: 12.1062
# Valid loss [opt]: 2.2757

# %%
opt_inceptionv3_calc_benign_or_malignant = models.load_model('../model/inceptionv3_calc_benign_or_malignant_best_Adamax.h5')
inceptionv3_calc_benign_or_malignant_best_Adamax = models.load_model('../model/inceptionv3_calc_benign_or_malignant_end_Adamax.h5')
test_loss_fe, test_acc_fe = inceptionv3_calc_benign_or_malignant_best_Adamax.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_inceptionv3_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
# Out:
# Test recall [opt]:  0.5608
# Test recall [end]:  0.6380
# Test loss [opt]:  2.6288
# Test loss [end]:  9.2967

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# ## Nadam

# %%
inceptionv3_calc_benign_or_malignant_best_Nadam = create_inceptionv3(dropout=0.5, fc_size=128, output = 2)

earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint('../model/inceptionv3_calc_benign_or_malignant_best_Nadam.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

inceptionv3_calc_benign_or_malignant_best_Nadam.compile(optimizer=optimizers.Nadam(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

# %%
# Train
history_inceptionv3_calc_benign_or_malignant_best_Nadam = inceptionv3_calc_benign_or_malignant_best_Nadam.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:From <ipython-input-15-54a6372c1f8e>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate for 3 steps
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 2s - loss: 2.1785 - recall: 0.5239
# Epoch 00001: val_loss improved from inf to 24.11765, saving model to ../model/inceptionv3_calc_benign_or_malignant_best_Nadam.h5
# 5/5 [==============================] - 18s 4s/step - loss: 2.0850 - recall: 0.5391 - val_loss: 24.1176 - val_recall: 0.3583
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 1s - loss: 0.7828 - recall: 0.5645
# ...

# %%
models.save_model(inceptionv3_calc_benign_or_malignant_best_Nadam, '../model/inceptionv3_calc_benign_or_malignant_end_Nadam.h5')

# %%
tra_loss_fe = history_inceptionv3_calc_benign_or_malignant_best_Nadam.history['loss']
tra_acc_fe = history_inceptionv3_calc_benign_or_malignant_best_Nadam.history['recall']
val_loss_fe = history_inceptionv3_calc_benign_or_malignant_best_Nadam.history['val_loss']
val_acc_fe = history_inceptionv3_calc_benign_or_malignant_best_Nadam.history['val_recall']

epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

opt_inceptionv3_calc_benign_or_malignant = models.load_model('../model/inceptionv3_calc_benign_or_malignant_best_Nadam.h5')
test_loss_fe, test_acc_fe = inceptionv3_calc_benign_or_malignant_best_Nadam.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_inceptionv3_calc_benign_or_malignant.evaluate(test_images, test_labels, verbose=False)

print("inceptionv3 benign or malignant\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# inceptionv3 benign or malignant
#
# Epoch [end]: 43
# Epoch [opt]: 13
# Valid recall [end]: 0.6417
# Valid recall [opt]: 0.6417
# Test recall [end]:  0.6380
# Test recall [opt]:  0.6380
# Valid loss [end]: 41.3434
# Valid loss [opt]: 7.4284
# Test loss [end]:  38.0264
# Test loss [opt]:  6.6935

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %% [markdown]
# #### fine tuning

# %%
inceptionv3_calc_benign_or_malignant_fine_RMSprop = models.load_model('../model/inceptionv3_calc_benign_or_malignant_best_RMSprop.h5')

for layer in inceptionv3_calc_benign_or_malignant_fine_RMSprop.layers:
    if layer.name.startswith('block5_conv3'):
        layer.trainable = True
    else:
        layer.trainable = False

# Recompile the model ()
inceptionv3_calc_benign_or_malignant_fine_RMSprop.compile(optimizer=optimizers.RMSprop(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

inceptionv3_calc_benign_or_malignant_fine_RMSprop.summary()

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint(
        '../model/inceptionv3_calc_benign_or_malignant_fine_RMSprop_best.h5',
        monitor='val_loss',
        mode='min',
        verbose=1, 
     
    save_best_only=True, 
        save_freq='epoch')

# %%
history_fit = inceptionv3_calc_benign_or_malignant_fine_RMSprop.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[early_stop, checkpoint],
        shuffle=True,
        verbose=1,
        initial_epoch=0)

# %%
models.save_model(inceptionv3_calc_benign_or_malignant_fine_RMSprop, '../model/inceptionv3_calc_benign_or_malignant_fine_RMSprop_end.h5')

# %%
# History of accuracy and loss
tra_loss_fe = history_fit.history['loss']
tra_acc_fe = history_fit.history['recall']
val_loss_fe = history_fit.history['val_loss']
val_acc_fe = history_fit.history['val_recall']

# Total number of epochs training
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

# Epoch when reached the validation loss minimum
opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

# Loss and accuracy on the validation set
end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

# Loss and accuracy on the test set
opt_inceptionv3_calc_benign_or_malignant_fine_RMSprop = models.load_model('../model/inceptionv3_calc_benign_or_malignant_fine_RMSprop_best.h5')
test_loss_fe, test_acc_fe = inceptionv3_calc_benign_or_malignant_fine_RMSprop.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_inceptionv3_calc_benign_or_malignant_fine_RMSprop.evaluate(test_images, test_labels, verbose=False)

print("inceptionv3 Fine Tuning\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %%
inceptionv3_calc_benign_or_malignant_fine_RMSprop2 = models.load_model('../model/inceptionv3_calc_benign_or_malignant_fine_RMSprop_best.h5')

for layer in inceptionv3_calc_benign_or_malignant_fine_RMSprop2.layers:
    if layer.name in ('block5_conv2', 'block5_conv3'):
        layer.trainable = True
    else:
        layer.trainable = False

# Recompile the model ()
inceptionv3_calc_benign_or_malignant_fine_RMSprop2.compile(optimizer=optimizers.RMSprop(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

inceptionv3_calc_benign_or_malignant_fine_RMSprop2.summary()

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint(
        '../model/inceptionv3_calc_benign_or_malignant_fine_RMSprop_best2.h5',
        monitor='val_loss',
        mode='min',
        verbose=1, 
     
    save_best_only=True, 
        save_freq='epoch')

# %%
history_fit = inceptionv3_calc_benign_or_malignant_fine_RMSprop2.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[early_stop, checkpoint],
        shuffle=True,
        verbose=1,
        initial_epoch=0)

# %%
models.save_model(inceptionv3_calc_benign_or_malignant_fine_RMSprop2, '../model/inceptionv3_calc_benign_or_malignant_fine_RMSprop_end2.h5')

# %%
# History of accuracy and loss
tra_loss_fe = history_fit.history['loss']
tra_acc_fe = history_fit.history['recall']
val_loss_fe = history_fit.history['val_loss']
val_acc_fe = history_fit.history['val_recall']

# Total number of epochs training
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

# Epoch when reached the validation loss minimum
opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

# Loss and accuracy on the validation set
end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

# Loss and accuracy on the test set
opt_inceptionv3_calc_benign_or_malignant_fine_RMSprop2 = models.load_model('../model/inceptionv3_calc_benign_or_malignant_fine_RMSprop_best2.h5')
test_loss_fe, test_acc_fe = inceptionv3_calc_benign_or_malignant_fine_RMSprop2.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_inceptionv3_calc_benign_or_malignant_fine_RMSprop2.evaluate(test_images, test_labels, verbose=False)

print("inceptionv3 Fine Tuning\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %%
inceptionv3_calc_benign_or_malignant_fine_RMSprop3 = models.load_model('../model/inceptionv3_calc_benign_or_malignant_fine_RMSprop_best2.h5')

for layer in inceptionv3_calc_benign_or_malignant_fine_RMSprop3.layers:
    if layer.name in ('block5_conv1', 'block5_conv2', 'block5_conv3'):
        layer.trainable = True
    else:
        layer.trainable = False

# Recompile the model ()
inceptionv3_calc_benign_or_malignant_fine_RMSprop3.compile(optimizer=optimizers.RMSprop(learning_rate=0.0001),
                                            loss='categorical_crossentropy',
                                            metrics=[tf.keras.metrics.Recall(name='recall')])

inceptionv3_calc_benign_or_malignant_fine_RMSprop3.summary()

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

checkpoint = ModelCheckpoint(
        '../model/inceptionv3_calc_benign_or_malignant_fine_RMSprop_best3.h5',
        monitor='val_loss',
        mode='min',
        verbose=1, 
     
    save_best_only=True, 
        save_freq='epoch')

# %%
history_fit = inceptionv3_calc_benign_or_malignant_fine_RMSprop3.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=300,
        validation_data=validation_generator,
        callbacks=[early_stop, checkpoint],
        shuffle=True,
        verbose=1,
        initial_epoch=0)

# %%
models.save_model(inceptionv3_calc_benign_or_malignant_fine_RMSprop3, '../model/inceptionv3_calc_benign_or_malignant_fine_RMSprop_end3.h5')

# %%
# History of accuracy and loss
tra_loss_fe = history_fit.history['loss']
tra_acc_fe = history_fit.history['recall']
val_loss_fe = history_fit.history['val_loss']
val_acc_fe = history_fit.history['val_recall']

# Total number of epochs training
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

# Epoch when reached the validation loss minimum
opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

# Loss and accuracy on the validation set
end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

# Loss and accuracy on the test set
opt_inceptionv3_calc_benign_or_malignant_fine_RMSprop3 = models.load_model('../model/inceptionv3_calc_benign_or_malignant_fine_RMSprop_best3.h5')
test_loss_fe, test_acc_fe = inceptionv3_calc_benign_or_malignant_fine_RMSprop3.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_inceptionv3_calc_benign_or_malignant_fine_RMSprop3.evaluate(test_images, test_labels, verbose=False)

print("inceptionv3 Fine Tuning\n")
print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid recall [end]: %.4f" % end_val_acc_fe)
print("Valid recall [opt]: %.4f" % opt_val_acc_fe)
print("Test recall [end]:  %.4f" % test_acc_fe)
print("Test recall [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT accuracy')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('inceptionv3 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();
