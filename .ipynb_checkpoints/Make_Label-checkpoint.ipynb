# %%
import numpy as np
import pandas as pd
import os
import re
import shutil

# %%
calc_test = pd.read_csv("calc_case_description_test_set.csv")
calc_test
# Out:
#     patient_id  breast density left or right breast image view  \
# 0      P_00038               2                 LEFT         CC
# 1      P_00038               2                 LEFT        MLO
# 2      P_00038               2                RIGHT         CC
# 3      P_00038               2                RIGHT         CC
# 4      P_00038               2                RIGHT        MLO
# ..         ...             ...                  ...        ...
# 321    P_02464               2                RIGHT        MLO
# 322    P_02498               4                RIGHT         CC
# 323    P_02498               4                RIGHT        MLO
# 324    P_02501               3                RIGHT         CC
# 325    P_02501               3                RIGHT        MLO
#
#      abnormality id abnormality type              calc type calc distribution  \
# 0                 1    calcification   PUNCTATE-PLEOMORPHIC         CLUSTERED
# 1                 1    calcification   PUNCTATE-PLEOMORPHIC         CLUSTERED
# 2                 1    calcification               VASCULAR               NaN
# 3                 2    calcification               VASCULAR               NaN
# 4                 1    calcification               VASCULAR               NaN
# ..              ...              ...                    ...               ...
# 321               1    calcification  FINE_LINEAR_BRANCHING         CLUSTERED
# 322               1    calcification               PUNCTATE         CLUSTERED
# 323               1    calcification               PUNCTATE         CLUSTERED
# 324               1    calcification            PLEOMORPHIC         CLUSTERED
# 325               1    calcification            PLEOMORPHIC         CLUSTERED
#
#      assessment                pathology  subtlety  \
# 0             4                   BENIGN         2
# 1             4                   BENIGN         2
# 2             2  BENIGN_WITHOUT_CALLBACK         5
# 3             2  BENIGN_WITHOUT_CALLBACK         5
# 4             2  BENIGN_WITHOUT_CALLBACK         5
# ..          ...                      ...       ...
# 321           0                MALIGNANT         4
# 322           0                   BENIGN         3
# 323           0                   BENIGN         3
# 324           0                MALIGNANT         3
# 325           0                MALIGNANT         3
#
#                                        image file path  \
# 0    Calc-Test_P_00038_LEFT_CC/1.3.6.1.4.1.9590.100...
# 1    Calc-Test_P_00038_LEFT_MLO/1.3.6.1.4.1.9590.10...
# 2    Calc-Test_P_00038_RIGHT_CC/1.3.6.1.4.1.9590.10...
# 3    Calc-Test_P_00038_RIGHT_CC/1.3.6.1.4.1.9590.10...
# 4    Calc-Test_P_00038_RIGHT_MLO/1.3.6.1.4.1.9590.1...
# ..                                                 ...
# 321  Calc-Test_P_02464_RIGHT_MLO/1.3.6.1.4.1.9590.1...
# 322  Calc-Test_P_02498_RIGHT_CC/1.3.6.1.4.1.9590.10...
# 323  Calc-Test_P_02498_RIGHT_MLO/1.3.6.1.4.1.9590.1...
# 324  Calc-Test_P_02501_RIGHT_CC/1.3.6.1.4.1.9590.10...
# 325  Calc-Test_P_02501_RIGHT_MLO/1.3.6.1.4.1.9590.1...
#
#                                cropped image file path  \
# 0    Calc-Test_P_00038_LEFT_CC_1/1.3.6.1.4.1.9590.1...
# 1    Calc-Test_P_00038_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 2    Calc-Test_P_00038_RIGHT_CC_1/1.3.6.1.4.1.9590....
# 3    Calc-Test_P_00038_RIGHT_CC_2/1.3.6.1.4.1.9590....
# 4    Calc-Test_P_00038_RIGHT_MLO_1/1.3.6.1.4.1.9590...
# ..                                                 ...
# 321  Calc-Test_P_02464_RIGHT_MLO_1/1.3.6.1.4.1.9590...
# 322  Calc-Test_P_02498_RIGHT_CC_1/1.3.6.1.4.1.9590....
# 323  Calc-Test_P_02498_RIGHT_MLO_1/1.3.6.1.4.1.9590...
# 324  Calc-Test_P_02501_RIGHT_CC_1/1.3.6.1.4.1.9590....
# 325  Calc-Test_P_02501_RIGHT_MLO_1/1.3.6.1.4.1.9590...
#
#                                     ROI mask file path
# 0    Calc-Test_P_00038_LEFT_CC_1/1.3.6.1.4.1.9590.1...
# 1    Calc-Test_P_00038_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 2    Calc-Test_P_00038_RIGHT_CC_1/1.3.6.1.4.1.9590....
# 3    Calc-Test_P_00038_RIGHT_CC_2/1.3.6.1.4.1.9590....
# 4    Calc-Test_P_00038_RIGHT_MLO_1/1.3.6.1.4.1.9590...
# ..                                                 ...
# 321  Calc-Test_P_02464_RIGHT_MLO_1/1.3.6.1.4.1.9590...
# 322  Calc-Test_P_02498_RIGHT_CC_1/1.3.6.1.4.1.9590....
# 323  Calc-Test_P_02498_RIGHT_MLO_1/1.3.6.1.4.1.9590...
# 324  Calc-Test_P_02501_RIGHT_CC_1/1.3.6.1.4.1.9590....
# 325  Calc-Test_P_02501_RIGHT_MLO_1/1.3.6.1.4.1.9590...
#
# [326 rows x 14 columns]

# %%
new_calc_test = calc_test
new_calc_test.drop(["image file path","cropped image file path","ROI mask file path"], axis=1, inplace=True)
new_calc_test
# Out:
#     patient_id  breast density left or right breast image view  \
# 0      P_00038               2                 LEFT         CC
# 1      P_00038               2                 LEFT        MLO
# 2      P_00038               2                RIGHT         CC
# 3      P_00038               2                RIGHT         CC
# 4      P_00038               2                RIGHT        MLO
# ..         ...             ...                  ...        ...
# 321    P_02464               2                RIGHT        MLO
# 322    P_02498               4                RIGHT         CC
# 323    P_02498               4                RIGHT        MLO
# 324    P_02501               3                RIGHT         CC
# 325    P_02501               3                RIGHT        MLO
#
#      abnormality id abnormality type              calc type calc distribution  \
# 0                 1    calcification   PUNCTATE-PLEOMORPHIC         CLUSTERED
# 1                 1    calcification   PUNCTATE-PLEOMORPHIC         CLUSTERED
# 2                 1    calcification               VASCULAR               NaN
# 3                 2    calcification               VASCULAR               NaN
# 4                 1    calcification               VASCULAR               NaN
# ..              ...              ...                    ...               ...
# 321               1    calcification  FINE_LINEAR_BRANCHING         CLUSTERED
# 322               1    calcification               PUNCTATE         CLUSTERED
# 323               1    calcification               PUNCTATE         CLUSTERED
# 324               1    calcification            PLEOMORPHIC         CLUSTERED
# 325               1    calcification            PLEOMORPHIC         CLUSTERED
#
#      assessment                pathology  subtlety
# 0             4                   BENIGN         2
# 1             4                   BENIGN         2
# 2             2  BENIGN_WITHOUT_CALLBACK         5
# 3             2  BENIGN_WITHOUT_CALLBACK         5
# 4             2  BENIGN_WITHOUT_CALLBACK         5
# ..          ...                      ...       ...
# 321           0                MALIGNANT         4
# 322           0                   BENIGN         3
# 323           0                   BENIGN         3
# 324           0                MALIGNANT         3
# 325           0                MALIGNANT         3
#
# [326 rows x 11 columns]

# %%
new_calc_test['image_name'] = ''

# %%
i = 0
for id in new_calc_test['abnormality id']:
    #print(id)
    new_calc_test['image_name'][i] = 'Calc-Test_' + calc_test.patient_id[i] + '_' + calc_test['left or right breast'][i] + '_' + calc_test['image view'][i] + '_' + str(id) + '.dcm'
    i+=1
# Out:
# C:\Users\dahyun\anaconda3\envs\mammo\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
new_calc_test.image_name
# Out:
# 0        Calc-Test_P_00038_LEFT_CC_1.dcm
# 1       Calc-Test_P_00038_LEFT_MLO_1.dcm
# 2       Calc-Test_P_00038_RIGHT_CC_1.dcm
# 3       Calc-Test_P_00038_RIGHT_CC_2.dcm
# 4      Calc-Test_P_00038_RIGHT_MLO_1.dcm
#                      ...
# 321    Calc-Test_P_02464_RIGHT_MLO_1.dcm
# 322     Calc-Test_P_02498_RIGHT_CC_1.dcm
# 323    Calc-Test_P_02498_RIGHT_MLO_1.dcm
# 324     Calc-Test_P_02501_RIGHT_CC_1.dcm
# 325    Calc-Test_P_02501_RIGHT_MLO_1.dcm
# Name: image_name, Length: 326, dtype: object

# %%
new_calc_test.image_name[266]
# Out:
# 'Calc-Test_P_01670_LEFT_MLO_3.dcm'

# %%
new_calc_test.columns = ["patient_id","breast_density","left_or_right_breast","image_view","abnormality_id","abnormality_type","calc_type","calc_distribution","assessment","pathology", "subtlety","image_name"]
new_calc_test
# Out:
#     patient_id  breast_density left_or_right_breast image_view  \
# 0      P_00038               2                 LEFT         CC
# 1      P_00038               2                 LEFT        MLO
# 2      P_00038               2                RIGHT         CC
# 3      P_00038               2                RIGHT         CC
# 4      P_00038               2                RIGHT        MLO
# ..         ...             ...                  ...        ...
# 321    P_02464               2                RIGHT        MLO
# 322    P_02498               4                RIGHT         CC
# 323    P_02498               4                RIGHT        MLO
# 324    P_02501               3                RIGHT         CC
# 325    P_02501               3                RIGHT        MLO
#
#      abnormality_id abnormality_type              calc_type calc_distribution  \
# 0                 1    calcification   PUNCTATE-PLEOMORPHIC         CLUSTERED
# 1                 1    calcification   PUNCTATE-PLEOMORPHIC         CLUSTERED
# 2                 1    calcification               VASCULAR               NaN
# 3                 2    calcification               VASCULAR               NaN
# 4                 1    calcification               VASCULAR               NaN
# ..              ...              ...                    ...               ...
# 321               1    calcification  FINE_LINEAR_BRANCHING         CLUSTERED
# 322               1    calcification               PUNCTATE         CLUSTERED
# 323               1    calcification               PUNCTATE         CLUSTERED
# 324               1    calcification            PLEOMORPHIC         CLUSTERED
# 325               1    calcification            PLEOMORPHIC         CLUSTERED
#
#      assessment                pathology  subtlety  \
# 0             4                   BENIGN         2
# 1             4                   BENIGN         2
# 2             2  BENIGN_WITHOUT_CALLBACK         5
# 3             2  BENIGN_WITHOUT_CALLBACK         5
# 4             2  BENIGN_WITHOUT_CALLBACK         5
# ..          ...                      ...       ...
# 321           0                MALIGNANT         4
# 322           0                   BENIGN         3
# 323           0                   BENIGN         3
# 324           0                MALIGNANT         3
# 325           0                MALIGNANT         3
#
#                             image_name
# 0      Calc-Test_P_00038_LEFT_CC_1.dcm
# 1     Calc-Test_P_00038_LEFT_MLO_1.dcm
# 2     Calc-Test_P_00038_RIGHT_CC_1.dcm
# 3     Calc-Test_P_00038_RIGHT_CC_2.dcm
# 4    Calc-Test_P_00038_RIGHT_MLO_1.dcm
# ..                                 ...
# 321  Calc-Test_P_02464_RIGHT_MLO_1.dcm
# 322   Calc-Test_P_02498_RIGHT_CC_1.dcm
# 323  Calc-Test_P_02498_RIGHT_MLO_1.dcm
# 324   Calc-Test_P_02501_RIGHT_CC_1.dcm
# 325  Calc-Test_P_02501_RIGHT_MLO_1.dcm
#
# [326 rows x 12 columns]

# %%
#print(calc_test.patient_id)
#print(calc_test['left or right breast'])
print(calc_test['image view'])
# Out:
# 0       CC
# 1      MLO
# 2       CC
# 3       CC
# 4      MLO
#       ...
# 321    MLO
# 322     CC
# 323    MLO
# 324     CC
# 325    MLO
# Name: image view, Length: 326, dtype: object

# %%
calc_train = pd.read_csv("calc_case_description_train_set.csv")
new_calc_train = calc_train
new_calc_train.drop(["image file path","cropped image file path","ROI mask file path"], axis=1, inplace=True)
new_calc_train['image_name'] = ''

i = 0
for id in new_calc_train['abnormality id']:
    #print(id)
    new_calc_train['image_name'][i] = 'Calc-Training_' + calc_train.patient_id[i] + '_' + calc_train['left or right breast'][i] + '_' + calc_train['image view'][i] + '_' + str(id) + '.dcm'
    i+=1
new_calc_train.columns = ["patient_id","breast_density","left_or_right_breast","image_view","abnormality_id","abnormality_type","calc_type","calc_distribution","assessment","pathology", "subtlety","image_name"]
# Out:
# C:\Users\dahyun\anaconda3\envs\mammo\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
new_calc_train
# Out:
#      patient_id  breast_density left_or_right_breast image_view  \
# 0       P_00005               3                RIGHT         CC
# 1       P_00005               3                RIGHT        MLO
# 2       P_00007               4                 LEFT         CC
# 3       P_00007               4                 LEFT        MLO
# 4       P_00008               1                 LEFT         CC
# ...         ...             ...                  ...        ...
# 1541    P_02566               2                RIGHT        MLO
# 1542    P_02572               2                 LEFT         CC
# 1543    P_02572               2                 LEFT        MLO
# 1544    P_02584               1                 LEFT         CC
# 1545    P_02584               1                 LEFT        MLO
#
#       abnormality_id abnormality_type              calc_type  \
# 0                  1    calcification              AMORPHOUS
# 1                  1    calcification              AMORPHOUS
# 2                  1    calcification            PLEOMORPHIC
# 3                  1    calcification            PLEOMORPHIC
# 4                  1    calcification                    NaN
# ...              ...              ...                    ...
# 1541               1    calcification  AMORPHOUS-PLEOMORPHIC
# 1542               1    calcification              AMORPHOUS
# 1543               1    calcification              AMORPHOUS
# 1544               1    calcification            PLEOMORPHIC
# 1545               1    calcification            PLEOMORPHIC
#
#      calc_distribution  assessment                pathology  subtlety  \
# 0            CLUSTERED           3                MALIGNANT         3
# 1            CLUSTERED           3                MALIGNANT         3
# 2               LINEAR           4                   BENIGN         4
# 3               LINEAR           4                   BENIGN         4
# 4             REGIONAL           2  BENIGN_WITHOUT_CALLBACK         3
# ...                ...         ...                      ...       ...
# 1541         SEGMENTAL           5                MALIGNANT         5
# 1542         CLUSTERED           0                MALIGNANT         2
# 1543         CLUSTERED           0                MALIGNANT         2
# 1544         SEGMENTAL           0                   BENIGN         4
# 1545         SEGMENTAL           0                   BENIGN         4
#
#                                  image_name
# 0      Calc-Training_P_00005_RIGHT_CC_1.dcm
# 1     Calc-Training_P_00005_RIGHT_MLO_1.dcm
# 2       Calc-Training_P_00007_LEFT_CC_1.dcm
# 3      Calc-Training_P_00007_LEFT_MLO_1.dcm
# 4       Calc-Training_P_00008_LEFT_CC_1.dcm
# ...                                     ...
# 1541  Calc-Training_P_02566_RIGHT_MLO_1.dcm
# 1542    Calc-Training_P_02572_LEFT_CC_1.dcm
# 1543   Calc-Training_P_02572_LEFT_MLO_1.dcm
# 1544    Calc-Training_P_02584_LEFT_CC_1.dcm
# 1545   Calc-Training_P_02584_LEFT_MLO_1.dcm
#
# [1546 rows x 12 columns]

# %%
mass_test = pd.read_csv("mass_case_description_test_set.csv")
new_mass_test = mass_test
new_mass_test.drop(["image file path","cropped image file path","ROI mask file path"], axis=1, inplace=True)
new_mass_test['image_name'] = ''

i = 0
for id in new_mass_test['abnormality id']:
    #print(id)
    new_mass_test['image_name'][i] = 'Mass-Test_' + mass_test.patient_id[i] + '_' + mass_test['left or right breast'][i] + '_' + mass_test['image view'][i] + '_' + str(id) + '.dcm'
    i+=1
new_mass_test.columns = ["patient_id","breast_density","left_or_right_breast","image_view","abnormality_id","abnormality_type","mass_shape","mass_margins","assessment","pathology", "subtlety","image_name"]
# Out:
# C:\Users\dahyun\anaconda3\envs\mammo\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
new_mass_test
# Out:
#     patient_id  breast_density left_or_right_breast image_view  \
# 0      P_00016               4                 LEFT         CC
# 1      P_00016               4                 LEFT        MLO
# 2      P_00017               2                 LEFT         CC
# 3      P_00017               2                 LEFT        MLO
# 4      P_00032               3                RIGHT         CC
# ..         ...             ...                  ...        ...
# 373    P_01825               2                RIGHT        MLO
# 374    P_01833               2                RIGHT        MLO
# 375    P_01865               2                 LEFT        MLO
# 376    P_01912               3                RIGHT         CC
# 377    P_01912               3                RIGHT        MLO
#
#      abnormality_id abnormality_type mass_shape    mass_margins  assessment  \
# 0                 1             mass  IRREGULAR      SPICULATED           5
# 1                 1             mass  IRREGULAR      SPICULATED           5
# 2                 1             mass      ROUND   CIRCUMSCRIBED           4
# 3                 1             mass      ROUND     ILL_DEFINED           4
# 4                 1             mass      ROUND        OBSCURED           0
# ..              ...              ...        ...             ...         ...
# 373               1             mass  LOBULATED  MICROLOBULATED           3
# 374               1             mass  IRREGULAR     ILL_DEFINED           5
# 375               1             mass  IRREGULAR     ILL_DEFINED           4
# 376               1             mass  IRREGULAR      SPICULATED           5
# 377               1             mass  IRREGULAR      SPICULATED           5
#
#                    pathology  subtlety                         image_name
# 0                  MALIGNANT         5    Mass-Test_P_00016_LEFT_CC_1.dcm
# 1                  MALIGNANT         5   Mass-Test_P_00016_LEFT_MLO_1.dcm
# 2                  MALIGNANT         4    Mass-Test_P_00017_LEFT_CC_1.dcm
# 3                  MALIGNANT         4   Mass-Test_P_00017_LEFT_MLO_1.dcm
# 4                     BENIGN         2   Mass-Test_P_00032_RIGHT_CC_1.dcm
# ..                       ...       ...                                ...
# 373  BENIGN_WITHOUT_CALLBACK         3  Mass-Test_P_01825_RIGHT_MLO_1.dcm
# 374                MALIGNANT         5  Mass-Test_P_01833_RIGHT_MLO_1.dcm
# 375                MALIGNANT         2   Mass-Test_P_01865_LEFT_MLO_1.dcm
# 376                MALIGNANT         4   Mass-Test_P_01912_RIGHT_CC_1.dcm
# 377                MALIGNANT         4  Mass-Test_P_01912_RIGHT_MLO_1.dcm
#
# [378 rows x 12 columns]

# %%
mass_train = pd.read_csv("mass_case_description_train_set.csv")
new_mass_train = mass_train
new_mass_train.drop(["image file path","cropped image file path","ROI mask file path"], axis=1, inplace=True)
new_mass_train['image_name'] = ''

i = 0
for id in new_mass_train['abnormality id']:
    #print(id)
    new_mass_train['image_name'][i] = 'Mass-Training_' + mass_train.patient_id[i] + '_' + mass_train['left or right breast'][i] + '_' + mass_train['image view'][i] + '_' + str(id) + '.dcm'
    i+=1
new_mass_train.columns = ["patient_id","breast_density","left_or_right_breast","image_view","abnormality_id","abnormality_type","mass_shape","mass_margins","assessment","pathology", "subtlety","image_name"]
# Out:
# C:\Users\dahyun\anaconda3\envs\mammo\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
new_mass_train
# Out:
#      patient_id  breast_density left_or_right_breast image_view  \
# 0       P_00001               3                 LEFT         CC
# 1       P_00001               3                 LEFT        MLO
# 2       P_00004               3                 LEFT         CC
# 3       P_00004               3                 LEFT        MLO
# 4       P_00004               3                RIGHT        MLO
# ...         ...             ...                  ...        ...
# 1313    P_02033               2                RIGHT        MLO
# 1314    P_02079               2                RIGHT         CC
# 1315    P_02079               2                RIGHT        MLO
# 1316    P_02092               2                 LEFT         CC
# 1317    P_02092               2                 LEFT        MLO
#
#       abnormality_id abnormality_type                          mass_shape  \
# 0                  1             mass  IRREGULAR-ARCHITECTURAL_DISTORTION
# 1                  1             mass  IRREGULAR-ARCHITECTURAL_DISTORTION
# 2                  1             mass            ARCHITECTURAL_DISTORTION
# 3                  1             mass            ARCHITECTURAL_DISTORTION
# 4                  1             mass                                OVAL
# ...              ...              ...                                 ...
# 1313               1             mass                           IRREGULAR
# 1314               1             mass                               ROUND
# 1315               1             mass                               ROUND
# 1316               1             mass                           IRREGULAR
# 1317               1             mass                           IRREGULAR
#
#        mass_margins  assessment  pathology  subtlety  \
# 0        SPICULATED           4  MALIGNANT         4
# 1        SPICULATED           4  MALIGNANT         4
# 2       ILL_DEFINED           4     BENIGN         3
# 3       ILL_DEFINED           4     BENIGN         3
# 4     CIRCUMSCRIBED           4     BENIGN         5
# ...             ...         ...        ...       ...
# 1313    ILL_DEFINED           3  MALIGNANT         4
# 1314     SPICULATED           3  MALIGNANT         5
# 1315     SPICULATED           3  MALIGNANT         5
# 1316     SPICULATED           3  MALIGNANT         2
# 1317     SPICULATED           3  MALIGNANT         2
#
#                                  image_name
# 0       Mass-Training_P_00001_LEFT_CC_1.dcm
# 1      Mass-Training_P_00001_LEFT_MLO_1.dcm
# 2       Mass-Training_P_00004_LEFT_CC_1.dcm
# 3      Mass-Training_P_00004_LEFT_MLO_1.dcm
# 4     Mass-Training_P_00004_RIGHT_MLO_1.dcm
# ...                                     ...
# 1313  Mass-Training_P_02033_RIGHT_MLO_1.dcm
# 1314   Mass-Training_P_02079_RIGHT_CC_1.dcm
# 1315  Mass-Training_P_02079_RIGHT_MLO_1.dcm
# 1316    Mass-Training_P_02092_LEFT_CC_1.dcm
# 1317   Mass-Training_P_02092_LEFT_MLO_1.dcm
#
# [1318 rows x 12 columns]

# %%
new_mass_test.image_name[316]
# Out:
# 'Mass-Test_P_01566_RIGHT_MLO_3.dcm'

# %%
new_mass_train.image_name[85]
# Out:
# 'Mass-Training_P_00106_LEFT_MLO_5.dcm'

# %%
#concat=> 여러개의 동일한 형태 DataFrame 합치기
train_label = pd.concat([new_calc_train, new_mass_train], axis = 0)
train_label['pathology'][train_label['pathology'] == 'BENIGN_WITHOUT_CALLBACK'] = 'BENIGN'
train_label['class'] = train_label['pathology'] + '_' + train_label['abnormality_type']

test_label = pd.concat([new_calc_test, new_mass_test], axis = 0)
test_label['pathology'][test_label['pathology'] == 'BENIGN_WITHOUT_CALLBACK'] = 'BENIGN'
test_label['class'] = test_label['pathology'] + '_' + test_label['abnormality_type']
# Out:
# C:\Users\dahyun\anaconda3\envs\mammo\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\dahyun\anaconda3\envs\mammo\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
train_label.set_index("image_name", inplace = True)
test_label.set_index("image_name", inplace = True)

# %%
test_label
# Out:
#                                   patient_id  breast_density  \
# image_name
# Calc-Test_P_00038_LEFT_CC_1.dcm      P_00038               2
# Calc-Test_P_00038_LEFT_MLO_1.dcm     P_00038               2
# Calc-Test_P_00038_RIGHT_CC_1.dcm     P_00038               2
# Calc-Test_P_00038_RIGHT_CC_2.dcm     P_00038               2
# Calc-Test_P_00038_RIGHT_MLO_1.dcm    P_00038               2
# ...                                      ...             ...
# Mass-Test_P_01825_RIGHT_MLO_1.dcm    P_01825               2
# Mass-Test_P_01833_RIGHT_MLO_1.dcm    P_01833               2
# Mass-Test_P_01865_LEFT_MLO_1.dcm     P_01865               2
# Mass-Test_P_01912_RIGHT_CC_1.dcm     P_01912               3
# Mass-Test_P_01912_RIGHT_MLO_1.dcm    P_01912               3
#
#                                   left_or_right_breast image_view  \
# image_name
# Calc-Test_P_00038_LEFT_CC_1.dcm                   LEFT         CC
# Calc-Test_P_00038_LEFT_MLO_1.dcm                  LEFT        MLO
# Calc-Test_P_00038_RIGHT_CC_1.dcm                 RIGHT         CC
# Calc-Test_P_00038_RIGHT_CC_2.dcm                 RIGHT         CC
# Calc-Test_P_00038_RIGHT_MLO_1.dcm                RIGHT        MLO
# ...                                                ...        ...
# Mass-Test_P_01825_RIGHT_MLO_1.dcm                RIGHT        MLO
# Mass-Test_P_01833_RIGHT_MLO_1.dcm                RIGHT        MLO
# Mass-Test_P_01865_LEFT_MLO_1.dcm                  LEFT        MLO
# Mass-Test_P_01912_RIGHT_CC_1.dcm                 RIGHT         CC
# Mass-Test_P_01912_RIGHT_MLO_1.dcm                RIGHT        MLO
#
#                                    abnormality_id abnormality_type  \
# image_name
# Calc-Test_P_00038_LEFT_CC_1.dcm                 1    calcification
# Calc-Test_P_00038_LEFT_MLO_1.dcm                1    calcification
# Calc-Test_P_00038_RIGHT_CC_1.dcm                1    calcification
# Calc-Test_P_00038_RIGHT_CC_2.dcm                2    calcification
# Calc-Test_P_00038_RIGHT_MLO_1.dcm               1    calcification
# ...                                           ...              ...
# Mass-Test_P_01825_RIGHT_MLO_1.dcm               1             mass
# Mass-Test_P_01833_RIGHT_MLO_1.dcm               1             mass
# Mass-Test_P_01865_LEFT_MLO_1.dcm                1             mass
# Mass-Test_P_01912_RIGHT_CC_1.dcm                1             mass
# Mass-Test_P_01912_RIGHT_MLO_1.dcm               1             mass
#
#                                               calc_type calc_distribution  \
# image_name
# Calc-Test_P_00038_LEFT_CC_1.dcm    PUNCTATE-PLEOMORPHIC         CLUSTERED
# Calc-Test_P_00038_LEFT_MLO_1.dcm   PUNCTATE-PLEOMORPHIC         CLUSTERED
# Calc-Test_P_00038_RIGHT_CC_1.dcm               VASCULAR               NaN
# Calc-Test_P_00038_RIGHT_CC_2.dcm               VASCULAR               NaN
# Calc-Test_P_00038_RIGHT_MLO_1.dcm              VASCULAR               NaN
# ...                                                 ...               ...
# Mass-Test_P_01825_RIGHT_MLO_1.dcm                   NaN               NaN
# Mass-Test_P_01833_RIGHT_MLO_1.dcm                   NaN               NaN
# Mass-Test_P_01865_LEFT_MLO_1.dcm                    NaN               NaN
# Mass-Test_P_01912_RIGHT_CC_1.dcm                    NaN               NaN
# Mass-Test_P_01912_RIGHT_MLO_1.dcm                   NaN               NaN
#
#                                    assessment  pathology  subtlety mass_shape  \
# image_name
# Calc-Test_P_00038_LEFT_CC_1.dcm             4     BENIGN         2        NaN
# Calc-Test_P_00038_LEFT_MLO_1.dcm            4     BENIGN         2        NaN
# Calc-Test_P_00038_RIGHT_CC_1.dcm            2     BENIGN         5        NaN
# Calc-Test_P_00038_RIGHT_CC_2.dcm            2     BENIGN         5        NaN
# Calc-Test_P_00038_RIGHT_MLO_1.dcm           2     BENIGN         5        NaN
# ...                                       ...        ...       ...        ...
# Mass-Test_P_01825_RIGHT_MLO_1.dcm           3     BENIGN         3  LOBULATED
# Mass-Test_P_01833_RIGHT_MLO_1.dcm           5  MALIGNANT         5  IRREGULAR
# Mass-Test_P_01865_LEFT_MLO_1.dcm            4  MALIGNANT         2  IRREGULAR
# Mass-Test_P_01912_RIGHT_CC_1.dcm            5  MALIGNANT         4  IRREGULAR
# Mass-Test_P_01912_RIGHT_MLO_1.dcm           5  MALIGNANT         4  IRREGULAR
#
#                                      mass_margins                 class
# image_name
# Calc-Test_P_00038_LEFT_CC_1.dcm               NaN  BENIGN_calcification
# Calc-Test_P_00038_LEFT_MLO_1.dcm              NaN  BENIGN_calcification
# Calc-Test_P_00038_RIGHT_CC_1.dcm              NaN  BENIGN_calcification
# Calc-Test_P_00038_RIGHT_CC_2.dcm              NaN  BENIGN_calcification
# Calc-Test_P_00038_RIGHT_MLO_1.dcm             NaN  BENIGN_calcification
# ...                                           ...                   ...
# Mass-Test_P_01825_RIGHT_MLO_1.dcm  MICROLOBULATED           BENIGN_mass
# Mass-Test_P_01833_RIGHT_MLO_1.dcm     ILL_DEFINED        MALIGNANT_mass
# Mass-Test_P_01865_LEFT_MLO_1.dcm      ILL_DEFINED        MALIGNANT_mass
# Mass-Test_P_01912_RIGHT_CC_1.dcm       SPICULATED        MALIGNANT_mass
# Mass-Test_P_01912_RIGHT_MLO_1.dcm      SPICULATED        MALIGNANT_mass
#
# [704 rows x 14 columns]

# %%
#save labels
train_label.to_pickle("train_label.pkl")
test_label.to_pickle("test_label.pkl")
