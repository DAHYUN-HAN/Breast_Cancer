# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import optimizers
#from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.applications import resnet50
from keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop, SGD, Adam, Adadelta, Adagrad, Adamax, Nadam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical

import time
import numpy as np
import pandas as pd
import os
import sys
import sklearn
import datetime
import random
import matplotlib.pyplot as plt
import math
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Activation, Flatten, BatchNormalization, GlobalAveragePooling2D  
from tensorflow.keras.backend import batch_normalization
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import metrics
from packaging import version
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
#identify GPU
device_name = tf.test.gpu_device_name()
if not tf.test.is_gpu_available():
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
tf.config.list_physical_devices('GPU')
# Out:
# WARNING:tensorflow:From <ipython-input-2-6c8645f8fea6>:3: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# Found GPU at: /device:GPU:0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def load_training():
    """
    Load the training set (excluding baseline patches)
    """
    images = np.load(os.path.join('Data_new3', 'X_train.npy'))
    labels = np.load(os.path.join('Data_new3', 'train_labels_multi.npy'))
    return images, labels


def load_testing():
    """
    Load the test set (abnormalities patches and labels, no baseline)
    """
    images = np.load(os.path.join('Data_new3', 'X_test.npy'))
    labels = np.load(os.path.join('Data_new3', 'y_test_labels_multi.npy'))
    return images, labels


def remap_label(l):
    """
    Remap the labels to:
        0 -> mass benign 
        1 -> mass malignant
        2 -> calcification benign
        3 -> calcification malignant
    """
    if 1 <= l <= 4:
        return l-1
    else:
        print("[WARN] Unrecognized label (%d)" % l)
        return None

# %%
# Load training and test images (abnormalities only, no baseline)
train_images, train_labels= load_training()
test_images, test_labels= load_testing()

# Number of images
n_train_img = train_images.shape[0]
n_test_img = test_images.shape[0]
print("Train size: %d \t Test size: %d" % (n_train_img, n_test_img))

# Compute width and height of images
img_w = train_images.shape[1]
img_h = train_images.shape[2]
print("Image size: %dx%d" % (img_w, img_h))

# Convert the labels to categorical format
train_labels = to_categorical(train_labels)
test_labels_raw = test_labels.copy()
test_labels = to_categorical(test_labels)

# Create a new dimension for color in the images arrays
train_images = train_images.reshape((n_train_img, img_w, img_h, 1))
test_images = test_images.reshape((n_test_img, img_w, img_h, 1))

# Convert from 16-bit (0-65535) to to 8-bit (0-255)
train_images = train_images.astype('uint16') / 255
test_images = test_images.astype('uint16') / 255

# Replicate the only color channel (gray) 3 times, for VGGNet compatibility
train_images = np.repeat(train_images, 3, axis=3)
test_images = np.repeat(test_images, 3, axis=3)

# Shuffle the training set (originally sorted by label)
perm = np.random.permutation(n_train_img)
train_images = train_images[perm]
train_labels = train_labels[perm]

# Create a generator for training images
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2,
    rotation_range=180,
    shear_range=15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='reflect'
)

# Fit the generator with some images
train_datagen.fit(train_images)

# Split train images into actual training and validation
train_generator = train_datagen.flow(train_images, train_labels, batch_size=128, subset='training')
validation_generator = train_datagen.flow(train_images, train_labels, batch_size=128, subset='validation')

# Preprocess the test images as well
preprocess_input(test_images);
# Out:
# Train size: 2913 	 Test size: 655
# Image size: 256x256

# %%
# Build a model using VGG16 convolutional base and new FC final layer

def create_resnet50(verbose=False, fc_size=256, dropout=None):
    
    from tensorflow.keras.applications import resnet50
    
    resnet50_base = resnet50.ResNet50(weights='imagenet',
                       include_top=False,
                       input_shape=(256, 256, 3))
    resnet50 = models.Sequential()
    resnet50.add(resnet50_base)

    resnet50.add(layers.Flatten())
    if dropout is not None:
        resnet50.add(layers.Dropout(dropout))
    resnet50.add(layers.Dense(fc_size, activation='relu'))
    resnet50.add(layers.Dense(4, activation='softmax'))

    # Freeze the convolutional base
    resnet50_base.trainable = False
    
    if verbose:
        resnet50_base.summary()
        resnet50.summary()

    return resnet50

# %%
resnet50_fe_drop_temp = create_resnet50(verbose=True, dropout=0.5, fc_size=256)
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 262, 262, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 128, 128, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 128, 128, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 128, 128, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 130, 130, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 64, 64, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 64, 64, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 64, 64, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 64, 64, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 64, 64, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 64, 64, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 64, 64, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 64, 64, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 64, 64, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 64, 64, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 64, 64, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 64, 64, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 64, 64, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 64, 64, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 64, 64, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 64, 64, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 64, 64, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 64, 64, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 64, 64, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 64, 64, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 64, 64, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 64, 64, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 64, 64, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 32, 32, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 32, 32, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 32, 32, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 32, 32, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 32, 32, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 32, 32, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 32, 32, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 32, 32, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 32, 32, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 32, 32, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 32, 32, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 32, 32, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 32, 32, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 32, 32, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 32, 32, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 32, 32, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 32, 32, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 32, 32, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 32, 32, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 32, 32, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 32, 32, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 16, 16, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 16, 16, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 16, 16, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 16, 16, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 16, 16, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 16, 16, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 16, 16, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 16, 16, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 16, 16, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 16, 16, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 16, 16, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 16, 16, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 16, 16, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 16, 16, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 16, 16, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 16, 16, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 16, 16, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 16, 16, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 16, 16, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 16, 16, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 16, 16, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 16, 16, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 16, 16, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 16, 16, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 16, 16, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 16, 16, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 8, 8, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 8, 8, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 8, 8, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 8, 8, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 8, 8, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 8, 8, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 8, 8, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 8, 8, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 8, 8, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 8, 8, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 8, 8, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 8, 8, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 8, 8, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 8, 8, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 8, 8, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 8, 8, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 8, 8, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 8, 8, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 8, 8, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 8, 8, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 8, 8, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 8, 8, 2048)   0           conv5_block3_add[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 8, 8, 2048)        23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 131072)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 131072)            0
# _________________________________________________________________
# dense (Dense)                (None, 256)               33554688
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 57,143,428
# Trainable params: 33,555,716
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
resnet50_base = resnet50.ResNet50(weights='imagenet',
                       include_top=False,
                       input_shape=(256, 256, 3))

# %%
# Instantiate a VGG19 network with custom final layer
resnet50 = models.Sequential()
resnet50.add(resnet50_base)
resnet50.add(layers.Flatten())

resnet50.add(layers.Dropout(0.5))
resnet50.add(layers.Dense(2048, activation='relu'))
resnet50.add(layers.Dense(512, activation='relu'))
resnet50.add(layers.Dense(128, activation='relu'))
resnet50.add(layers.Dense(4, activation='softmax'))

resnet50_base.trainable = False

resnet50_fe_drop_128 = resnet50

# %%
resnet50_fe_drop_128.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 8, 8, 2048)        23587712
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 131072)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 131072)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2048)              268437504
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 293,140,484
# Trainable params: 269,552,772
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
# Early stopping (stop training after the validation loss reaches the minimum)
earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

# Callback for checkpointing
checkpoint = ModelCheckpoint('resnet50_fe_drop_128_4cl_best.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

# Compile the model
resnet50_fe_drop_128.compile(optimizer=optimizers.SGD(lr=1e-4, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train
history_resnet50_fe_drop_128 = resnet50_fe_drop_128.fit_generator(
        train_generator,
        epochs=200,
        validation_data=validation_generator,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)
# Out:
# WARNING:tensorflow:From <ipython-input-11-f5d72695d460>:9: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 19 steps, validate for 5 steps
# Epoch 1/200
# 18/19 [===========================>..] - ETA: 1s - loss: 2.2005 - accuracy: 0.2792
# Epoch 00001: val_loss improved from inf to 1.62114, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 36s 2s/step - loss: 2.1819 - accuracy: 0.2776 - val_loss: 1.6211 - val_accuracy: 0.2732
# Epoch 2/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.6739 - accuracy: 0.3123
# Epoch 00002: val_loss improved from 1.62114 to 1.48946, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.6781 - accuracy: 0.3093 - val_loss: 1.4895 - val_accuracy: 0.2595
# Epoch 3/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.6047 - accuracy: 0.3114
# Epoch 00003: val_loss improved from 1.48946 to 1.46387, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.6060 - accuracy: 0.3085 - val_loss: 1.4639 - val_accuracy: 0.2612
# Epoch 4/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.4929 - accuracy: 0.3296
# Epoch 00004: val_loss improved from 1.46387 to 1.43724, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.4881 - accuracy: 0.3316 - val_loss: 1.4372 - val_accuracy: 0.3007
# Epoch 5/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.4774 - accuracy: 0.3314
# Epoch 00005: val_loss improved from 1.43724 to 1.39944, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.4768 - accuracy: 0.3312 - val_loss: 1.3994 - val_accuracy: 0.2955
# Epoch 6/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.4344 - accuracy: 0.3482
# Epoch 00006: val_loss did not improve from 1.39944
# 19/19 [==============================] - 29s 2s/step - loss: 1.4349 - accuracy: 0.3492 - val_loss: 1.4069 - val_accuracy: 0.2887
# Epoch 7/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.3952 - accuracy: 0.3677
# Epoch 00007: val_loss improved from 1.39944 to 1.38543, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.3966 - accuracy: 0.3664 - val_loss: 1.3854 - val_accuracy: 0.3179
# Epoch 8/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.3972 - accuracy: 0.3640
# Epoch 00008: val_loss improved from 1.38543 to 1.35183, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.3954 - accuracy: 0.3634 - val_loss: 1.3518 - val_accuracy: 0.3093
# Epoch 9/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.3703 - accuracy: 0.3604
# Epoch 00009: val_loss did not improve from 1.35183
# 19/19 [==============================] - 29s 2s/step - loss: 1.3732 - accuracy: 0.3604 - val_loss: 1.3986 - val_accuracy: 0.3058
# Epoch 10/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.3697 - accuracy: 0.3795
# Epoch 00010: val_loss did not improve from 1.35183
# 19/19 [==============================] - 29s 2s/step - loss: 1.3743 - accuracy: 0.3775 - val_loss: 1.3520 - val_accuracy: 0.3557
# Epoch 11/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.3726 - accuracy: 0.3550
# Epoch 00011: val_loss improved from 1.35183 to 1.34275, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.3717 - accuracy: 0.3574 - val_loss: 1.3428 - val_accuracy: 0.3540
# Epoch 12/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.3606 - accuracy: 0.3808
# Epoch 00012: val_loss did not improve from 1.34275
# 19/19 [==============================] - 29s 2s/step - loss: 1.3541 - accuracy: 0.3844 - val_loss: 1.3503 - val_accuracy: 0.3385
# Epoch 13/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.3328 - accuracy: 0.3831
# Epoch 00013: val_loss did not improve from 1.34275
# 19/19 [==============================] - 29s 2s/step - loss: 1.3347 - accuracy: 0.3801 - val_loss: 1.3478 - val_accuracy: 0.3402
# Epoch 14/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.3292 - accuracy: 0.3854
# Epoch 00014: val_loss did not improve from 1.34275
# 19/19 [==============================] - 29s 2s/step - loss: 1.3294 - accuracy: 0.3878 - val_loss: 1.3540 - val_accuracy: 0.3436
# Epoch 15/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.3512 - accuracy: 0.3745
# Epoch 00015: val_loss did not improve from 1.34275
# 19/19 [==============================] - 29s 2s/step - loss: 1.3533 - accuracy: 0.3737 - val_loss: 1.3562 - val_accuracy: 0.3265
# Epoch 16/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.3131 - accuracy: 0.3849
# Epoch 00016: val_loss did not improve from 1.34275
# 19/19 [==============================] - 29s 2s/step - loss: 1.3118 - accuracy: 0.3865 - val_loss: 1.3523 - val_accuracy: 0.3522
# Epoch 17/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.3053 - accuracy: 0.3827
# Epoch 00017: val_loss improved from 1.34275 to 1.33462, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.3073 - accuracy: 0.3827 - val_loss: 1.3346 - val_accuracy: 0.3763
# Epoch 18/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.3129 - accuracy: 0.4090
# Epoch 00018: val_loss improved from 1.33462 to 1.32500, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.3085 - accuracy: 0.4144 - val_loss: 1.3250 - val_accuracy: 0.3608
# Epoch 19/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.3046 - accuracy: 0.3926
# Epoch 00019: val_loss did not improve from 1.32500
# 19/19 [==============================] - 29s 2s/step - loss: 1.3001 - accuracy: 0.3977 - val_loss: 1.3365 - val_accuracy: 0.3574
# Epoch 20/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.3049 - accuracy: 0.4067
# Epoch 00020: val_loss improved from 1.32500 to 1.32487, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.2990 - accuracy: 0.4067 - val_loss: 1.3249 - val_accuracy: 0.3557
# Epoch 21/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2970 - accuracy: 0.4049
# Epoch 00021: val_loss improved from 1.32487 to 1.32152, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.2909 - accuracy: 0.4097 - val_loss: 1.3215 - val_accuracy: 0.3574
# Epoch 22/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2864 - accuracy: 0.4085
# Epoch 00022: val_loss improved from 1.32152 to 1.31781, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.2839 - accuracy: 0.4058 - val_loss: 1.3178 - val_accuracy: 0.3454
# Epoch 23/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2704 - accuracy: 0.4231
# Epoch 00023: val_loss improved from 1.31781 to 1.30947, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.2708 - accuracy: 0.4239 - val_loss: 1.3095 - val_accuracy: 0.3540
# Epoch 24/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2781 - accuracy: 0.4181
# Epoch 00024: val_loss did not improve from 1.30947
# 19/19 [==============================] - 29s 2s/step - loss: 1.2776 - accuracy: 0.4170 - val_loss: 1.3105 - val_accuracy: 0.3849
# Epoch 25/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2984 - accuracy: 0.4094
# Epoch 00025: val_loss did not improve from 1.30947
# 19/19 [==============================] - 29s 2s/step - loss: 1.2959 - accuracy: 0.4088 - val_loss: 1.3155 - val_accuracy: 0.3660
# Epoch 26/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2704 - accuracy: 0.4131
# Epoch 00026: val_loss did not improve from 1.30947
# 19/19 [==============================] - 29s 2s/step - loss: 1.2717 - accuracy: 0.4114 - val_loss: 1.3258 - val_accuracy: 0.3436
# Epoch 27/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2707 - accuracy: 0.4131
# Epoch 00027: val_loss did not improve from 1.30947
# 19/19 [==============================] - 29s 2s/step - loss: 1.2742 - accuracy: 0.4110 - val_loss: 1.3236 - val_accuracy: 0.3505
# Epoch 28/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2624 - accuracy: 0.4258
# Epoch 00028: val_loss did not improve from 1.30947
# 19/19 [==============================] - 29s 2s/step - loss: 1.2633 - accuracy: 0.4277 - val_loss: 1.3194 - val_accuracy: 0.3643
# Epoch 29/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2802 - accuracy: 0.4222
# Epoch 00029: val_loss improved from 1.30947 to 1.30890, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.2762 - accuracy: 0.4260 - val_loss: 1.3089 - val_accuracy: 0.3711
# Epoch 30/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2624 - accuracy: 0.4203
# Epoch 00030: val_loss did not improve from 1.30890
# 19/19 [==============================] - 29s 2s/step - loss: 1.2659 - accuracy: 0.4183 - val_loss: 1.3230 - val_accuracy: 0.3488
# Epoch 31/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2754 - accuracy: 0.4167
# Epoch 00031: val_loss improved from 1.30890 to 1.29997, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.2709 - accuracy: 0.4196 - val_loss: 1.3000 - val_accuracy: 0.3660
# Epoch 32/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2734 - accuracy: 0.4172
# Epoch 00032: val_loss did not improve from 1.29997
# 19/19 [==============================] - 29s 2s/step - loss: 1.2707 - accuracy: 0.4183 - val_loss: 1.3015 - val_accuracy: 0.3608
# Epoch 33/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2429 - accuracy: 0.4312
# Epoch 00033: val_loss improved from 1.29997 to 1.28570, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.2425 - accuracy: 0.4303 - val_loss: 1.2857 - val_accuracy: 0.3969
# Epoch 34/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2565 - accuracy: 0.4222
# Epoch 00034: val_loss did not improve from 1.28570
# 19/19 [==============================] - 29s 2s/step - loss: 1.2582 - accuracy: 0.4213 - val_loss: 1.2908 - val_accuracy: 0.3677
# Epoch 35/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2459 - accuracy: 0.4362
# Epoch 00035: val_loss did not improve from 1.28570
# 19/19 [==============================] - 29s 2s/step - loss: 1.2463 - accuracy: 0.4341 - val_loss: 1.2910 - val_accuracy: 0.3694
# Epoch 36/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2361 - accuracy: 0.4353
# Epoch 00036: val_loss did not improve from 1.28570
# 19/19 [==============================] - 29s 2s/step - loss: 1.2421 - accuracy: 0.4307 - val_loss: 1.2946 - val_accuracy: 0.3557
# Epoch 37/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2355 - accuracy: 0.4535
# Epoch 00037: val_loss did not improve from 1.28570
# 19/19 [==============================] - 29s 2s/step - loss: 1.2353 - accuracy: 0.4535 - val_loss: 1.2873 - val_accuracy: 0.4021
# Epoch 38/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2545 - accuracy: 0.4412
# Epoch 00038: val_loss did not improve from 1.28570
# 19/19 [==============================] - 29s 2s/step - loss: 1.2562 - accuracy: 0.4406 - val_loss: 1.2942 - val_accuracy: 0.3643
# Epoch 39/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2440 - accuracy: 0.4376
# Epoch 00039: val_loss improved from 1.28570 to 1.28536, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.2408 - accuracy: 0.4367 - val_loss: 1.2854 - val_accuracy: 0.4021
# Epoch 40/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2435 - accuracy: 0.4426
# Epoch 00040: val_loss did not improve from 1.28536
# 19/19 [==============================] - 29s 2s/step - loss: 1.2421 - accuracy: 0.4427 - val_loss: 1.2999 - val_accuracy: 0.3694
# Epoch 41/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2192 - accuracy: 0.4485
# Epoch 00041: val_loss did not improve from 1.28536
# 19/19 [==============================] - 29s 2s/step - loss: 1.2192 - accuracy: 0.4479 - val_loss: 1.3024 - val_accuracy: 0.3797
# Epoch 42/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2232 - accuracy: 0.4494
# Epoch 00042: val_loss did not improve from 1.28536
# 19/19 [==============================] - 29s 2s/step - loss: 1.2266 - accuracy: 0.4462 - val_loss: 1.2977 - val_accuracy: 0.3608
# Epoch 43/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2158 - accuracy: 0.4530
# Epoch 00043: val_loss improved from 1.28536 to 1.28523, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.2200 - accuracy: 0.4535 - val_loss: 1.2852 - val_accuracy: 0.3797
# Epoch 44/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2198 - accuracy: 0.4435
# Epoch 00044: val_loss improved from 1.28523 to 1.26902, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.2160 - accuracy: 0.4474 - val_loss: 1.2690 - val_accuracy: 0.4021
# Epoch 45/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1916 - accuracy: 0.4689
# Epoch 00045: val_loss did not improve from 1.26902
# 19/19 [==============================] - 29s 2s/step - loss: 1.1921 - accuracy: 0.4715 - val_loss: 1.2863 - val_accuracy: 0.3918
# Epoch 46/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2047 - accuracy: 0.4612
# Epoch 00046: val_loss did not improve from 1.26902
# 19/19 [==============================] - 29s 2s/step - loss: 1.2029 - accuracy: 0.4655 - val_loss: 1.2892 - val_accuracy: 0.3986
# Epoch 47/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2150 - accuracy: 0.4498
# Epoch 00047: val_loss did not improve from 1.26902
# 19/19 [==============================] - 29s 2s/step - loss: 1.2143 - accuracy: 0.4522 - val_loss: 1.2728 - val_accuracy: 0.4192
# Epoch 48/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2110 - accuracy: 0.4567
# Epoch 00048: val_loss did not improve from 1.26902
# 19/19 [==============================] - 29s 2s/step - loss: 1.2091 - accuracy: 0.4577 - val_loss: 1.2949 - val_accuracy: 0.4124
# Epoch 49/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2070 - accuracy: 0.4562
# Epoch 00049: val_loss did not improve from 1.26902
# 19/19 [==============================] - 29s 2s/step - loss: 1.2123 - accuracy: 0.4530 - val_loss: 1.2797 - val_accuracy: 0.3849
# Epoch 50/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2055 - accuracy: 0.4535
# Epoch 00050: val_loss did not improve from 1.26902
# 19/19 [==============================] - 29s 2s/step - loss: 1.2105 - accuracy: 0.4496 - val_loss: 1.2798 - val_accuracy: 0.4055
# Epoch 51/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2116 - accuracy: 0.4544
# Epoch 00051: val_loss did not improve from 1.26902
# 19/19 [==============================] - 29s 2s/step - loss: 1.2098 - accuracy: 0.4556 - val_loss: 1.2833 - val_accuracy: 0.3935
# Epoch 52/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2177 - accuracy: 0.4526
# Epoch 00052: val_loss did not improve from 1.26902
# 19/19 [==============================] - 29s 2s/step - loss: 1.2192 - accuracy: 0.4505 - val_loss: 1.2889 - val_accuracy: 0.3918
# Epoch 53/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1957 - accuracy: 0.4548
# Epoch 00053: val_loss did not improve from 1.26902
# 19/19 [==============================] - 29s 2s/step - loss: 1.2013 - accuracy: 0.4517 - val_loss: 1.2690 - val_accuracy: 0.4175
# Epoch 54/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2074 - accuracy: 0.4553
# Epoch 00054: val_loss improved from 1.26902 to 1.26698, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.2056 - accuracy: 0.4590 - val_loss: 1.2670 - val_accuracy: 0.4141
# Epoch 55/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2107 - accuracy: 0.4639
# Epoch 00055: val_loss did not improve from 1.26698
# 19/19 [==============================] - 29s 2s/step - loss: 1.2145 - accuracy: 0.4612 - val_loss: 1.2683 - val_accuracy: 0.3729
# Epoch 56/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1895 - accuracy: 0.4621
# Epoch 00056: val_loss improved from 1.26698 to 1.26259, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.1886 - accuracy: 0.4612 - val_loss: 1.2626 - val_accuracy: 0.4416
# Epoch 57/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1746 - accuracy: 0.4862
# Epoch 00057: val_loss did not improve from 1.26259
# 19/19 [==============================] - 29s 2s/step - loss: 1.1809 - accuracy: 0.4831 - val_loss: 1.2683 - val_accuracy: 0.4313
# Epoch 58/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.2071 - accuracy: 0.4744
# Epoch 00058: val_loss improved from 1.26259 to 1.24858, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.2026 - accuracy: 0.4805 - val_loss: 1.2486 - val_accuracy: 0.4330
# Epoch 59/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1972 - accuracy: 0.4548
# Epoch 00059: val_loss did not improve from 1.24858
# 19/19 [==============================] - 29s 2s/step - loss: 1.1994 - accuracy: 0.4556 - val_loss: 1.2647 - val_accuracy: 0.4244
# Epoch 60/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1986 - accuracy: 0.4648
# Epoch 00060: val_loss did not improve from 1.24858
# 19/19 [==============================] - 29s 2s/step - loss: 1.1973 - accuracy: 0.4693 - val_loss: 1.2519 - val_accuracy: 0.4107
# Epoch 61/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1901 - accuracy: 0.4744
# Epoch 00061: val_loss did not improve from 1.24858
# 19/19 [==============================] - 29s 2s/step - loss: 1.1832 - accuracy: 0.4749 - val_loss: 1.2577 - val_accuracy: 0.3969
# Epoch 62/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1857 - accuracy: 0.4639
# Epoch 00062: val_loss did not improve from 1.24858
# 19/19 [==============================] - 29s 2s/step - loss: 1.1844 - accuracy: 0.4650 - val_loss: 1.2649 - val_accuracy: 0.3969
# Epoch 63/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1856 - accuracy: 0.4707
# Epoch 00063: val_loss did not improve from 1.24858
# 19/19 [==============================] - 29s 2s/step - loss: 1.1875 - accuracy: 0.4698 - val_loss: 1.2646 - val_accuracy: 0.4072
# Epoch 64/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1872 - accuracy: 0.4662
# Epoch 00064: val_loss did not improve from 1.24858
# 19/19 [==============================] - 29s 2s/step - loss: 1.1906 - accuracy: 0.4646 - val_loss: 1.2562 - val_accuracy: 0.3952
# Epoch 65/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1878 - accuracy: 0.4694
# Epoch 00065: val_loss did not improve from 1.24858
# 19/19 [==============================] - 29s 2s/step - loss: 1.1863 - accuracy: 0.4715 - val_loss: 1.3002 - val_accuracy: 0.3711
# Epoch 66/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1915 - accuracy: 0.4657
# Epoch 00066: val_loss improved from 1.24858 to 1.24765, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.1884 - accuracy: 0.4668 - val_loss: 1.2476 - val_accuracy: 0.4124
# Epoch 67/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1852 - accuracy: 0.4671
# Epoch 00067: val_loss did not improve from 1.24765
# 19/19 [==============================] - 29s 2s/step - loss: 1.1832 - accuracy: 0.4685 - val_loss: 1.2579 - val_accuracy: 0.3969
# Epoch 68/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1531 - accuracy: 0.4775
# Epoch 00068: val_loss improved from 1.24765 to 1.23663, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.1563 - accuracy: 0.4770 - val_loss: 1.2366 - val_accuracy: 0.4433
# Epoch 69/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1771 - accuracy: 0.4798
# Epoch 00069: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1736 - accuracy: 0.4818 - val_loss: 1.2510 - val_accuracy: 0.4158
# Epoch 70/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1731 - accuracy: 0.4825
# Epoch 00070: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1757 - accuracy: 0.4843 - val_loss: 1.2471 - val_accuracy: 0.4244
# Epoch 71/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1855 - accuracy: 0.4707
# Epoch 00071: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1868 - accuracy: 0.4676 - val_loss: 1.2434 - val_accuracy: 0.4278
# Epoch 72/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1694 - accuracy: 0.4753
# Epoch 00072: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1677 - accuracy: 0.4758 - val_loss: 1.2464 - val_accuracy: 0.4089
# Epoch 73/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1908 - accuracy: 0.4812
# Epoch 00073: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1918 - accuracy: 0.4801 - val_loss: 1.2372 - val_accuracy: 0.4364
# Epoch 74/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1815 - accuracy: 0.4784
# Epoch 00074: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1861 - accuracy: 0.4753 - val_loss: 1.2538 - val_accuracy: 0.4175
# Epoch 75/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1684 - accuracy: 0.4907
# Epoch 00075: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1726 - accuracy: 0.4886 - val_loss: 1.2542 - val_accuracy: 0.4089
# Epoch 76/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1789 - accuracy: 0.4893
# Epoch 00076: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1826 - accuracy: 0.4891 - val_loss: 1.2560 - val_accuracy: 0.4158
# Epoch 77/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1666 - accuracy: 0.4725
# Epoch 00077: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1688 - accuracy: 0.4706 - val_loss: 1.2712 - val_accuracy: 0.3900
# Epoch 78/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1713 - accuracy: 0.4816
# Epoch 00078: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1777 - accuracy: 0.4775 - val_loss: 1.2465 - val_accuracy: 0.4158
# Epoch 79/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1555 - accuracy: 0.4852
# Epoch 00079: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1592 - accuracy: 0.4822 - val_loss: 1.2517 - val_accuracy: 0.4278
# Epoch 80/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1612 - accuracy: 0.4939
# Epoch 00080: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1633 - accuracy: 0.4908 - val_loss: 1.2622 - val_accuracy: 0.4038
# Epoch 81/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1599 - accuracy: 0.4843
# Epoch 00081: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1631 - accuracy: 0.4831 - val_loss: 1.2529 - val_accuracy: 0.4296
# Epoch 82/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1673 - accuracy: 0.4866
# Epoch 00082: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1711 - accuracy: 0.4809 - val_loss: 1.2730 - val_accuracy: 0.3763
# Epoch 83/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1288 - accuracy: 0.4952
# Epoch 00083: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1278 - accuracy: 0.4942 - val_loss: 1.2515 - val_accuracy: 0.4107
# Epoch 84/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1507 - accuracy: 0.4857
# Epoch 00084: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1506 - accuracy: 0.4861 - val_loss: 1.2455 - val_accuracy: 0.4055
# Epoch 85/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1411 - accuracy: 0.5007
# Epoch 00085: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1436 - accuracy: 0.4981 - val_loss: 1.2497 - val_accuracy: 0.4107
# Epoch 86/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1650 - accuracy: 0.4766
# Epoch 00086: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1704 - accuracy: 0.4740 - val_loss: 1.2501 - val_accuracy: 0.4296
# Epoch 87/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1727 - accuracy: 0.4731
# Epoch 00087: val_loss did not improve from 1.23663
# 19/19 [==============================] - 29s 2s/step - loss: 1.1658 - accuracy: 0.4736 - val_loss: 1.2390 - val_accuracy: 0.4261
# Epoch 88/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1721 - accuracy: 0.4812
# Epoch 00088: val_loss improved from 1.23663 to 1.22017, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.1758 - accuracy: 0.4801 - val_loss: 1.2202 - val_accuracy: 0.4485
# Epoch 89/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1496 - accuracy: 0.4939
# Epoch 00089: val_loss did not improve from 1.22017
# 19/19 [==============================] - 29s 2s/step - loss: 1.1316 - accuracy: 0.4972 - val_loss: 1.2469 - val_accuracy: 0.4210
# Epoch 90/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1633 - accuracy: 0.4798
# Epoch 00090: val_loss did not improve from 1.22017
# 19/19 [==============================] - 29s 2s/step - loss: 1.1598 - accuracy: 0.4835 - val_loss: 1.2490 - val_accuracy: 0.4124
# Epoch 91/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1661 - accuracy: 0.4918
# Epoch 00091: val_loss did not improve from 1.22017
# 19/19 [==============================] - 29s 2s/step - loss: 1.1583 - accuracy: 0.4921 - val_loss: 1.2396 - val_accuracy: 0.4278
# Epoch 92/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1446 - accuracy: 0.4884
# Epoch 00092: val_loss did not improve from 1.22017
# 19/19 [==============================] - 29s 2s/step - loss: 1.1383 - accuracy: 0.4929 - val_loss: 1.2345 - val_accuracy: 0.4210
# Epoch 93/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1575 - accuracy: 0.4998
# Epoch 00093: val_loss did not improve from 1.22017
# 19/19 [==============================] - 29s 2s/step - loss: 1.1579 - accuracy: 0.5006 - val_loss: 1.2519 - val_accuracy: 0.4244
# Epoch 94/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1322 - accuracy: 0.5007
# Epoch 00094: val_loss did not improve from 1.22017
# 19/19 [==============================] - 29s 2s/step - loss: 1.1338 - accuracy: 0.4981 - val_loss: 1.2599 - val_accuracy: 0.4192
# Epoch 95/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1429 - accuracy: 0.4930
# Epoch 00095: val_loss did not improve from 1.22017
# 19/19 [==============================] - 29s 2s/step - loss: 1.1438 - accuracy: 0.4938 - val_loss: 1.2289 - val_accuracy: 0.4399
# Epoch 96/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1753 - accuracy: 0.4612
# Epoch 00096: val_loss did not improve from 1.22017
# 19/19 [==============================] - 29s 2s/step - loss: 1.1728 - accuracy: 0.4642 - val_loss: 1.2657 - val_accuracy: 0.3849
# Epoch 97/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1477 - accuracy: 0.4852
# Epoch 00097: val_loss improved from 1.22017 to 1.21626, saving model to resnet50_fe_drop_128_4cl_best.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.1499 - accuracy: 0.4835 - val_loss: 1.2163 - val_accuracy: 0.4467
# Epoch 98/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1534 - accuracy: 0.4902
# Epoch 00098: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1554 - accuracy: 0.4903 - val_loss: 1.2383 - val_accuracy: 0.4278
# Epoch 99/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1507 - accuracy: 0.4821
# Epoch 00099: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1508 - accuracy: 0.4843 - val_loss: 1.2378 - val_accuracy: 0.4210
# Epoch 100/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1378 - accuracy: 0.5043
# Epoch 00100: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1369 - accuracy: 0.5062 - val_loss: 1.2288 - val_accuracy: 0.4605
# Epoch 101/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1450 - accuracy: 0.5093
# Epoch 00101: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1484 - accuracy: 0.5088 - val_loss: 1.2478 - val_accuracy: 0.4278
# Epoch 102/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1471 - accuracy: 0.5007
# Epoch 00102: val_loss did not improve from 1.21626
# 19/19 [==============================] - 30s 2s/step - loss: 1.1494 - accuracy: 0.5024 - val_loss: 1.2454 - val_accuracy: 0.4124
# Epoch 103/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1530 - accuracy: 0.4925
# Epoch 00103: val_loss did not improve from 1.21626
# 19/19 [==============================] - 30s 2s/step - loss: 1.1550 - accuracy: 0.4959 - val_loss: 1.2260 - val_accuracy: 0.4227
# Epoch 104/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1547 - accuracy: 0.4780
# Epoch 00104: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1571 - accuracy: 0.4792 - val_loss: 1.2456 - val_accuracy: 0.4210
# Epoch 105/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1249 - accuracy: 0.4998
# Epoch 00105: val_loss did not improve from 1.21626
# 19/19 [==============================] - 30s 2s/step - loss: 1.1251 - accuracy: 0.5002 - val_loss: 1.2240 - val_accuracy: 0.4296
# Epoch 106/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1459 - accuracy: 0.4966
# Epoch 00106: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1437 - accuracy: 0.4998 - val_loss: 1.2503 - val_accuracy: 0.4158
# Epoch 107/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1349 - accuracy: 0.5034
# Epoch 00107: val_loss did not improve from 1.21626
# 19/19 [==============================] - 31s 2s/step - loss: 1.1372 - accuracy: 0.5019 - val_loss: 1.2538 - val_accuracy: 0.4124
# Epoch 108/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1442 - accuracy: 0.5020
# Epoch 00108: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1451 - accuracy: 0.5015 - val_loss: 1.2314 - val_accuracy: 0.4055
# Epoch 109/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1384 - accuracy: 0.4993
# Epoch 00109: val_loss did not improve from 1.21626
# 19/19 [==============================] - 30s 2s/step - loss: 1.1398 - accuracy: 0.5006 - val_loss: 1.2217 - val_accuracy: 0.4519
# Epoch 110/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1409 - accuracy: 0.4966
# Epoch 00110: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1365 - accuracy: 0.4994 - val_loss: 1.2518 - val_accuracy: 0.4227
# Epoch 111/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1348 - accuracy: 0.5043
# Epoch 00111: val_loss did not improve from 1.21626
# 19/19 [==============================] - 30s 2s/step - loss: 1.1354 - accuracy: 0.5041 - val_loss: 1.2315 - val_accuracy: 0.4210
# Epoch 112/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1299 - accuracy: 0.5079
# Epoch 00112: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1323 - accuracy: 0.5084 - val_loss: 1.2490 - val_accuracy: 0.4278
# Epoch 113/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1202 - accuracy: 0.5197
# Epoch 00113: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1185 - accuracy: 0.5204 - val_loss: 1.2415 - val_accuracy: 0.4227
# Epoch 114/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1383 - accuracy: 0.5016
# Epoch 00114: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1443 - accuracy: 0.4989 - val_loss: 1.2277 - val_accuracy: 0.4381
# Epoch 115/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1257 - accuracy: 0.5084
# Epoch 00115: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1270 - accuracy: 0.5079 - val_loss: 1.2444 - val_accuracy: 0.3986
# Epoch 116/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1385 - accuracy: 0.4934
# Epoch 00116: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1403 - accuracy: 0.4925 - val_loss: 1.2581 - val_accuracy: 0.4278
# Epoch 117/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1538 - accuracy: 0.4830
# Epoch 00117: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1585 - accuracy: 0.4792 - val_loss: 1.2489 - val_accuracy: 0.4433
# Epoch 118/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1336 - accuracy: 0.5129
# Epoch 00118: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1385 - accuracy: 0.5105 - val_loss: 1.2381 - val_accuracy: 0.4364
# Epoch 119/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1307 - accuracy: 0.5197
# Epoch 00119: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1303 - accuracy: 0.5182 - val_loss: 1.2357 - val_accuracy: 0.4261
# Epoch 120/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1327 - accuracy: 0.4889
# Epoch 00120: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1321 - accuracy: 0.4908 - val_loss: 1.2276 - val_accuracy: 0.4296
# Epoch 121/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1376 - accuracy: 0.4998
# Epoch 00121: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1362 - accuracy: 0.4976 - val_loss: 1.2449 - val_accuracy: 0.4330
# Epoch 122/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1117 - accuracy: 0.5302
# Epoch 00122: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1086 - accuracy: 0.5324 - val_loss: 1.2419 - val_accuracy: 0.4570
# Epoch 123/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1284 - accuracy: 0.5135
# Epoch 00123: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1134 - accuracy: 0.5157 - val_loss: 1.2569 - val_accuracy: 0.4038
# Epoch 124/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1202 - accuracy: 0.5002
# Epoch 00124: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1201 - accuracy: 0.4981 - val_loss: 1.2414 - val_accuracy: 0.4244
# Epoch 125/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1259 - accuracy: 0.5175
# Epoch 00125: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1213 - accuracy: 0.5187 - val_loss: 1.2601 - val_accuracy: 0.3935
# Epoch 126/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1310 - accuracy: 0.5048
# Epoch 00126: val_loss did not improve from 1.21626
# 19/19 [==============================] - 30s 2s/step - loss: 1.1274 - accuracy: 0.5075 - val_loss: 1.2501 - val_accuracy: 0.4278
# Epoch 127/200
# 18/19 [===========================>..] - ETA: 1s - loss: 1.1319 - accuracy: 0.5089
# Epoch 00127: val_loss did not improve from 1.21626
# 19/19 [==============================] - 29s 2s/step - loss: 1.1319 - accuracy: 0.5079 - val_loss: 1.2665 - val_accuracy: 0.3883
# Epoch 00127: early stopping

# %%
# Save
models.save_model(resnet50_fe_drop_128, 'resnet50_fe_drop_128_4cl_end.h5')

# %%
# History of accuracy and loss
tra_loss_fe = history_resnet50_fe_drop_128.history['loss']
tra_acc_fe = history_resnet50_fe_drop_128.history['accuracy']
val_loss_fe = history_resnet50_fe_drop_128.history['val_loss']
val_acc_fe = history_resnet50_fe_drop_128.history['val_accuracy']

# %%
# Total number of epochs training
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

# Epoch when reached the validation loss minimum
opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

# Loss and accuracy on the validation set
end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

# Loss and accuracy on the test set
opt_resnet50_fe_drop_128 = models.load_model('resnet50_fe_drop_128_4cl_best.h5')
test_loss_fe, test_acc_fe = resnet50_fe_drop_128.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_resnet50_fe_drop_128.evaluate(test_images, test_labels, verbose=False)

# %%
print("resnet50 (w/ dropout, smaller FC) Feature Extraction\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid accuracy [end]: %.4f" % end_val_acc_fe)
print("Valid accuracy [opt]: %.4f" % opt_val_acc_fe)
print("Test accuracy [end]:  %.4f" % test_acc_fe)
print("Test accuracy [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# resnet50 (w/ dropout, smaller FC) Feature Extraction
#
# Epoch [end]: 127
# Epoch [opt]: 97
# Valid accuracy [end]: 0.3883
# Valid accuracy [opt]: 0.4467
# Test accuracy [end]:  0.4489
# Test accuracy [opt]:  0.4336
# Valid loss [end]: 1.2665
# Valid loss [opt]: 1.2163
# Test loss [end]:  1.1842
# Test loss [opt]:  1.1916

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet50 w/ dropout FC 128 FE accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet50 w/ dropout FC 128 FE loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %%
conv5_block3 = ['conv5_block3_1_conv', 'conv5_block3_1_bn', 'conv5_block3_1_relu', 'conv5_block3_2_conv', 'conv5_block3_2_bn','conv5_block3_2_relu', 'conv5_block3_3_conv', 'conv5_block3_3_bn', 'conv5_block3_add', 'conv5_block3_out']                   

resnet50_ft_1layer = models.load_model('resnet50_fe_drop_128_4cl_best.h5')
# Fine tuning: unfreeze the last convolutional layer
for layer in resnet50_ft_1layer.get_layer('resnet50').layers:
    if layer.name in conv5_block3:
        print('true')
        layer.trainable = True
    else:
        print('false')
        layer.trainable = False

# Recompile the model ()
resnet50_ft_1layer.compile(optimizer=optimizers.SGD(lr=1e-6, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

resnet50_ft_1layer.summary()
resnet50_ft_1layer.get_layer('resnet50').summary()
# Out:
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 8, 8, 2048)        23587712
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 131072)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 131072)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2048)              268437504
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 293,140,484
# Trainable params: 274,018,436
# Non-trainable params: 19,122,048
# _________________________________________________________________
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 262, 262, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 128, 128, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 128, 128, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 128, 128, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 130, 130, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 64, 64, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 64, 64, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 64, 64, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 64, 64, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 64, 64, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 64, 64, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 64, 64, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 64, 64, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 64, 64, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 64, 64, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 64, 64, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 64, 64, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 64, 64, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 64, 64, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 64, 64, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 64, 64, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 64, 64, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 64, 64, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 64, 64, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 64, 64, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 64, 64, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 64, 64, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 64, 64, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 32, 32, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 32, 32, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 32, 32, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 32, 32, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 32, 32, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 32, 32, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 32, 32, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 32, 32, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 32, 32, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 32, 32, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 32, 32, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 32, 32, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 32, 32, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 32, 32, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 32, 32, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 32, 32, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 32, 32, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 32, 32, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 32, 32, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 32, 32, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 32, 32, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 16, 16, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 16, 16, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 16, 16, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 16, 16, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 16, 16, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 16, 16, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 16, 16, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 16, 16, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 16, 16, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 16, 16, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 16, 16, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 16, 16, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 16, 16, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 16, 16, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 16, 16, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 16, 16, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 16, 16, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 16, 16, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 16, 16, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 16, 16, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 16, 16, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 16, 16, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 16, 16, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 16, 16, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 16, 16, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 16, 16, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 8, 8, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 8, 8, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 8, 8, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 8, 8, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 8, 8, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 8, 8, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 8, 8, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 8, 8, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 8, 8, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 8, 8, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 8, 8, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 8, 8, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 8, 8, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 8, 8, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 8, 8, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 8, 8, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 8, 8, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 8, 8, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 8, 8, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 8, 8, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 8, 8, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 8, 8, 2048)   0           conv5_block3_add[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 4,465,664
# Non-trainable params: 19,122,048
# __________________________________________________________________________________________________

# %%
# Callback for early-stopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

# Callback for checkpointing
checkpoint = ModelCheckpoint(
        'resnet50_ft_1layer_4cl_best.h5',
        monitor='val_loss',
        mode='min',
        verbose=1, 
        save_best_only=True, 
        save_freq='epoch')

# %%
# Train
history_ft = resnet50_ft_1layer.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=200,
        validation_data=validation_generator,
        callbacks=[early_stop, checkpoint],
        shuffle=True,
        verbose=1,
        initial_epoch=0)
# Out:
# WARNING:tensorflow:From <ipython-input-7-3e36c7e71dc5>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 11 steps, validate for 5 steps
# Epoch 1/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1604 - accuracy: 0.4828
# Epoch 00001: val_loss improved from inf to 1.26494, saving model to resnet50_ft_1layer_4cl_best.h5
# 11/11 [==============================] - 27s 2s/step - loss: 1.1595 - accuracy: 0.4879 - val_loss: 1.2649 - val_accuracy: 0.4124
# Epoch 2/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1356 - accuracy: 0.4733
# Epoch 00002: val_loss improved from 1.26494 to 1.24532, saving model to resnet50_ft_1layer_4cl_best.h5
# 11/11 [==============================] - 23s 2s/step - loss: 1.1415 - accuracy: 0.4728 - val_loss: 1.2453 - val_accuracy: 0.4416
# Epoch 3/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1541 - accuracy: 0.4859
# Epoch 00003: val_loss did not improve from 1.24532
# 11/11 [==============================] - 21s 2s/step - loss: 1.1608 - accuracy: 0.4858 - val_loss: 1.2532 - val_accuracy: 0.4536
# Epoch 4/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1165 - accuracy: 0.4877
# Epoch 00004: val_loss improved from 1.24532 to 1.24181, saving model to resnet50_ft_1layer_4cl_best.h5
# 11/11 [==============================] - 23s 2s/step - loss: 1.1285 - accuracy: 0.4843 - val_loss: 1.2418 - val_accuracy: 0.4502
# Epoch 5/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1352 - accuracy: 0.5047
# Epoch 00005: val_loss did not improve from 1.24181
# 11/11 [==============================] - 20s 2s/step - loss: 1.1426 - accuracy: 0.5050 - val_loss: 1.2545 - val_accuracy: 0.4364
# Epoch 6/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1855 - accuracy: 0.4547
# Epoch 00006: val_loss did not improve from 1.24181
# 11/11 [==============================] - 20s 2s/step - loss: 1.1768 - accuracy: 0.4631 - val_loss: 1.2515 - val_accuracy: 0.4570
# Epoch 7/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1539 - accuracy: 0.4741
# Epoch 00007: val_loss did not improve from 1.24181
# 11/11 [==============================] - 19s 2s/step - loss: 1.1628 - accuracy: 0.4713 - val_loss: 1.2439 - val_accuracy: 0.4313
# Epoch 8/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1798 - accuracy: 0.4750
# Epoch 00008: val_loss did not improve from 1.24181
# 11/11 [==============================] - 20s 2s/step - loss: 1.1692 - accuracy: 0.4744 - val_loss: 1.2609 - val_accuracy: 0.4296
# Epoch 9/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1711 - accuracy: 0.4665
# Epoch 00009: val_loss did not improve from 1.24181
# 11/11 [==============================] - 20s 2s/step - loss: 1.1695 - accuracy: 0.4698 - val_loss: 1.2604 - val_accuracy: 0.4124
# Epoch 10/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1545 - accuracy: 0.4673
# Epoch 00010: val_loss did not improve from 1.24181
# 11/11 [==============================] - 19s 2s/step - loss: 1.1655 - accuracy: 0.4629 - val_loss: 1.2434 - val_accuracy: 0.4656
# Epoch 11/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1421 - accuracy: 0.4911
# Epoch 00011: val_loss did not improve from 1.24181
# 11/11 [==============================] - 19s 2s/step - loss: 1.1547 - accuracy: 0.4836 - val_loss: 1.2487 - val_accuracy: 0.4519
# Epoch 12/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1791 - accuracy: 0.4648
# Epoch 00012: val_loss improved from 1.24181 to 1.24065, saving model to resnet50_ft_1layer_4cl_best.h5
# 11/11 [==============================] - 24s 2s/step - loss: 1.1801 - accuracy: 0.4682 - val_loss: 1.2407 - val_accuracy: 0.4467
# Epoch 13/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1741 - accuracy: 0.4820
# Epoch 00013: val_loss did not improve from 1.24065
# 11/11 [==============================] - 20s 2s/step - loss: 1.1772 - accuracy: 0.4744 - val_loss: 1.2480 - val_accuracy: 0.4416
# Epoch 14/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1871 - accuracy: 0.4877
# Epoch 00014: val_loss improved from 1.24065 to 1.21370, saving model to resnet50_ft_1layer_4cl_best.h5
# 11/11 [==============================] - 23s 2s/step - loss: 1.1781 - accuracy: 0.4927 - val_loss: 1.2137 - val_accuracy: 0.4742
# Epoch 15/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1549 - accuracy: 0.4818
# Epoch 00015: val_loss did not improve from 1.21370
# 11/11 [==============================] - 21s 2s/step - loss: 1.1537 - accuracy: 0.4813 - val_loss: 1.2524 - val_accuracy: 0.4278
# Epoch 16/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1684 - accuracy: 0.4818
# Epoch 00016: val_loss did not improve from 1.21370
# 11/11 [==============================] - 20s 2s/step - loss: 1.1723 - accuracy: 0.4820 - val_loss: 1.2652 - val_accuracy: 0.4038
# Epoch 17/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.2114 - accuracy: 0.4695
# Epoch 00017: val_loss did not improve from 1.21370
# 11/11 [==============================] - 20s 2s/step - loss: 1.2220 - accuracy: 0.4673 - val_loss: 1.2344 - val_accuracy: 0.4519
# Epoch 18/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1302 - accuracy: 0.5038
# Epoch 00018: val_loss did not improve from 1.21370
# 11/11 [==============================] - 20s 2s/step - loss: 1.1379 - accuracy: 0.4912 - val_loss: 1.2568 - val_accuracy: 0.4347
# Epoch 19/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1754 - accuracy: 0.4665
# Epoch 00019: val_loss did not improve from 1.21370
# 11/11 [==============================] - 22s 2s/step - loss: 1.1749 - accuracy: 0.4660 - val_loss: 1.2614 - val_accuracy: 0.4381
# Epoch 20/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1587 - accuracy: 0.4614
# Epoch 00020: val_loss did not improve from 1.21370
# 11/11 [==============================] - 20s 2s/step - loss: 1.1580 - accuracy: 0.4667 - val_loss: 1.2399 - val_accuracy: 0.4433
# Epoch 21/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1323 - accuracy: 0.4970
# Epoch 00021: val_loss did not improve from 1.21370
# 11/11 [==============================] - 19s 2s/step - loss: 1.1407 - accuracy: 0.4935 - val_loss: 1.2633 - val_accuracy: 0.4502
# Epoch 22/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1537 - accuracy: 0.4775
# Epoch 00022: val_loss did not improve from 1.21370
# 11/11 [==============================] - 19s 2s/step - loss: 1.1579 - accuracy: 0.4721 - val_loss: 1.2484 - val_accuracy: 0.4622
# Epoch 23/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1636 - accuracy: 0.4521
# Epoch 00023: val_loss did not improve from 1.21370
# 11/11 [==============================] - 19s 2s/step - loss: 1.1691 - accuracy: 0.4529 - val_loss: 1.2543 - val_accuracy: 0.4519
# Epoch 24/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1451 - accuracy: 0.4936
# Epoch 00024: val_loss did not improve from 1.21370
# 11/11 [==============================] - 19s 2s/step - loss: 1.1521 - accuracy: 0.4904 - val_loss: 1.2346 - val_accuracy: 0.4485
# Epoch 25/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1651 - accuracy: 0.4919
# Epoch 00025: val_loss did not improve from 1.21370
# 11/11 [==============================] - 20s 2s/step - loss: 1.1674 - accuracy: 0.4912 - val_loss: 1.2546 - val_accuracy: 0.4347
# Epoch 26/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1319 - accuracy: 0.4979
# Epoch 00026: val_loss did not improve from 1.21370
# 11/11 [==============================] - 20s 2s/step - loss: 1.1337 - accuracy: 0.4950 - val_loss: 1.2336 - val_accuracy: 0.4450
# Epoch 27/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1636 - accuracy: 0.4818
# Epoch 00027: val_loss did not improve from 1.21370
# 11/11 [==============================] - 20s 2s/step - loss: 1.1698 - accuracy: 0.4759 - val_loss: 1.2201 - val_accuracy: 0.4502
# Epoch 28/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1521 - accuracy: 0.4877
# Epoch 00028: val_loss did not improve from 1.21370
# 11/11 [==============================] - 21s 2s/step - loss: 1.1436 - accuracy: 0.4966 - val_loss: 1.2592 - val_accuracy: 0.4038
# Epoch 29/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1564 - accuracy: 0.4953
# Epoch 00029: val_loss did not improve from 1.21370
# 11/11 [==============================] - 20s 2s/step - loss: 1.1487 - accuracy: 0.4973 - val_loss: 1.2548 - val_accuracy: 0.4278
# Epoch 30/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1668 - accuracy: 0.4724
# Epoch 00030: val_loss did not improve from 1.21370
# 11/11 [==============================] - 20s 2s/step - loss: 1.1668 - accuracy: 0.4782 - val_loss: 1.2610 - val_accuracy: 0.4278
# Epoch 31/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1908 - accuracy: 0.4766
# Epoch 00031: val_loss did not improve from 1.21370
# 11/11 [==============================] - 21s 2s/step - loss: 1.1862 - accuracy: 0.4737 - val_loss: 1.2788 - val_accuracy: 0.4192
# Epoch 32/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1762 - accuracy: 0.4860
# Epoch 00032: val_loss did not improve from 1.21370
# 11/11 [==============================] - 20s 2s/step - loss: 1.1688 - accuracy: 0.4874 - val_loss: 1.2611 - val_accuracy: 0.4192
# Epoch 33/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1631 - accuracy: 0.4953
# Epoch 00033: val_loss did not improve from 1.21370
# 11/11 [==============================] - 20s 2s/step - loss: 1.1718 - accuracy: 0.4936 - val_loss: 1.2515 - val_accuracy: 0.4381
# Epoch 34/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1384 - accuracy: 0.4919
# Epoch 00034: val_loss did not improve from 1.21370
# 11/11 [==============================] - 20s 2s/step - loss: 1.1384 - accuracy: 0.4897 - val_loss: 1.2542 - val_accuracy: 0.4210
# Epoch 35/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1411 - accuracy: 0.5013
# Epoch 00035: val_loss did not improve from 1.21370
# 11/11 [==============================] - 19s 2s/step - loss: 1.1470 - accuracy: 0.4989 - val_loss: 1.2529 - val_accuracy: 0.4347
# Epoch 36/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1639 - accuracy: 0.4844
# Epoch 00036: val_loss improved from 1.21370 to 1.21293, saving model to resnet50_ft_1layer_4cl_best.h5
# 11/11 [==============================] - 24s 2s/step - loss: 1.1458 - accuracy: 0.4950 - val_loss: 1.2129 - val_accuracy: 0.4433
# Epoch 37/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1416 - accuracy: 0.4914
# Epoch 00037: val_loss did not improve from 1.21293
# 11/11 [==============================] - 22s 2s/step - loss: 1.1447 - accuracy: 0.4893 - val_loss: 1.2453 - val_accuracy: 0.4691
# Epoch 38/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1860 - accuracy: 0.4672
# Epoch 00038: val_loss did not improve from 1.21293
# 11/11 [==============================] - 20s 2s/step - loss: 1.1748 - accuracy: 0.4744 - val_loss: 1.2493 - val_accuracy: 0.4381
# Epoch 39/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1681 - accuracy: 0.4673
# Epoch 00039: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1705 - accuracy: 0.4660 - val_loss: 1.2731 - val_accuracy: 0.3900
# Epoch 40/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1443 - accuracy: 0.4928
# Epoch 00040: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1392 - accuracy: 0.4950 - val_loss: 1.2291 - val_accuracy: 0.4210
# Epoch 41/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1568 - accuracy: 0.4928
# Epoch 00041: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1578 - accuracy: 0.4927 - val_loss: 1.2589 - val_accuracy: 0.4347
# Epoch 42/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1838 - accuracy: 0.4656
# Epoch 00042: val_loss did not improve from 1.21293
# 11/11 [==============================] - 20s 2s/step - loss: 1.1787 - accuracy: 0.4737 - val_loss: 1.2252 - val_accuracy: 0.4433
# Epoch 43/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1289 - accuracy: 0.5089
# Epoch 00043: val_loss did not improve from 1.21293
# 11/11 [==============================] - 20s 2s/step - loss: 1.1421 - accuracy: 0.5027 - val_loss: 1.2365 - val_accuracy: 0.4313
# Epoch 44/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1541 - accuracy: 0.4869
# Epoch 00044: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1583 - accuracy: 0.4874 - val_loss: 1.2386 - val_accuracy: 0.4519
# Epoch 45/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1290 - accuracy: 0.4885
# Epoch 00045: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1255 - accuracy: 0.4889 - val_loss: 1.2568 - val_accuracy: 0.4381
# Epoch 46/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1690 - accuracy: 0.4906
# Epoch 00046: val_loss did not improve from 1.21293
# 11/11 [==============================] - 20s 2s/step - loss: 1.1604 - accuracy: 0.4957 - val_loss: 1.2632 - val_accuracy: 0.4072
# Epoch 47/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1725 - accuracy: 0.4695
# Epoch 00047: val_loss did not improve from 1.21293
# 11/11 [==============================] - 20s 2s/step - loss: 1.1851 - accuracy: 0.4666 - val_loss: 1.2460 - val_accuracy: 0.4622
# Epoch 48/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1416 - accuracy: 0.5123
# Epoch 00048: val_loss did not improve from 1.21293
# 11/11 [==============================] - 20s 2s/step - loss: 1.1537 - accuracy: 0.5050 - val_loss: 1.2239 - val_accuracy: 0.4674
# Epoch 49/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1498 - accuracy: 0.4898
# Epoch 00049: val_loss did not improve from 1.21293
# 11/11 [==============================] - 20s 2s/step - loss: 1.1479 - accuracy: 0.4922 - val_loss: 1.2553 - val_accuracy: 0.4313
# Epoch 50/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1533 - accuracy: 0.4648
# Epoch 00050: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1636 - accuracy: 0.4598 - val_loss: 1.2419 - val_accuracy: 0.4347
# Epoch 51/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1558 - accuracy: 0.4835
# Epoch 00051: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1712 - accuracy: 0.4774 - val_loss: 1.2369 - val_accuracy: 0.4244
# Epoch 52/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1403 - accuracy: 0.5016
# Epoch 00052: val_loss did not improve from 1.21293
# 11/11 [==============================] - 20s 2s/step - loss: 1.1362 - accuracy: 0.5007 - val_loss: 1.2655 - val_accuracy: 0.4347
# Epoch 53/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1395 - accuracy: 0.4852
# Epoch 00053: val_loss did not improve from 1.21293
# 11/11 [==============================] - 20s 2s/step - loss: 1.1396 - accuracy: 0.4866 - val_loss: 1.2319 - val_accuracy: 0.4467
# Epoch 54/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1159 - accuracy: 0.5064
# Epoch 00054: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1211 - accuracy: 0.5057 - val_loss: 1.2532 - val_accuracy: 0.4055
# Epoch 55/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1692 - accuracy: 0.4688
# Epoch 00055: val_loss did not improve from 1.21293
# 11/11 [==============================] - 20s 2s/step - loss: 1.1665 - accuracy: 0.4730 - val_loss: 1.2801 - val_accuracy: 0.4416
# Epoch 56/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1553 - accuracy: 0.4911
# Epoch 00056: val_loss did not improve from 1.21293
# 11/11 [==============================] - 20s 2s/step - loss: 1.1547 - accuracy: 0.4943 - val_loss: 1.2273 - val_accuracy: 0.4519
# Epoch 57/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1529 - accuracy: 0.4945
# Epoch 00057: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1759 - accuracy: 0.4851 - val_loss: 1.2482 - val_accuracy: 0.4313
# Epoch 58/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1510 - accuracy: 0.4911
# Epoch 00058: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1484 - accuracy: 0.4889 - val_loss: 1.2319 - val_accuracy: 0.4570
# Epoch 59/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1516 - accuracy: 0.4852
# Epoch 00059: val_loss did not improve from 1.21293
# 11/11 [==============================] - 20s 2s/step - loss: 1.1540 - accuracy: 0.4830 - val_loss: 1.2249 - val_accuracy: 0.4570
# Epoch 60/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1383 - accuracy: 0.4767
# Epoch 00060: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1427 - accuracy: 0.4751 - val_loss: 1.2559 - val_accuracy: 0.4433
# Epoch 61/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1543 - accuracy: 0.4781
# Epoch 00061: val_loss did not improve from 1.21293
# 11/11 [==============================] - 20s 2s/step - loss: 1.1530 - accuracy: 0.4794 - val_loss: 1.2349 - val_accuracy: 0.4330
# Epoch 62/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1415 - accuracy: 0.4758
# Epoch 00062: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1453 - accuracy: 0.4797 - val_loss: 1.2334 - val_accuracy: 0.4485
# Epoch 63/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1441 - accuracy: 0.5021
# Epoch 00063: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1468 - accuracy: 0.5034 - val_loss: 1.2570 - val_accuracy: 0.4296
# Epoch 64/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1556 - accuracy: 0.4898
# Epoch 00064: val_loss did not improve from 1.21293
# 11/11 [==============================] - 20s 2s/step - loss: 1.1640 - accuracy: 0.4822 - val_loss: 1.2626 - val_accuracy: 0.4244
# Epoch 65/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1481 - accuracy: 0.4869
# Epoch 00065: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1526 - accuracy: 0.4866 - val_loss: 1.2429 - val_accuracy: 0.4364
# Epoch 66/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1590 - accuracy: 0.4894
# Epoch 00066: val_loss did not improve from 1.21293
# 11/11 [==============================] - 19s 2s/step - loss: 1.1488 - accuracy: 0.4935 - val_loss: 1.2416 - val_accuracy: 0.4399
# Epoch 00066: early stopping

# %%
# Save
models.save_model(resnet50_ft_1layer, 'resnet50_ft_1layer_4cl_end.h5')

# %%
# History of accuracy and loss
tra_loss_fe = history_ft.history['loss']
tra_acc_fe = history_ft.history['accuracy']
val_loss_fe = history_ft.history['val_loss']
val_acc_fe = history_ft.history['val_accuracy']

# Total number of epochs training
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

# Epoch when reached the validation loss minimum
opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

# Loss and accuracy on the validation set
end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]

# Loss and accuracy on the test set
opt_resnet50_ft_1layer = models.load_model('resnet50_ft_1layer_4cl_best.h5')
test_loss_fe, test_acc_fe = resnet50_ft_1layer.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_resnet50_ft_1layer.evaluate(test_images, test_labels, verbose=False)

print("resnet50 Fine Tuning\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid accuracy [end]: %.4f" % end_val_acc_fe)
print("Valid accuracy [opt]: %.4f" % opt_val_acc_fe)
print("Test accuracy [end]:  %.4f" % test_acc_fe)
print("Test accuracy [opt]:  %.4f" % opt_test_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# resnet50 Fine Tuning
#
# Epoch [end]: 66
# Epoch [opt]: 36
# Valid accuracy [end]: 0.4399
# Valid accuracy [opt]: 0.4433
# Test accuracy [end]:  0.4351
# Test accuracy [opt]:  0.4382
# Valid loss [end]: 1.2416
# Valid loss [opt]: 1.2129
# Test loss [end]:  1.2081
# Test loss [opt]:  1.2076

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet50 FT accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet50 FT loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %%
resnet50_ft_2layer = models.load_model('resnet50_ft_1layer_4cl_best.h5')
# Fine tuning: unfreeze the last convolutional layer
for layer in resnet50_ft_1layer.get_layer('resnet50').layers:
    if layer.name in ('conv5_block3_3_conv', 'conv5_block3_3_bn'):
        print('true')
        layer.trainable = True
    else:
        print('false')
        layer.trainable = False

# Recompile the model ()
resnet50_ft_2layer.compile(optimizer=optimizers.SGD(lr=1e-4, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

resnet50_ft_2layer.summary()
resnet50_ft_2layer.get_layer('resnet50').summary()
# Out:
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# false
# true
# true
# false
# false
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 8, 8, 2048)        23587712
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 131072)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 131072)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2048)              268437504
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 293,140,484
# Trainable params: 269,556,868
# Non-trainable params: 23,583,616
# _________________________________________________________________
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 262, 262, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 128, 128, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 128, 128, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 128, 128, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 130, 130, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 64, 64, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 64, 64, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 64, 64, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 64, 64, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 64, 64, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 64, 64, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 64, 64, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 64, 64, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 64, 64, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 64, 64, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 64, 64, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 64, 64, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 64, 64, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 64, 64, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 64, 64, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 64, 64, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 64, 64, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 64, 64, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 64, 64, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 64, 64, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 64, 64, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 64, 64, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 64, 64, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 64, 64, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 64, 64, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 32, 32, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 32, 32, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 32, 32, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 32, 32, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 32, 32, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 32, 32, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 32, 32, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 32, 32, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 32, 32, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 32, 32, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 32, 32, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 32, 32, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 32, 32, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 32, 32, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 32, 32, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 32, 32, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 32, 32, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 32, 32, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 32, 32, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 32, 32, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 32, 32, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 32, 32, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 32, 32, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 32, 32, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 16, 16, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 16, 16, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 16, 16, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 16, 16, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 16, 16, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 16, 16, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 16, 16, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 16, 16, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 16, 16, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 16, 16, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 16, 16, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 16, 16, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 16, 16, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 16, 16, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 16, 16, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 16, 16, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 16, 16, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 16, 16, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 16, 16, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 16, 16, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 16, 16, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 16, 16, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 16, 16, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 16, 16, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 16, 16, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 16, 16, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 16, 16, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 16, 16, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 16, 16, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 16, 16, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 16, 16, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 8, 8, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 8, 8, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 8, 8, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 8, 8, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 8, 8, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 8, 8, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 8, 8, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 8, 8, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 8, 8, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 8, 8, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 8, 8, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 8, 8, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 8, 8, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 8, 8, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 8, 8, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 8, 8, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 8, 8, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 8, 8, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 8, 8, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 8, 8, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 8, 8, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 8, 8, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 8, 8, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 8, 8, 2048)   0           conv5_block3_add[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 4,096
# Non-trainable params: 23,583,616
# __________________________________________________________________________________________________

# %%
# Callback for early-stopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=30, verbose=1)

# Callback for checkpointing
checkpoint = ModelCheckpoint(
        'resnet50_ft_2layer_4cl_best.h5',
        monitor='val_loss',
        mode='min',
        verbose=1, 
        save_best_only=True, 
        save_freq='epoch')

# %%
# Train
history_ft_2layer = resnet50_ft_2layer.fit_generator(
        train_generator,
        steps_per_epoch=n_train_img // 256,
        epochs=200,
        validation_data=validation_generator,
        callbacks=[early_stop, checkpoint],
        shuffle=True,
        verbose=1,
        initial_epoch=0)
# Out:
# WARNING:tensorflow:From <ipython-input-10-06f67946cbb5>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 11 steps, validate for 5 steps
# Epoch 1/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1622 - accuracy: 0.4867
# Epoch 00001: val_loss improved from inf to 1.25658, saving model to resnet50_ft_2layer_4cl_best.h5
# 11/11 [==============================] - 26s 2s/step - loss: 1.1561 - accuracy: 0.4874 - val_loss: 1.2566 - val_accuracy: 0.4347
# Epoch 2/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1523 - accuracy: 0.5016
# Epoch 00002: val_loss did not improve from 1.25658
# 11/11 [==============================] - 21s 2s/step - loss: 1.1546 - accuracy: 0.4979 - val_loss: 1.2610 - val_accuracy: 0.3935
# Epoch 3/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1581 - accuracy: 0.5008
# Epoch 00003: val_loss improved from 1.25658 to 1.25601, saving model to resnet50_ft_2layer_4cl_best.h5
# 11/11 [==============================] - 24s 2s/step - loss: 1.1653 - accuracy: 0.4936 - val_loss: 1.2560 - val_accuracy: 0.4003
# Epoch 4/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1418 - accuracy: 0.5086
# Epoch 00004: val_loss did not improve from 1.25601
# 11/11 [==============================] - 20s 2s/step - loss: 1.1438 - accuracy: 0.5064 - val_loss: 1.2637 - val_accuracy: 0.4278
# Epoch 5/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1466 - accuracy: 0.5117
# Epoch 00005: val_loss improved from 1.25601 to 1.24082, saving model to resnet50_ft_2layer_4cl_best.h5
# 11/11 [==============================] - 24s 2s/step - loss: 1.1589 - accuracy: 0.4986 - val_loss: 1.2408 - val_accuracy: 0.4485
# Epoch 6/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1201 - accuracy: 0.5195
# Epoch 00006: val_loss did not improve from 1.24082
# 11/11 [==============================] - 20s 2s/step - loss: 1.1255 - accuracy: 0.5149 - val_loss: 1.2415 - val_accuracy: 0.4519
# Epoch 7/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1371 - accuracy: 0.5000
# Epoch 00007: val_loss did not improve from 1.24082
# 11/11 [==============================] - 20s 2s/step - loss: 1.1342 - accuracy: 0.5057 - val_loss: 1.2473 - val_accuracy: 0.4227
# Epoch 8/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1235 - accuracy: 0.5199
# Epoch 00008: val_loss improved from 1.24082 to 1.23297, saving model to resnet50_ft_2layer_4cl_best.h5
# 11/11 [==============================] - 23s 2s/step - loss: 1.1241 - accuracy: 0.5134 - val_loss: 1.2330 - val_accuracy: 0.4570
# Epoch 9/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1419 - accuracy: 0.5021
# Epoch 00009: val_loss did not improve from 1.23297
# 11/11 [==============================] - 19s 2s/step - loss: 1.1369 - accuracy: 0.5050 - val_loss: 1.2579 - val_accuracy: 0.4210
# Epoch 10/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1629 - accuracy: 0.4877
# Epoch 00010: val_loss did not improve from 1.23297
# 11/11 [==============================] - 20s 2s/step - loss: 1.1687 - accuracy: 0.4874 - val_loss: 1.2564 - val_accuracy: 0.4536
# Epoch 11/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1471 - accuracy: 0.5016
# Epoch 00011: val_loss did not improve from 1.23297
# 11/11 [==============================] - 20s 2s/step - loss: 1.1507 - accuracy: 0.5021 - val_loss: 1.2653 - val_accuracy: 0.4244
# Epoch 12/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1369 - accuracy: 0.5030
# Epoch 00012: val_loss did not improve from 1.23297
# 11/11 [==============================] - 19s 2s/step - loss: 1.1393 - accuracy: 0.5019 - val_loss: 1.2342 - val_accuracy: 0.4553
# Epoch 13/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1431 - accuracy: 0.5047
# Epoch 00013: val_loss did not improve from 1.23297
# 11/11 [==============================] - 19s 2s/step - loss: 1.1404 - accuracy: 0.5011 - val_loss: 1.2799 - val_accuracy: 0.4313
# Epoch 14/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1268 - accuracy: 0.5227
# Epoch 00014: val_loss improved from 1.23297 to 1.23197, saving model to resnet50_ft_2layer_4cl_best.h5
# 11/11 [==============================] - 24s 2s/step - loss: 1.1264 - accuracy: 0.5192 - val_loss: 1.2320 - val_accuracy: 0.4605
# Epoch 15/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1256 - accuracy: 0.5109
# Epoch 00015: val_loss improved from 1.23197 to 1.22841, saving model to resnet50_ft_2layer_4cl_best.h5
# 11/11 [==============================] - 24s 2s/step - loss: 1.1254 - accuracy: 0.5135 - val_loss: 1.2284 - val_accuracy: 0.4485
# Epoch 16/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1305 - accuracy: 0.4922
# Epoch 00016: val_loss did not improve from 1.22841
# 11/11 [==============================] - 19s 2s/step - loss: 1.1234 - accuracy: 0.4935 - val_loss: 1.2693 - val_accuracy: 0.4244
# Epoch 17/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1243 - accuracy: 0.5180
# Epoch 00017: val_loss did not improve from 1.22841
# 11/11 [==============================] - 21s 2s/step - loss: 1.1308 - accuracy: 0.5099 - val_loss: 1.2502 - val_accuracy: 0.4450
# Epoch 18/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1518 - accuracy: 0.4996
# Epoch 00018: val_loss did not improve from 1.22841
# 11/11 [==============================] - 20s 2s/step - loss: 1.1517 - accuracy: 0.4996 - val_loss: 1.2462 - val_accuracy: 0.4330
# Epoch 19/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1212 - accuracy: 0.4996
# Epoch 00019: val_loss improved from 1.22841 to 1.22681, saving model to resnet50_ft_2layer_4cl_best.h5
# 11/11 [==============================] - 23s 2s/step - loss: 1.1201 - accuracy: 0.5057 - val_loss: 1.2268 - val_accuracy: 0.4759
# Epoch 20/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1419 - accuracy: 0.4859
# Epoch 00020: val_loss did not improve from 1.22681
# 11/11 [==============================] - 21s 2s/step - loss: 1.1422 - accuracy: 0.4851 - val_loss: 1.2429 - val_accuracy: 0.4347
# Epoch 21/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1277 - accuracy: 0.5148
# Epoch 00021: val_loss did not improve from 1.22681
# 11/11 [==============================] - 19s 2s/step - loss: 1.1310 - accuracy: 0.5126 - val_loss: 1.2551 - val_accuracy: 0.4244
# Epoch 22/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1440 - accuracy: 0.5023
# Epoch 00022: val_loss did not improve from 1.22681
# 11/11 [==============================] - 20s 2s/step - loss: 1.1478 - accuracy: 0.4993 - val_loss: 1.2601 - val_accuracy: 0.4210
# Epoch 23/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1257 - accuracy: 0.5008
# Epoch 00023: val_loss did not improve from 1.22681
# 11/11 [==============================] - 21s 2s/step - loss: 1.1312 - accuracy: 0.4936 - val_loss: 1.2382 - val_accuracy: 0.4347
# Epoch 24/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1386 - accuracy: 0.5008
# Epoch 00024: val_loss did not improve from 1.22681
# 11/11 [==============================] - 20s 2s/step - loss: 1.1422 - accuracy: 0.4972 - val_loss: 1.2395 - val_accuracy: 0.4330
# Epoch 25/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1347 - accuracy: 0.5023
# Epoch 00025: val_loss did not improve from 1.22681
# 11/11 [==============================] - 21s 2s/step - loss: 1.1353 - accuracy: 0.5043 - val_loss: 1.2509 - val_accuracy: 0.4588
# Epoch 26/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1081 - accuracy: 0.5109
# Epoch 00026: val_loss did not improve from 1.22681
# 11/11 [==============================] - 21s 2s/step - loss: 1.1050 - accuracy: 0.5135 - val_loss: 1.2377 - val_accuracy: 0.4622
# Epoch 27/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1387 - accuracy: 0.4992
# Epoch 00027: val_loss did not improve from 1.22681
# 11/11 [==============================] - 20s 2s/step - loss: 1.1421 - accuracy: 0.4972 - val_loss: 1.2650 - val_accuracy: 0.4175
# Epoch 28/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1236 - accuracy: 0.5013
# Epoch 00028: val_loss did not improve from 1.22681
# 11/11 [==============================] - 20s 2s/step - loss: 1.1261 - accuracy: 0.4989 - val_loss: 1.2620 - val_accuracy: 0.4467
# Epoch 29/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1447 - accuracy: 0.5156
# Epoch 00029: val_loss did not improve from 1.22681
# 11/11 [==============================] - 20s 2s/step - loss: 1.1479 - accuracy: 0.5078 - val_loss: 1.2302 - val_accuracy: 0.4416
# Epoch 30/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1476 - accuracy: 0.4987
# Epoch 00030: val_loss did not improve from 1.22681
# 11/11 [==============================] - 20s 2s/step - loss: 1.1452 - accuracy: 0.5019 - val_loss: 1.2338 - val_accuracy: 0.4158
# Epoch 31/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1375 - accuracy: 0.4852
# Epoch 00031: val_loss did not improve from 1.22681
# 11/11 [==============================] - 19s 2s/step - loss: 1.1359 - accuracy: 0.4927 - val_loss: 1.2664 - val_accuracy: 0.4433
# Epoch 32/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1412 - accuracy: 0.5125
# Epoch 00032: val_loss did not improve from 1.22681
# 11/11 [==============================] - 20s 2s/step - loss: 1.1345 - accuracy: 0.5107 - val_loss: 1.2516 - val_accuracy: 0.4347
# Epoch 33/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.0855 - accuracy: 0.5174
# Epoch 00033: val_loss improved from 1.22681 to 1.21066, saving model to resnet50_ft_2layer_4cl_best.h5
# 11/11 [==============================] - 23s 2s/step - loss: 1.0922 - accuracy: 0.5134 - val_loss: 1.2107 - val_accuracy: 0.4536
# Epoch 34/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1277 - accuracy: 0.5157
# Epoch 00034: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1408 - accuracy: 0.5149 - val_loss: 1.2237 - val_accuracy: 0.4192
# Epoch 35/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1570 - accuracy: 0.5000
# Epoch 00035: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1541 - accuracy: 0.5028 - val_loss: 1.2441 - val_accuracy: 0.4485
# Epoch 36/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1486 - accuracy: 0.5000
# Epoch 00036: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1469 - accuracy: 0.4993 - val_loss: 1.2508 - val_accuracy: 0.4296
# Epoch 37/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1470 - accuracy: 0.4852
# Epoch 00037: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1374 - accuracy: 0.4897 - val_loss: 1.2588 - val_accuracy: 0.4296
# Epoch 38/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1305 - accuracy: 0.5094
# Epoch 00038: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1305 - accuracy: 0.5092 - val_loss: 1.2397 - val_accuracy: 0.4296
# Epoch 39/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1312 - accuracy: 0.4784
# Epoch 00039: val_loss did not improve from 1.21066
# 11/11 [==============================] - 19s 2s/step - loss: 1.1230 - accuracy: 0.4904 - val_loss: 1.2416 - val_accuracy: 0.4278
# Epoch 40/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1419 - accuracy: 0.4977
# Epoch 00040: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1410 - accuracy: 0.5014 - val_loss: 1.2451 - val_accuracy: 0.4467
# Epoch 41/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1049 - accuracy: 0.5030
# Epoch 00041: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1065 - accuracy: 0.5027 - val_loss: 1.2584 - val_accuracy: 0.4021
# Epoch 42/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1428 - accuracy: 0.5004
# Epoch 00042: val_loss did not improve from 1.21066
# 11/11 [==============================] - 19s 2s/step - loss: 1.1368 - accuracy: 0.5042 - val_loss: 1.2313 - val_accuracy: 0.4227
# Epoch 43/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1134 - accuracy: 0.5227
# Epoch 00043: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1105 - accuracy: 0.5249 - val_loss: 1.2230 - val_accuracy: 0.4485
# Epoch 44/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.0919 - accuracy: 0.5422
# Epoch 00044: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1024 - accuracy: 0.5334 - val_loss: 1.2517 - val_accuracy: 0.4330
# Epoch 45/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1352 - accuracy: 0.5070
# Epoch 00045: val_loss did not improve from 1.21066
# 11/11 [==============================] - 19s 2s/step - loss: 1.1367 - accuracy: 0.5088 - val_loss: 1.2622 - val_accuracy: 0.4399
# Epoch 46/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1272 - accuracy: 0.5123
# Epoch 00046: val_loss did not improve from 1.21066
# 11/11 [==============================] - 19s 2s/step - loss: 1.1357 - accuracy: 0.5080 - val_loss: 1.2650 - val_accuracy: 0.4244
# Epoch 47/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1057 - accuracy: 0.5216
# Epoch 00047: val_loss did not improve from 1.21066
# 11/11 [==============================] - 19s 2s/step - loss: 1.1142 - accuracy: 0.5157 - val_loss: 1.2364 - val_accuracy: 0.4519
# Epoch 48/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1158 - accuracy: 0.5225
# Epoch 00048: val_loss did not improve from 1.21066
# 11/11 [==============================] - 19s 2s/step - loss: 1.1126 - accuracy: 0.5226 - val_loss: 1.2342 - val_accuracy: 0.4708
# Epoch 49/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1096 - accuracy: 0.5180
# Epoch 00049: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1161 - accuracy: 0.5185 - val_loss: 1.2394 - val_accuracy: 0.4364
# Epoch 50/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1381 - accuracy: 0.5180
# Epoch 00050: val_loss did not improve from 1.21066
# 11/11 [==============================] - 21s 2s/step - loss: 1.1301 - accuracy: 0.5220 - val_loss: 1.2476 - val_accuracy: 0.4227
# Epoch 51/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1204 - accuracy: 0.5013
# Epoch 00051: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1190 - accuracy: 0.5019 - val_loss: 1.2337 - val_accuracy: 0.4433
# Epoch 52/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1154 - accuracy: 0.5109
# Epoch 00052: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1073 - accuracy: 0.5192 - val_loss: 1.2424 - val_accuracy: 0.4450
# Epoch 53/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1159 - accuracy: 0.5233
# Epoch 00053: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1212 - accuracy: 0.5226 - val_loss: 1.2377 - val_accuracy: 0.4381
# Epoch 54/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1042 - accuracy: 0.5055
# Epoch 00054: val_loss did not improve from 1.21066
# 11/11 [==============================] - 19s 2s/step - loss: 1.1090 - accuracy: 0.5088 - val_loss: 1.2401 - val_accuracy: 0.4536
# Epoch 55/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.0999 - accuracy: 0.5233
# Epoch 00055: val_loss did not improve from 1.21066
# 11/11 [==============================] - 19s 2s/step - loss: 1.1087 - accuracy: 0.5210 - val_loss: 1.2339 - val_accuracy: 0.4399
# Epoch 56/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1144 - accuracy: 0.5352
# Epoch 00056: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1126 - accuracy: 0.5312 - val_loss: 1.2616 - val_accuracy: 0.4416
# Epoch 57/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.0939 - accuracy: 0.5242
# Epoch 00057: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.0966 - accuracy: 0.5287 - val_loss: 1.2520 - val_accuracy: 0.4055
# Epoch 58/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1012 - accuracy: 0.5203
# Epoch 00058: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1024 - accuracy: 0.5206 - val_loss: 1.2454 - val_accuracy: 0.4433
# Epoch 59/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1122 - accuracy: 0.5301
# Epoch 00059: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1195 - accuracy: 0.5249 - val_loss: 1.2260 - val_accuracy: 0.4450
# Epoch 60/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.0997 - accuracy: 0.5125
# Epoch 00060: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.0995 - accuracy: 0.5170 - val_loss: 1.2515 - val_accuracy: 0.4536
# Epoch 61/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.0940 - accuracy: 0.5140
# Epoch 00061: val_loss did not improve from 1.21066
# 11/11 [==============================] - 19s 2s/step - loss: 1.0981 - accuracy: 0.5157 - val_loss: 1.2433 - val_accuracy: 0.4261
# Epoch 62/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.0937 - accuracy: 0.5123
# Epoch 00062: val_loss did not improve from 1.21066
# 11/11 [==============================] - 19s 2s/step - loss: 1.0962 - accuracy: 0.5119 - val_loss: 1.2412 - val_accuracy: 0.4502
# Epoch 63/200
# 10/11 [==========================>...] - ETA: 1s - loss: 1.1138 - accuracy: 0.5094
# Epoch 00063: val_loss did not improve from 1.21066
# 11/11 [==============================] - 20s 2s/step - loss: 1.1099 - accuracy: 0.5114 - val_loss: 1.2346 - val_accuracy: 0.4399
# Epoch 00063: early stopping

# %%
# Save
models.save_model(resnet50_ft_2layer, 'resnet50_ft_2layer_4cl_end.h5')

# %%
# History of accuracy and loss
tra_loss_fe = history_ft_2layer.history['loss']
tra_acc_fe = history_ft_2layer.history['accuracy']
val_loss_fe = history_ft_2layer.history['val_loss']
val_acc_fe = history_ft_2layer.history['val_accuracy']

# Total number of epochs training
epochs_fe = range(1, len(tra_acc_fe)+1)
end_epoch_fe = len(tra_acc_fe)

# Epoch when reached the validation loss minimum
opt_epoch_fe = val_loss_fe.index(min(val_loss_fe)) + 1

# Loss and accuracy on the validation set
end_val_loss_fe = val_loss_fe[-1]
end_val_acc_fe = val_acc_fe[-1]
opt_val_loss_fe = val_loss_fe[opt_epoch_fe-1]
opt_val_acc_fe = val_acc_fe[opt_epoch_fe-1]


print("resnet50 Fine Tuning (2 layers)\n")

print("Epoch [end]: %d" % end_epoch_fe)
print("Epoch [opt]: %d" % opt_epoch_fe)
print("Valid accuracy [end]: %.4f" % end_val_acc_fe)
print("Valid accuracy [opt]: %.4f" % opt_val_acc_fe)
print("Valid loss [end]: %.4f" % end_val_loss_fe)
print("Valid loss [opt]: %.4f" % opt_val_loss_fe)
# Out:
# resnet50 Fine Tuning (2 layers)
#
# Epoch [end]: 63
# Epoch [opt]: 33
# Valid accuracy [end]: 0.4399
# Valid accuracy [opt]: 0.4536
# Valid loss [end]: 1.2346
# Valid loss [opt]: 1.2107

# %%
# Loss and accuracy on the test set
opt_resnet50_ft_2layer = models.load_model('resnet50_ft_2layer_4cl_best.h5')
test_loss_fe, test_acc_fe = resnet50_ft_2layer.evaluate(test_images, test_labels, verbose=False)
opt_test_loss_fe, opt_test_acc_fe = opt_resnet50_ft_2layer.evaluate(test_images, test_labels, verbose=False)


print("Test accuracy [end]:  %.4f" % test_acc_fe)
print("Test accuracy [opt]:  %.4f" % opt_test_acc_fe)

print("Test loss [end]:  %.4f" % test_loss_fe)
print("Test loss [opt]:  %.4f" % opt_test_loss_fe)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-15-175ca0c77df9> in <module>
#       1 # Loss and accuracy on the test set
# ----> 2 opt_resnet50_ft_2layer = models.load_model('resnet50_ft_2layer_4cl_best.h5')
#       3 test_loss_fe, test_acc_fe = resnet50_ft_2layer.evaluate(test_images, test_labels, verbose=False)
#       4 opt_test_loss_fe, opt_test_acc_fe = opt_resnet50_ft_2layer.evaluate(test_images, test_labels, verbose=False)
#       5
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\saving\save.py in load_model(filepath, custom_objects, compile)
#     144   if (h5py is not None and (
#     145       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\saving\hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     166     model_config = json.loads(model_config.decode('utf-8'))
#     167     model = model_config_lib.model_from_config(model_config,
# --> 168                                                custom_objects=custom_objects)
#     169
#     170     # set weights
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\saving\model_config.py in model_from_config(config, custom_objects)
#      53                     '`Sequential.from_config(config)`?')
#      54   from tensorflow.python.keras.layers import deserialize  # pylint: disable=g-import-not-at-top
# ---> 55   return deserialize(config, custom_objects=custom_objects)
#      56
#      57
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\layers\serialization.py in deserialize(config, custom_objects)
#     104       module_objects=globs,
#     105       custom_objects=custom_objects,
# --> 106       printable_module_name='layer')
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\utils\generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     301             custom_objects=dict(
#     302                 list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# --> 303                 list(custom_objects.items())))
#     304       with CustomObjectScope(custom_objects):
#     305         return cls.from_config(cls_config)
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\engine\sequential.py in from_config(cls, config, custom_objects)
#     376       layer = layer_module.deserialize(layer_config,
#     377                                        custom_objects=custom_objects)
# --> 378       model.add(layer)
#     379     if not model.inputs and build_input_shape:
#     380       model.build(build_input_shape)
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\engine\sequential.py in add(self, layer)
#     201       # If the model is being built continuously on top of an input layer:
#     202       # refresh its output.
# --> 203       output_tensor = layer(self.outputs[0])
#     204       if len(nest.flatten(output_tensor)) != 1:
#     205         raise TypeError('All layers in a Sequential model '
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     746           # Build layer if applicable (if the `build` method has been
#     747           # overridden).
# --> 748           self._maybe_build(inputs)
#     749           cast_inputs = self._maybe_cast_inputs(inputs)
#     750
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in _maybe_build(self, inputs)
#    2114         # operations.
#    2115         with tf_utils.maybe_init_scope(self):
# -> 2116           self.build(input_shapes)
#    2117       # We must set self.built since user defined build functions are not
#    2118       # constrained to set self.built.
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\layers\core.py in build(self, input_shape)
#    1111         constraint=self.kernel_constraint,
#    1112         dtype=self.dtype,
# -> 1113         trainable=True)
#    1114     if self.use_bias:
#    1115       self.bias = self.add_weight(
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     444         synchronization=synchronization,
#     445         aggregation=aggregation,
# --> 446         caching_device=caching_device)
#     447     backend.track_variable(variable)
#     448
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\training\tracking\base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     742         dtype=dtype,
#     743         initializer=initializer,
# --> 744         **kwargs_for_getter)
#     745
#     746     # If we set an initializer and the variable processed it, tracking will not
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\engine\base_layer_utils.py in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner)
#     140       synchronization=synchronization,
#     141       aggregation=aggregation,
# --> 142       shape=variable_shape if variable_shape else None)
#     143
#     144
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     256   def __call__(cls, *args, **kwargs):
#     257     if cls is VariableV1:
# --> 258       return cls._variable_v1_call(*args, **kwargs)
#     259     elif cls is Variable:
#     260       return cls._variable_v2_call(*args, **kwargs)
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\ops\variables.py in _variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     217         synchronization=synchronization,
#     218         aggregation=aggregation,
# --> 219         shape=shape)
#     220
#     221   def _variable_v2_call(cls,
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\ops\variables.py in <lambda>(**kwargs)
#     195                         shape=None):
#     196     """Call on Variable class. Useful to force the signature."""
# --> 197     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     198     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     199       previous_getter = _make_getter(getter, previous_getter)
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\ops\variable_scope.py in default_variable_creator(next_creator, **kwargs)
#    2594         synchronization=synchronization,
#    2595         aggregation=aggregation,
# -> 2596         shape=shape)
#    2597   else:
#    2598     return variables.RefVariable(
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     260       return cls._variable_v2_call(*args, **kwargs)
#     261     else:
# --> 262       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     263
#     264
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1409           aggregation=aggregation,
#    1410           shape=shape,
# -> 1411           distribute_strategy=distribute_strategy)
#    1412
#    1413   def _init_from_args(self,
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1540           with ops.name_scope("Initializer"), device_context_manager(None):
#    1541             initial_value = ops.convert_to_tensor(
# -> 1542                 initial_value() if init_from_fn else initial_value,
#    1543                 name="initial_value", dtype=dtype)
#    1544           if shape is not None:
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\keras\engine\base_layer_utils.py in <lambda>()
#     120           (type(init_ops.Initializer), type(init_ops_v2.Initializer))):
#     121         initializer = initializer()
# --> 122       init_val = lambda: initializer(shape, dtype=dtype)
#     123       variable_dtype = dtype.base_dtype
#     124   if use_resource is None:
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\ops\init_ops_v2.py in __call__(self, shape, dtype)
#     423     else:
#     424       limit = math.sqrt(3.0 * scale)
# --> 425       return self._random_generator.random_uniform(shape, -limit, limit, dtype)
#     426
#     427   def get_config(self):
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\ops\init_ops_v2.py in random_uniform(self, shape, minval, maxval, dtype)
#     786       op = random_ops.random_uniform
#     787     return op(
# --> 788         shape=shape, minval=minval, maxval=maxval, dtype=dtype, seed=self.seed)
#     789
#     790   def truncated_normal(self, shape, mean, stddev, dtype):
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\ops\random_ops.py in random_uniform(shape, minval, maxval, dtype, seed, name)
#     270           shape, minval, maxval, seed=seed1, seed2=seed2, name=name)
#     271     else:
# --> 272       rnd = gen_random_ops.random_uniform(shape, dtype, seed=seed1, seed2=seed2)
#     273       result = math_ops.add(rnd * (maxval - minval), minval, name=name)
#     274     # TODO(b/132092188): C++ shape inference inside functional ops does not
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\ops\gen_random_ops.py in random_uniform(shape, dtype, seed, seed2, name)
#     722         pass  # Add nodes to the TensorFlow graph.
#     723     except _core._NotOkStatusException as e:
# --> 724       _ops.raise_from_not_ok_status(e, name)
#     725   # Add nodes to the TensorFlow graph.
#     726   dtype = _execute.make_type(dtype, "dtype")
#
# ~\anaconda3\envs\mammo\lib\site-packages\tensorflow_core\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6604   message = e.message + (" name: " + name if name is not None else "")
#    6605   # pylint: disable=protected-access
# -> 6606   six.raise_from(core._status_to_exception(e.code, message), None)
#    6607   # pylint: enable=protected-access
#    6608
#
# ~\anaconda3\envs\mammo\lib\site-packages\six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[131072,2048] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:RandomUniform]

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet50 FT (2 layers) accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_acc_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_acc_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_acc_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_acc_fe), opt_val_acc_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('resnet50 FT (2 layers) loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs_fe, tra_loss_fe, 'r', label='Training set')
plt.plot(epochs_fe, val_loss_fe, 'g', label='Validation set')
plt.plot(opt_epoch_fe, val_loss_fe[opt_epoch_fe-1], 'go')
plt.vlines(opt_epoch_fe, min(val_loss_fe), opt_val_loss_fe, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss_fe, 1, opt_epoch_fe, linestyle="dashed", color='g', linewidth=1)
plt.legend();
